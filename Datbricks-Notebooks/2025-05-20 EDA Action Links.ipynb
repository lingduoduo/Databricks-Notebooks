# %%
ml_catalog = "onedata_us_east_1_shared_dit"
ml_search_db = "nas_raw_lyric_search_dit"

df_action = spark.sql(f"""
    SELECT _id, caption, subtitle, count(*) AS views
    FROM {ml_catalog}.{ml_search_db}.ml_search_action
    WHERE context='US'
    GROUP BY 1, 2, 3
    ORDER BY 4 DESC
""")

# %%
display(df_action)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>caption</th><th>subtitle</th><th>views</th></tr></thead><tbody><tr><td>7843598ab66a41d28253f40b5e9a3c56</td><td>Manage Associate's Pay Profile</td><td>Maintain and capture Associate's pay data records within a legal entity and/or pay group.</td><td>1170</td></tr><tr><td>119fb43320ab44c9847c9b2284f7e848</td><td>View My Associate Profile</td><td>View My Associate Profile</td><td>1087</td></tr><tr><td>d0adbfea7381492e976ec090d26777ba</td><td>Manage Benefits Supplemental Fields</td><td>View and Manage Associate's benefit related supplemental eligibility and compliance values.</td><td>1036</td></tr><tr><td>899c324e3f2742ce9cd9d27a97048cc5</td><td>View Company Org Chart</td><td>View Company Org Chart</td><td>936</td></tr><tr><td>0429ea12a5974851ab47620c9d7205c9</td><td>View Criteria Control Center</td><td>Setup and manage the search queries that give eligibility, approvals, authorizations and other apps the flexibility and power they need to evolve with your workforce.</td><td>864</td></tr><tr><td>df6e2b589b0d462ebcdfb01bae2106c3</td><td>Add My Personal Contacts</td><td>Add a contact to your profile</td><td>838</td></tr><tr><td>846b123c190448f8a7b82f942d7609bd</td><td>View and Manage Associates' Benefits</td><td>Manage changes to associates' Benefits</td><td>816</td></tr><tr><td>9925c8101c7b43e98eeb2c6539728764</td><td>Manage Payroll Company Data</td><td>Configure company pay data and maintain payroll settings within a legal entity and/or pay group.</td><td>772</td></tr><tr><td>6aa709dc9ad44b7ea7e61424086e2415</td><td>View Your Pay</td><td>Access your pay details.</td><td>760</td></tr><tr><td>2a1ec3581d634da888cc03ce2dd8d818</td><td>Benefits Data Management</td><td>View and edit benefits data, add new records, and download benefits reports for all associates.</td><td>726</td></tr><tr><td>50f79735cf8647e1902b132b8063e3ae</td><td>Edit My Personal Demographics</td><td>Edit your gender, race, nationality, marital status and other birth details</td><td>684</td></tr><tr><td>4766e323575849acb389a0ba42353f89</td><td>Work Authorization Type Configuration</td><td>Manage work visas, permits and other documents</td><td>612</td></tr><tr><td>51ad5ab7fdeb47e380a43e00359373d4</td><td>View My Org</td><td>View your direct reports, peers, and managers.</td><td>577</td></tr><tr><td>229bbf0c07a449b08fd7731656cee98e</td><td>Create Criteria</td><td>Create a new search query for an app or domain.</td><td>574</td></tr><tr><td>ff3b3f8391b7490c95f3c0c693327aa5</td><td>Reports & Analytics</td><td>Run, create and manage reports and analytics with benchmarks</td><td>554</td></tr><tr><td>3a59d8daae5147c389cdaaffbcad7d64</td><td>Manage Authorizations</td><td>Manage permissions for users and apps.</td><td>538</td></tr><tr><td>61879fc535b74accb21081bda19bdd92</td><td>User Management Troubleshooting</td><td>Access CRUD pages for user registration, product access, passwords/usernames and more.</td><td>538</td></tr><tr><td>2c09c9db5dfb4314af1b9a4ffa28dbb6</td><td>Configure Associate Classification</td><td>Create, configure and manage associate classification</td><td>517</td></tr><tr><td>b3cc3ceac4d24c2e843aa13078bd2f8e</td><td>Hiring Dashboard</td><td>Navigate to the new hire dashboard to start a hire.</td><td>511</td></tr><tr><td>6152f780beef4fb3806ba3f43d3f88cb</td><td>Manage Licenses & Certifications</td><td>Manage the Library of Licenses and Certifications</td><td>508</td></tr><tr><td>9ca43b27a0ed48d699f0e126a9dcbe14</td><td>View Time Dashboard</td><td>Navigate to the Time Dashboard to view and manage time information</td><td>502</td></tr><tr><td>d27d5dcf28b442e09b090540cf80f3cd</td><td>View and Manage Benefits</td><td>View and Manage all Benefits</td><td>500</td></tr><tr><td>f0b0e94638cd4ffb8ee446fbca6c9086</td><td>AOID Tracker</td><td>View the status of AOID Provisioning for an associate</td><td>496</td></tr><tr><td>dcfb1c00f641403793 ...

# %% [markdown]
# ### Tokenize and Normalize

# %%
import re
import string

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from typing import List
from nltk.stem import PorterStemmer, WordNetLemmatizer

class CustomTextSplitter:
    """A custom text splitter that extracts top keywords from each segment using NLTK."""

    def __init__(self, separator: str, **kwargs):
        """
        Initialize with a separator string and number of keywords to extract per segment.
        :param separator: The string to split the text on.
        """
        self._separator = separator
        self._stopwords = set(stopwords.words('english'))
        self._punct_table = str.maketrans('', '', string.punctuation)

    def normalize_text(self, text: str):
        # Replace line breaks (both types) with spaces
        text = re.sub(r'[\n\r]', ' ', text)

        # Replace special characters
        text = re.sub(r'#([[a-zA-Z]|[0-9]]+)', ' ', text)

        # Replace URLs
        text = re.sub(r'http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\(\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+', ' ', text)

        # Replace user mentions
        text = re.sub(r'@(\w+)', ' ', text)

        # Convert to lowercase
        text = text.lower()

        # Remove punctuation
        text = text.translate(str.maketrans('', '', string.punctuation))

        # Replace two or more subsequent white spaces with a single space
        text = re.sub(r'\ {2,}', ' ', text)

        # Trim white spaces at the beginning or end
        text = text.strip()
        return ' ' if text is None else text

    def split_text(self, text: str) -> List[str]:
        """
        Split the input text using the separator, extract keywords from each segment,
        and return a list of comma-separated keyword strings per segment.
        :param text: The full text to split and analyze.
        :return: List of keyword strings for each segment.
        """
        segments = text.split(self._separator)
        keyword_chunks: List[str] = []
        for segment in segments:
            tokens = word_tokenize(segment.lower())
            cleaned = [t.translate(self._punct_table) for t in tokens]
            filtered_tokens = [self.normalize_text(t) for t in cleaned if t.isalpha() and t not in self._stopwords]

            # Initialize the stemmer and lemmatizer
            # stemmer = PorterStemmer()
            lemmatizer = WordNetLemmatizer()
            # processed_tokens = [lemmatizer.lemmatize(stemmer.stem(word)) for word in filtered_tokens]
            processed_tokens = [lemmatizer.lemmatize(word) for word in filtered_tokens]
            keyword_chunks.append(",".join(processed_tokens))

            # Compute frequency distribution and get top K
            # freq_dist = nltk.FreqDist(processed_tokens)
            # top_keywords = [word for word, _ in freq_dist.most_common(self._top_k)]
            # keyword_chunks.append(",".join(top_keywords))

        return keyword_chunks

# %%
pdf_action = df_action.toPandas()
pdf_action['combined'] = pdf_action.apply(
    lambda x: x.caption if x.caption.lower() == x.subtitle.lower() else ','.join([x.caption, x.subtitle]), 
    axis=1
)
documents = "\n\n".join(pdf_action.combined)
documents[:100]
# Out:
# "Manage Associate's Pay Profile,Maintain and capture Associate's pay data records within a legal enti"

# %%
splitter = CustomTextSplitter(separator="\n\n")
processed_tokens = splitter.split_text(documents)

# %%
processed_tokens
# Out:
# ['view,associate,profile',
#  'manage,benefit,supplemental,field,view,manage,associate,benefit,related,supplemental,eligibility,compliance,value',
#  'manage,associate,pay,profile,maintain,capture,associate,pay,data,record,within,legal,entity,andor,pay,group',
#  'view,company,org,chart',
#  'view,criterion,control,center,setup,manage,search,query,give,eligibility,approval,authorization,apps,flexibility,power,need,evolve,workforce',
#  'add,personal,contact,add,contact,profile',
#  'view,manage,associate,benefit,manage,change,associate,benefit',
#  'benefit,data,management,view,edit,benefit,data,add,new,record,download,benefit,report,associate',
#  'view,pay,access,pay,detail',
#  'manage,payroll,company,data,configure,company,pay,data,maintain,payroll,setting,within,legal,entity,andor,pay,group',
#  'edit,personal,demographic,edit,gender,race,nationality,marital,status,birth,detail',
#  'create,criterion,create,new,search,query,app,domain',
#  'hiring,dashboard,navigate,new,hire,dashboard,start,hire',
#  'work,authorization,type,configuration,manage,work,visa,permit,document',
#  'manage,license,certification,manage,library,license,certification',
#  'user,management,troubleshooting,access,crud,page,user,registration,product,access,passwordsusernames',
#  'report,analytics,run,create,manage,report,analytics,benchmark',
#  'view,org,view,direct,report,peer,manager',
#  'configure,additional,associate,identifier,add,new,identification,type,assigned,associate',
#  'configure,associate,classification,create,configure,manage,associate,classification',
#  'send,registration,email,send,registration,email,one,many,associate',
#  'manage,authorization,manage,permission,user,apps',
#  'view,license,certification,manage,license,certification,certification,section,profile,page',
#  'approval,management,dashboard,view,manage,approval,request',
#  'aoid,tracker,view,status,aoid,provisioning,associate',
#  'view,hr,inbound,data,dashboard,view,manage,inbound,hr,data',
#  'view,time,dashboard,navigate,time,dashboard,view,manage,time,information',
#  'manage,user,manage,user,registration,account,status,recovery,feature',
#  'view,manage,benefit,view,manage,benefit',
#  'assign,additional,associate,identifier,assign,remove,configured,identification,type,associate',
#  'manage,hour,earnings,view,manage,company,hour,earnings',
#  'manage,company,survey',
#  'company,link,faq',
#  'appliedforactionlink,navigate,applied,associate,listing,view,associate,applied,document,number,hiring',
#  'view,approve,team,time',
#  'configure,approval,request,workflow,configure,workflow,approval,request',
#  'manage,company,compensation',
#  'import,new,hire,at,manally,import,new,hire,at,either,csv,excel,format',
#  'view,scope,management',
#  'view,time,time',
#  'bulk,termination,process,bulk,termination,import,screen,workflow',
#  'configure,leave,absence,manage,reason,category,leave,absence',
#  'manage,fluid,field,definition,create,view,modify,fluid,field,definition',
#  'view,approve,team,timecard,view,approve,team,timecard',
#  'manage,company,broadcast,message',
#  'createupdatedelete,associate,data,ic,associate,crud',
#  'payload,handler,configure,manage,inbound,filebased,integration',
#  'view,occupational,classification,manage,list,occupational,classification',
#  'add,physical,address,add,physical,address',
#  'manage,company,policy,manage,view,company,policy',
#  'add,mailing,address,add,mailing,address',
#  'export,associate,detail,export,associate,data',
#  'quarter,year,end,checklist,maintain,action,quarter,year,end,checklist,item,per,pay,group',
#  'view,direct,deposit,view,edit,direct,deposit',
#  'configure,work,relationship,type,allows,add,edit,delete,work,relationship,type',
#  'change,product,access,customize,adp,product,appear,user,navigate,log',
#  'manage,compensation,review',
#  'view,identification,view,identification,document',
#  'view,snapshot',
#  'document,management,dashboard,view,manage,document',
#  'manage,setting,setting,page',
#  'delegate,set,delegate,act,approval,request,pending,approval,office',
#  'manage,consent,adp,benchmark',
#  'view,hr,dashboard,hr,dashboard',
#  'manage,team,broadcast,message',
#  'manage,company,time,manage,time,request,balance,policy,holiday,calendar,work,schedule,payouts',
#  'manage,company,time,manage,time,balance,policy,holiday,calendar,work,pattern',
#  'bulk,document,migration,dashboard,view,manage,document,import',
#  'view,job,chart,view,job,chart',
#  'manage,associate,pay,profile,maintain,capture,associate,pay,data,record,within,legal,entity,andor,pay,group',
#  'lightweight,integration,configure,manage,outbound,filebased,integration',
#  'view,job,family,view,list,job,family',
#  'view,job,template,view,list,job,template',
#  'view,exit,interview,dashboard,mange,organization,exit,interview,process',
#  'change,login,method,configure,user,asked,log',
#  'view,position',
#  'view,legal,entity,view,list,legal,entity',
#  'view,fluid,field,activity,log,view,change,made,fluid,field,value,based,selected,business,object',
#  'touchpoints,view,edit,touchpoints,assigned',
#  'view,team,schedule,view,team,schedule',
#  'view,wisely,enroll,wisely,pay,card',
#  'request,time',
#  'view,client,provided,translation',
#  'view,cost,center,view,list,cost,center',
#  'view,dynamic,team,view,list,dynamic,team',
#  'configure,movement,reason,add,change,remove,reason,people,movement',
#  'delegate,information,set,delegate,act,approval,request,pending,approval,office',
#  'asset,management',
#  'view,additional,time,feature',
#  'view,schedule,schedule',
#  'clock,inout,manage,clock,inout',
#  'view,pulse,complete',
#  'view,enterprise,unit',
#  'import,legacy,system,data,import,manage,legacy,system,employment,data,past,hcm,system',
#  'view,request,leave,absence',
#  'view,completed,engagement,pulse',
#  'manage,pay,run,process,payroll,data,within,pay,group,given,pay,period,review,commit,pay,run',
#  'view,team,checkins',
#  'manage,vet,report,view,create,vet,report',
#  'request,time',
#  'award,management,view,manage,award',
#  'manage,aca,report,view,generate,aca,report',
#  'configure,union,bargaining,unit,create,configure,manage,union,bargaining,unit',
#  'view,support,ticket,view,support,ticket',
#  'view,faq,view,frequently,asked,question',
#  'manage,eeo,report,manage,create,eeo,report',
#  'view,cornerstone,employee,sync,dashboard,view,track,employee,sync,lifion,cornerstone',
#  'manage,illness,injury,reporting,manage,create,illness,injury,incident',
#  'manage,adp',
#  'view,tax,dashboard',
#  'submit,performance,pulse,submit,performance,pulse,track,team,member,performance',
#  'configure,competency',
#  'import,pay,data,import,temporary,rate,payouts,unit',
#  'learning,management,learning,admin,practitioner',
#  'manage,payroll,policy,configure,manage,payroll,policy,available,client',
#  'assembly',
#  'view,timecard,timecard',
#  'view,checkin',
#  'view,team,snapshot',
#  'edit,nationality,edit,nationality',
#  'manage,leave',
#  'add,language,add,language,profile',
#  'create,position',
#  'update,email,edit,email,address',
#  'global,integration,dashboard,view,manage,global,hr,payroll,integration',
#  'update,phone,number,edit,phone,number',
#  'view,benefit',
#  'import,client,provided,translation',
#  'export,current,data,export,client,translation,data',
#  'datacloud,admin,dashboard',
#  'manage,cornerstone,configuration,configure,authorization,timezone,mapping,country,mapping,mft,detail',
#  'view,succession,org,chart,use,org,chart,perform,succession,planning',
#  'submit,help,ticket,submit,problem,feature,request,hr,team',
#  'configure,followup,action,add,delete,followup,configuration',
#  'view,tax,withholding,view,edit,tax,withholding,election',
#  'talent,management,demo,tool,talent,management,demo,tool,implementation,consultant',
#  'edit,birth,detail,edit,birth,detail',
#  'learning,learning,employee',
#  'disciplinary,incident,view,acknowledge,disciplinary,incident',
#  'data,reconciliation,report,compare,reconcile,information,system',
#  'integration,core,tooling',
#  'import,education,history',
#  'integration,dashboard',
#  'disciplinary,setting,view,create,edit,disciplinary,incident,action,type',
#  'view,compensation',
#  'process,internal,hire',
#  'bulk,job,change',
#  'configure,worker,compensation,code,create,configure,manage,worker,compensation,code',
#  'team,learning',
#  'manage,recruiting',
#  'edit,profile,image,edit,profile,image',
#  'outbound,integration,execution,dashboard',
#  'broadcast,message,voice,employee',
#  'configure,onboarding',
#  'survey,voice,employee',
#  'bulk,leave,absence,update,associate,tofrom,leave,absence,status,bulk',
#  'manage,payroll,calendar,view,manage,payroll,calendar,pay,group',
#  'garnishment,dashboard',
#  'data,reconciliation,report,compare,reconcile,information,system',
#  'view,work,anniversary,celebrating,work,anniversary,important,part,employee,engagement,view,work,anniversary,listed,month',
#  'generate,cornerstone,file,manually,generate,different,file,need,manually,uploaded,cornerstone',
#  'manage,associate,pay,profile,maintain,capture,associate,pay,data,record,within,legal,entity,andor,pay,group',
#  'manage,global,payroll,action,link,global,payroll',
#  'configure,performance,plan',
#  'view,company,news,view,news,post,related,organization',
#  'manage,pay,group,transfer,pay,group,transfer,listing',
#  'configure,goal,objective',
#  'manage,successor,position,identifying,managing,successor,position,help,mitigate,risk,involved,position,becomes,vacant',
#  'manage,time',
#  'manage,team,survey',
#  'configure,compensation,review,allow,user,configure,compensation,planning',
#  'case,management,enable,user,search,case,management,miniapp,homepage',
#  'registration,dashboard,dashboard,track,associate,registration',
#  'manage,successor,identifying,managing,successor,one,position,encouraged,help,manager,hr,practitioner,identify,successor',
#  'view,payroll,dashboard,payroll,dashboard',
#  'manage,new,hire,at,view,process,delete,new,hire,at',
#  'configure,work,authorization,expiration,reminder,configure,timing,recipient,notification,upcoming,document,expiration',
#  'view,payroll,report,dashboard,view,payroll,report',
#  'test',
#  'view,performance,review,view,review',
#  'associate,data,import',
#  'manage,benefit,form,plan,document,manage,benefit,form,document',
#  'contract,management,allows,user,configure,manage,contract',
#  'manage,prior,quarter,year,adjustment,manage,prior,current,payroll,adjustment,united,state,canada',
#  'integration,health,monitor',
#  'view,onboarding',
#  'benefit,implementation,stepbystep,process,set,manage,modify,client,benefit',
#  'record,employment,manage,record,employment,roe,canadian,associate',
#  'manuel,test,google',
#  'manage,news,post,create,edit,publish,news,post,organization',
#  'associate,directory,search,employee',
#  'performance,evaluation',
#  'enter,hour,worked,view,enter,time,adp,time',
#  'manage,integration,monitor,manage,lifion,integration,adp,enterprise',
#  'hello',
#  'manage,birthday,notificationconsent,preference,manage,preference,see,birthday,others,consent,share,birthday,others',
#  'view,dynamic,team,chart,view,dynamic,team,chart',
#  'manage,team,onboarding',
#  'view,office,location,view,list,office,location',
#  'organization,management',
#  'manage,transaction,manage,associate,record',
#  'sync,coded,field,table',
#  'import,fluid,field,value,import,value,fluid,field,bulk,using,template',
#  'performance,setting,performance,setting,practitioner',
#  'classroom,training,management,link,instructor,persona',
#  'datacloud,dashboard,datacloud,adhoc,reporting,metric',
#  'manage,central,rate,action,link,taking,associate,client,central,rate,configuration,tile',
#  'core,hr,inbound,import,staging,list',
#  'manage,okrs',
#  'manage,time,manage,time,adp,time',
#  'berichte,und,analysen,berichte,und,analysen,mit,benchmark,ausführen,erstellen,und,verwalten',
#  'fehlerbehebung,benutzermanagement,zugriff,auf,crudseiten,für,benutzerregistrierung,produktzugang,passwörterbenutzernamen,und,mehr',
#  'produktzugriff,ändern,legen,sie,fest,zu,welchen,anderen,adpprodukten,die,benutzer,navigieren,können,wenn,sie,sich,anmelden',
#  'einwilligung,für,adpbenchmarks,verwalten',
#  'benutzer,verwalten,verwalten,sie,benutzerregistrierung,kontostatus,und,wiederherstellungsfunktionen',
#  'den,arbeitsblauf,de,genehmigungsantrags,konfigurieren,konfigurieren,sie,den,arbeitsblauf,ihres,genehmigungsantrags',
#  'autorisierungen,verwalten,verwalten,sie,berechtigungen,für,benutzer,und,apps',
#  'fluidfelddefinitionen,verwalten,erstellen,anzeigen,oder,ändern,von,fluidfelddefinitionen',
#  'daten,de,gehaltsabrechnungsunternehmens,verwalten,konfigurieren,sie,lohngehaltsdaten,de,unternehemens,und,verwalten,sie,abrechnungen,innerhalb,einer,juristischen,person,undoder,lohngehaltsgruppe',
#  'anmeldemethoden,ändern,konfigurieren,sie,wie,benutzer,sich,anmelden,sollen',
#  'registrierungsemails,senden,senden,sie,eine,registrierungsemail,einen,oder,mehrere,mitarbeiter',
#  'view,birthday,view,birthday,birthday,listing,page',
#  'payroll,import',
#  'view,dynamic,team,view,list,dynamic,team',
#  'manage,disciplinary,action,view,create,disciplinary,action,incident',
#  'import,new,hire,go,new,hire,setup,import,new,hire',
#  'viewedit,approve,team,time,card,allows,user,manage,time,card,direct,reportees',
#  'manage,general,ledger,navigate,adp,gl,manage,general,ledger',
#  'view,client,management,client,client,archived,client,data',
#  'view,internal,career,site',
#  'launch,engagement,pulse',
#  'manage,cycle,setup',
#  'create,cycle',
#  'juristische,personen,anzeigen,die,liste,der,juristischen,personen,anzeigen',
#  'mein,mitarbeiterprofil,anzeigen',
#  'eigene,demografischen,angaben,bearbeiten,ihre,geschlecht,ethnische,herkunft,staatsangehörigkeit,familienstand,und,sonstige,geburtsdaten,bearbeiten',
#  'meine,persönlichen,kontakte,hinzufügen,kontakt,zu,ihrem,profil,hinzufügen',
#  'geburtsangaben,bearbeiten,ihre,geburtsangaben,bearbeiten',
#  'konfigurationen,der,versetzungsgründe,fügen,sie,gründe,für,personenbewegungen,hinzu,ändern,oder,entfernen,sie,diese',
#  'meine,staatsangehörigkeiten,bearbeiten,ihre,staatsangehörigkeit,bearbeiten',
#  'manage,succession,plan,manage,succession,plan,key,critical,position',
#  'identify,critical,position,identifying,critical,position,important,activity,involved,succession,planning,position,critical,call,attention,succession,planning,place',
#  'performance,setup',
#  'compliance,demand',
#  'policy,management',
#  'view,classic,recruiting,management',
#  'manage,record,employment,action,link,roe,dashboard',
#  'impersonation,test',
#  'responsibility,view,manage,participant,relationship,responsibility',
#  'approve,time,view,approve,time,adp,time',
#  'update,goal,objective',
#  'bildungsverlauf,importieren',
#  'kriterien,erstellen,erstellen,sie,eine,neue,suchanfrage,für,eine,app,oder,domäne',
#  'zahlungsdaten,importieren,befristete,sätze,auszahlungen,und,einheiten,importieren',
#  'massenkündigung,massenkündigung,durch,einen,import,oder,dem,eingabemaskenworkflow,verarbeiten',
#  'kriterienkontrollzentrum,anzeigen,richten,sie,entsprechende,suchanfragen,ein,und,verwalten,sie,sie,um,berechtigungen,genehmigungen,und,autorisierungen,zu,erteilen,sowie,anderen,apps,die,flexibilität,und,leistungsfähigkeit,zu,verleihen,damit,sie,sich,zusammen,mit,ihrer,belegschaft,weiterentwickeln,können',
#  'reporting,help',
#  'configure,performance,plan',
#  'request,time,request,time,myadp',
#  'audit,reporting,create,download,audit,report',
#  'manageupdate,talent,assessment',
#  'view,recognition',
#  'data,bridge,configure,manage,inbound,filebased,integration',
#  'manage,global,payroll,action,link,celego,dashboard',
#  'view,client,administrator,view,administrator',
#  'manage,special,accommodation',
#  'manage,career,development',
#  'recognize,someone',
#  'administrar,los,datos,de,la,compañía,de,nómina,configure,los,datos,de,pago,de,la,compañía,mantenga,los,ajustes,de,la,nómina,dentro,de,la,entidad,jurídica,el,grupo,de,pago',
#  'view,report,okrs',
#  'view,everyone,okrs',
#  'traqueur,de,l,identifiant,de,l,organisation,associée,voir,le,statut,de,lattribution,de,privilèges,daccès,de,laoid,identifiant,de,l,organisation,associée,pour,un,collaborateur',
#  'voir,mon,aperçu',
#  'disciplinary,incident,view,report,disciplinary,incident',
#  'ver,administrar,beneficios,ver,administrar,todos,los,beneficios',
#  'ver,puestos',
#  'crear,puesto',
#  'assemblage',
#  'voir,me,identification,afficher,vos,document,identification',
#  'course,absorb,course',
#  'termination,configuration,setting,termination,configuration,setting',
#  'configure,career,profile',
#  'manage,enhanced,workflow',
#  'manage,timecard,view,edit,timecard',
#  'manage,talent,cycle',
#  'manage,eda',
#  'create,survey',
#  'administrar,autorizaciones,administrar,los,permisos,para,usuarios,aplicaciones',
#  'conjunto',
#  'view,checkins',
#  'administración,de,datos,de,beneficios,vea,edite,datos,de,beneficios,agregue,nuevos,registros,descargue,informes,de,beneficios,para,todos,los,colaboradores',
#  'configuración,de,tipo,de,permiso,de,trabajo,administrar,visados,de,trabajo,permisos,otros,documentos',
#  'manage,associate,pay,profile,tenez,à,jour,et,saisissez,le,enregistrements,relatifs,aux,données,de,paie,de,collaborateurs,au,sein,dune,entité,juridique,etou,dun,groupe,de,pay',
#  'gérer,le,données,de,entreprises,de,service,de,paie,configurez,le,données,de,paie,de,lentreprise,et,maintenez,le,paramètres,de,paie,dans,une,entité,juridique,etou,un,groupe,de,pay',
#  'configurer,le,congés,autorisés,gérer,le,motif,et,le,catégories,de,congés',
#  'ajouter,me,coordonnées,personnelles,ajouter,un,contact,à,votre,profil',
#  'statement,remittance,run,report,canada,tax,agency,remittance',
#  'afficher,mon,profil,de,collaborateur',
#  'dhmodalsize,opentoseemodalsize',
#  'ver,centro,de,control,de,criterios,configure,gestione,la,consultas,de,búsqueda,que,dan,la,elegibilidad,la,aprobaciones,la,autorizaciones,otras,aplicaciones,la,flexibilidad,la,potencia,que,necesitan,para,evolucionar,con,su,personal',
#  'ver,administrar,beneficios,del,colaborador,administrar,cambios,los,beneficios,del,colaborador',
#  'manage,associate,pay,profile,mantener,capturar,registros,de,datos,de,pago,de,los,colaboradores,dentro,de,una,entidad,legal,grupo,de,pago',
#  'view,recruiting,overview',
#  'adp,assist,knowledge,center,manage,aipowered,content,common,associate,question',
#  'lista,de,verificación,trimestral,anual,mantener,tomar,medidas,para,el,trimestre,los,elementos,de,la,lista,de,verificación,de,fin,de,año,por,grupo,de,pago',
#  'cese,masivo,procesar,despido,masivo,través,de,una,importación,un,flujo,de,trabajo,de,pantalla',
#  'calibrate,talent,attribute',
#  'ajouter,mon,adresse,physique,ajouter,votre,adresse,postale',
#  'importer,le,nouveaux,employés,at,importer,manuellement,le,nouveaux,employés,dat,en,format,csv,ou,excel',
#  'rapport,et,analysis,exécuter,créer,et,gérer,de,rapport,et,de,analysis,avec,de,point,repères',
#  'section,separate',
#  'consulter,me,dépôts,directs,pour,afficher,et,modifier,le,dépôts,directs',
#  'ajouter,mon,adresse,postale,ajouter,votre,adresse,postale',
#  'formation,mon,apprentissage,à,l,intention,de,employés',
#  'modifier,me,données,démographiques,personnelles,modifier,votre,sexe,votre,race,votre,nationalité,votre,état,civil,et,dautres,information,relative,à,votre,naissance',
#  'tableau,de,bord,de,saisiesarrêts',
#  'search,job',
#  'test',
#  'test',
#  'manage,associate,pay,data,maintain,capture,associate,pay,data,record,within,legal,entity,andor,pay,group',
#  'test',
#  'lmage,library,add,image',
#  'crear,criterios,cree,una,nueva,consulta,de,búsqueda,para,una,aplicación,un,dominio',
#  'editar,detalles,de,nacimiento,editar,sus,detalles,de,nacimiento',
#  'cambiar,métodos,de,inicio,de,sesión,configure,cómo,se,le,pide,los,usuarios,que,inicien,sesión',
#  'agregar,idioma,agregar,idioma,en,mi,perfil',
#  'importar,historial,educativo',
#  'editar,mi,información,demográfica,personal,editar,su,género,raza,nacionalidad,estado,civil,otros,detalles,de,nacimiento',
#  'configurar,los,tipos,de,relaciones,laborales,le,permite,agregar,editar,eliminar,tipos,de,relaciones,laborales',
#  'configurar,motivos,de,movimientos,agregar,cambiar,eliminar,motivos,de,los,movimientos,de,persona',
#  'cambiar,acceso,al,producto,personalice,qué,otros,productos,de,adp,aparecen,para,que,los,usuarios,naveguen,cuando,inician,sesión',
#  'administrar,la,configuración,de,cornerstone,configurar,autorización,asignación,de,zona,horaria,asignación,de,país,detalles,de,mft',
#  'administrar,los,datos,de,la,empresa,de,nómina,configurar,los,datos,de,pago,de,la,empresa,mantener,los,ajustes,de,la,nómina,dentro,de,la,entidad,jurídica,el,grupo,de,pago',
#  'administrar,definiciones,de,campos,fluidos,crear,ver,modificar,definiciones,de,campos,fluidos',
#  'agregar,mi,contactos,personales,agregar,un,contacto,su,perfil',
#  'editar,mi,nacionalidades,editar,su,nacionalidad',
#  'configurar,permiso,de,ausencia,administrar,los,motivos,la,categorías,del,permiso,de,ausencia',
#  'editar,imagen,de,perfil,editar,su,imagen,de,perfil',
#  'ver,mi,perfil,de,colaborador',
#  'afficher,le,mi,au,point,de,l,équipe',
#  'retrospective',
#  'afficher,mon,organigramme,afficher,vos,subordonnés,directs,vos,pair,et,vos,manager',
#  'tableau,de,bord,dembauche,accéder,au,tableau,de,bord,de,nouveaux,employés,pour,lancer,une,embauche',
#  'gestion,de,données,de,avantages,sociaux,consulter,et,modifier,le,données,relative,aux,avantages,sociaux,ajouter,de,nouveaux,dossier,et,télécharger,le,rapport,sur,le,avantages,sociaux,pour,tous,le,employés',
#  'consulter,votre,paie,accéder,à,vos,données,de,paie',
#  'view,team,view,list,team',
#  'générer,manuellement,de,fichiers,cornerstone,générer,le,différents,fichiers,qui,doivent,être,téléversés,manuellement,dans,cornerstone',
#  'afficher,me,congés,congés',
#  'minimum,wage,watcher,minimum,wage,watcher,dashboard',
#  'afficher,le,tableau,de,bord,de,synchronisation,de,employés,de,cornerstone,afficher,et,suivre,la,synchronisation,de,employés,entre,lifion,et,cornerstone',
#  'gérer,le,utilisateurs,gérer,le,inscription,de,utilisateurs,létat,de,comptes,et,le,fonctionnalités,de,récupération',
#  'demander,un,congé',
#  'envoyer,un,suivi,de,rendement,envoyer,un,suivi,de,rendement,pour,évaluer,le,rendement,de,membres,de,léquipe',
#  'consulter,l,organigramme,de,l,entreprise',
#  'document,cloud,dashboard,view,document,cloud,dashboard,functionality',
#  'configure,enhanced,workflow',
#  'agregar,mi,dirección,postal,agregue,su,dirección,postal',
#  'extended,benefit,enrollment',
#  'ver,sus,prestaciones',
#  'implementación,de,beneficios,proceso,por,etapas,para,configurar,administrar,modificar,los,beneficios,de,un,cliente',
#  'ver,panel,de,control,fiscal',
#  'view,engagement,pulse',
#  'importar,datos,de,pago,importar,retribuciones,pagos,unidades,temporales',
#  'consulte,la,preguntas,frecuentes,consulte,la,preguntas,frecuentes',
#  'envíe,un,ticket,de,ayuda,envíe,problemas,solicitude,de,funciones,al,equipo,de,rr,hh',
#  'homepage,setting',
#  'home',
#  'manage,associate,pay,profile,और',
#  'gérer,la,rémunération,de,votre,entreprise',
#  'afficher,et,gérer,le,avantages,sociaux,du,collaborateur,gérer,le,changements,apportés,aux,avantages,sociaux,de,collaborateurs',
#  'configurer,la,classification,du,collaborateur,créer,configurer,et,gérer,la,classification,de,collaborateurs',
#  'gérer,le,politiques,entreprise,gérer,et,visualiser,le,politiques,de,votre,entreprise',
#  '',
#  'और,एक,और',
#  'gérer,le,rapport,vet,afficher,et,créer,de,rapport,vet',
#  'afficher,le,familles,demploi,afficher,la,liste,de,familles,demploi',
#  'gérer,le,champ,supplémentaires,avantages,sociaux,afficher,et,gérer,le,valeurs,supplémentaires,admissibilité,et,de,conformité,liées,aux,avantages,sociaux,du,collaborateur',
#  'afficher,le,tableau,demplois,afficher,le,tableau,demploi',
#  'tableau,de,bord,de,intégrations',
#  'configurer,le,flux,de,travail,correspondant,à,la,demande,dapprobation,configurer,le,flux,de,travail,correspondant,à,votre,demande,dapprobation',
#  'afficher,et,approuver,le,congés,de,l,équipe',
#  'configuration,du,type,de,permis,de,travail,gérer,le,visa,le,permis,de,travail,et,autres,document',
#  'afficher,le,postes',
#  'lista,de,comprobación,trimestral,anual,mantener,tomar,medidas,para,el,trimestre,los,elementos,de,la,lista,de,comprobación,de,fin,de,año,por,grupo,de,pago',
#  'outils,de,base,pour,l,intégration',
#  'afficher,le,tableau,de,bord,gestion,du,temp,naviguez,vers,le,tableau,de,bord,gestion,du,temp,pour,visualiser,et,gérer,le,information,de,temp',
#  'tableau,de,bord,dembauche,accéder,au,tableau,de,bord,de,nouveaux,employés,pour,lancer,une,embauche',
#  'apex,inbound,integration,run,configure,view,log,apex,integration',
#  'afficher,tableau,de,bord,données,entrantes,rh,affichez,et,gérez,le,données,de,rh,entrantes',
#  'mettre,à,jour,mon,adresse,de,courriel,modifier,vos,adresses,de,courriel',
#  'modifier,le,méthodes,de,connexion,configurer,la,façon,dont,le,utilisateurs,sont,invités,à,se,connecter',
#  'modifier,laccès,aux,produits,personnaliser,le,produits,adp,auxquels,le,utilisateurs,peuvent,accéder,lorsquils,se,connectent',
#  'cessation,demploi,en,masse,traiter,le,cessation,emploi,en,masse,au,moyen,une,importation,ou,un,flux,de,travail,à,l,écran',
#  'relevés,demploi,gérer,le,relevé,demploi,pour,le,collaborateurs,canadiens',
#  'consulter,votre,paie,accéder,à,vos,données,de,paie',
#  'gérer,le,rapport,aca,afficher,et,générer,le,rapport,aca',
#  'generar,manualmente,archivos,de,cornerstone,generar,los,diferentes,archivos,que,se,deben,cargar,manualmente,cornerstone',
#  'gérer,le,paramètres,page,paramètres',
#  'और,और',
#  'demander,un,congé',
#  'créer,un,poste',
#  'afficher,mon,org,afficher,vos,subordonnés,directs,vos,pair,et,vos,gestionnaires',
#  'importar,la,nuevas,contrataciones,de,at,importar,manualmente,la,nuevas,contrataciones,de,at,en,formato,csv,excel',
#  'gérer,dans,adp',
#  'view,list,dynamic,team',
#  'recruiting,configuration',
#  'और',
#  'modifier,l,image,du,profil,modifier,votre,photo,de,profil',
#  'modifier,me,nationalités,modifier,votre,nationalité',
#  'afficher,le,tableau,de,bord,de,rh,tableau,de,bord,de,rh',
#  'afficher,la,gestion,de,champ,dapplication',
#  'modifier,le,détails,de,la,date,de,naissance,modifier,le,données,de,votre,naissance',
#  'liste,de,vérification,pour,la,fin,du,trimestre,et,de,l,année,tenir,à,jour,le,éléments,de,la,liste,de,contrôle,de,fin,de,trimestre,et,de,fin,année,par,groupe,de,pay,et,donner,suite',
#  'gérer,le,autorisations,gérer,le,permission,pour,le,utilisateurs,et,le,application',
#  'और,और',
#  'afficher,me,congés,congé',
#  'tableau,de,bord,de,gestion,de,approbation,voir,et,gérer,le,demandes,dapprobation',
#  'configurar,códigos,de,compensación,del,trabajador,crear,configurar,administrar,los,códigos,de,compensación,de,los,trabajadores',
#  'controlador,de,cargas,configurar,administrar,integraciones,entrantes,basadas,en,archivos',
#  'configurar,sindicatos,unidades,de,negociación,crear,configurar,administrar,sindicatos,unidades,de,negociación',
#  'exportar,datos,actuales,exporta,los,datos,de,traducción,del,cliente',
#  'importar,datos,del,sistema,heredado,importar,gestionar,los,datos,de,empleo,del,sistema,heredados,desde,los,sistemas,hcm,anteriores',
#  'ver,panel,de,control,de,los,datos,de,entrada,de,rr,hh,vea,gestione,los,datos,de,entrada,de,rr,hh',
#  'configure,compensation,code,create,configure,manage,compensation,code',
#  'procesar,contrataciones,internas',
#  'general,ledger',
#  'configurar,los,recordatorios,de,caducidad,de,permiso,de,trabajo,configurar,la,programación,los,destinatarios,para,la,notificaciones,de,caducidad,de,documento,próxima',
#  'configurar,el,flujo,de,trabajo,de,solicitud,de,aprobación,configurar,el,flujo,de,trabajo,de,su,solicitud,de,aprobación',
#  'ver,panel,de,control,de,tiempo,vaya,al,panel,de,control,de,tiempo,para,ver,administrar,la,información,de,tiempo',
#  'configurar,contratación',
#  'ver,la,plantillas,de,trabajo,ver,la,lista,de,platillas,de,trabajo',
#  'checar,entradasalida,administrar,registro,de,entradasalida',
#  'administrar,campos,complementarios,de,prestaciones,ver,administrar,los,valores,de,elegibilidad,cumplimiento,complementarios,relacionados,con,la,prestaciones,del,colaborador',
#  'administrar,transferencia,del,grupo,de,pago,listas,de,transferencia,del,grupo,de,pago',
#  'administrar,los,formularios,documentos,de,plan,de,beneficios,administrar,los,formularios,documentos,de,beneficios',
#  'puente,de,datos,configurar,administrar,integraciones,entrantes,basadas,en,archivos',
#  'configure,recognition',
#  'ver,traducciones,proporcionadas,por,el,cliente',
#  'importar,traducciones,proporcionadas,por,el,cliente',
#  'buscar,trabajos',
#  'cambio,de,empleo,masivo',
#  'create,new,client,create,new,client',
#  'ver,la,entidades,legales,ver,la,lista,de,entidades,legales',
#  'tabaccesstestcase,testactionlink',
#  'administrar,la,ejecuciones,de,pago,procesar,los,datos,de,nómina,dentro,de,un,grupo,de,pago,para,un,período,de,pago,determinado,para,revisar,confirmar,la,ejecuciones,de,pago',
#  'administrar,contratación',
#  'ver,el,gráfico,de,trabajo,ver,el,gráfico,del,equipo',
#  'directorio,de,colaboradores,búsqueda,de,un,empleado',
#  'configure,recruiting',
#  'administrar,los,ajustes,de,trimestres,años,anteriores,gestione,sus,modificaciones,de,nómina,anteriores,actuales,para,los,estados,unidos,canadá',
#  'importar,valores,de,campo,fluido,importar,valores,para,campos,fluidos,en,masa,utilizando,una,plantilla',
#  'google',
#  'lista,de,almacenamiento,provisional,de,importación,de,entrada,de,servicios,básicos,de,rr,hh',
#  'ver,familias,de,trabajo,ver,la,lista,de,familias,de,trabajo',
#  'herramientas,del,centro,de,integración',
#  'ver,unidades,empresariales',
#  'go,bvcore',
#  'view,time,report,view,incoming,outgoing,time,report',
#  'tenant,management']

# %% [markdown]
# ### Extract Corpus

# %%
from collections import Counter
import pandas as pd

words = ','.join(processed_tokens)
w = words.split(',')

most_common_keywords = Counter(w).most_common(100)
sorted_keywords = sorted(most_common_keywords, key=lambda x: x[0])
top_keywords = pd.DataFrame(sorted_keywords, columns=['keyword', 'count'])
display(top_keywords)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>keyword</th><th>count</th></tr></thead><tbody><tr><td>action</td><td>9</td></tr><tr><td>add</td><td>14</td></tr><tr><td>administrar</td><td>27</td></tr><tr><td>adp</td><td>12</td></tr><tr><td>afficher</td><td>26</td></tr><tr><td>agregar</td><td>7</td></tr><tr><td>ajouter</td><td>7</td></tr><tr><td>approval</td><td>9</td></tr><tr><td>associate</td><td>38</td></tr><tr><td>at</td><td>7</td></tr><tr><td>avantages</td><td>7</td></tr><tr><td>beneficios</td><td>11</td></tr><tr><td>benefit</td><td>15</td></tr><tr><td>bord</td><td>13</td></tr><tr><td>bulk</td><td>7</td></tr><tr><td>chart</td><td>7</td></tr><tr><td>client</td><td>13</td></tr><tr><td>company</td><td>13</td></tr><tr><td>compensation</td><td>9</td></tr><tr><td>configurar</td><td>17</td></tr><tr><td>configuration</td><td>8</td></tr><tr><td>configure</td><td>40</td></tr><tr><td>cornerstone</td><td>12</td></tr><tr><td>create</td><td>20</td></tr><tr><td>dashboard</td><td>29</td></tr><tr><td>data</td><td>24</td></tr><tr><td>datos</td><td>16</td></tr><tr><td>de</td><td>242</td></tr><tr><td>del</td><td>12</td></tr><tr><td>disciplinary</td><td>8</td></tr><tr><td>document</td><td>14</td></tr><tr><td>données</td><td>11</td></tr><tr><td>du</td><td>8</td></tr><tr><td>dynamic</td><td>7</td></tr><tr><td>edit</td><td>18</td></tr><tr><td>editar</td><td>9</td></tr><tr><td>el</td><td>10</td></tr><tr><td>employee</td><td>7</td></tr><tr><td>employés</td><td>8</td></tr><tr><td>en</td><td>8</td></tr><tr><td>entity</td><td>7</td></tr><tr><td>et</td><td>31</td></tr><tr><td>field</td><td>8</td></tr><tr><td>group</td><td>10</td></tr><tr><td>grupo</td><td>8</td></tr><tr><td>gérer</td><td>23</td></tr><tr><td>hire</td><td>10</td></tr><tr><td>hr</td><td>8</td></tr><tr><td>import</td><td>18</td></tr><tr><td>importar</td><td>10</td></tr><tr><td>incident</td><td>7</td></tr><tr><td>integration</td><td>14</td></tr><tr><td>job</td><td>8</td></tr><tr><td>l</td><td>12</td></tr><tr><td>la</td><td>44</td></tr><tr><td>le</td><td>63</td></tr><tr><td>legal</td><td>8</td></tr><tr><td>list</td><td>11</td></tr><tr><td>lista</td><td>8</td></tr><tr><td>los</td><td>35</td></tr><tr><td>manage</td><td>116</td></tr><tr><td>management</td><td>19</td></tr><tr><td>me</td><td>7</td></tr><tr><td>mi</td><td>7</td></tr><tr><td>modifier</td><td>13</td></tr><tr><td>mon</td><td>8</td></tr><tr><td>new</td><td>13</td></tr><tr><td>pago</td><td>15</td></tr><tr><td>paie</td><td>8</td></tr><tr><td>para</td><td>14</td></tr><tr><td>pay</td><td>32</td></tr><tr><td>payroll</td><td>17</td></tr><tr><td>performance</td><td>10</td></tr><tr><td>policy</td><td>7</td></tr><tr><td>position</td><td>10</td></tr><tr><td>pour</td><td>11</td></tr><tr><td>profile</td><td>13</td></tr><tr><td>rapport</td><td>7</td></tr><tr><td>record</td><td>9</td></tr><tr><td>report</td><td>20</td></tr><tr><td>request</td><td>12</td></tr><tr><td>setting</td><td>9</td></tr><tr><td>sie</td><td>16</td></tr><tr><td>su</td><td>7</td></tr><tr><td>tableau</td><td>15</td></tr><tr><td>team</td><td>23</td></tr><tr><td>time</td><td>28</td></tr><tr><td>trabajo</td><td>11</td></tr><tr><td>type</td><td>7</td></tr><tr><td>un</td><td>17</td></tr><tr><td>und</td><td>12</td></tr><tr><td>user</td><td>11</td></tr><tr><td>ver</td><td>23</td></tr><tr><td>verwalten</td><td>10</td></tr><tr><td>view</td><td>129</td></tr><tr><td>vos</td><td>10</td></tr><tr><td>votre</td><td>16</td></tr><tr><td>work</td><td>10</td></tr><tr><td>à</td><td>12</td></tr><tr><td>और</td><td>8</td></tr></tbody></table></div>
# Databricks visualization. Run in Databricks to view.

# %% [markdown]
# ### Extract Keywords by Frequency

# %%
passages = processed_tokens

# %%
print(f"--{passages[0]}\n--{passages[1]}")
# Out:
# --view,associate,profile
# --manage,benefit,supplemental,field,view,manage,associate,benefit,related,supplemental,eligibility,compliance,value

# %%
# !pip install rank_bm25
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Collecting rank_bm25
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/2a/21/f691fb2613100a62b3fa91e9988c991e9ca5b89ea31c0d3152a3210344f9/rank_bm25-0.2.2-py3-none-any.whl (8.6 kB)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.11/site-packages (from rank_bm25) (1.23.5)
# Installing collected packages: rank_bm25
# Successfully installed rank_bm25-0.2.2
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from rank_bm25 import BM25Okapi


def bm25_tokenizer(text):
    tokenized_doc = []
    for token in text.split(','):
        token = token.strip(string.punctuation)
        if len(token) > 0:
            tokenized_doc.append(token)
    return tokenized_doc

tokenized_corpus = []
for passage in passages:
    tokenized_corpus.append(bm25_tokenizer(passage))

# #Create a BM25 index from the tokenized document corpus
bm25 = BM25Okapi(tokenized_corpus)

# %%
import numpy as np


def search(query, top_k=3, num_candidates=100):
    print("Input question:", query)

    ##### BM25 search (lexical search) #####
    bm25_scores = bm25.get_scores(bm25_tokenizer(query))
    top_n = np.argpartition(bm25_scores, -num_candidates)[-num_candidates:]
    bm25_hits = [{'corpus_id': idx, 'score': bm25_scores[idx]} for idx in top_n]
    bm25_hits = sorted(bm25_hits, key=lambda x: x['score'], reverse=True)
    
    print(f"\nTop-3 lexical search (BM25) hits")
    print("-----------------------------------")

    for hit in bm25_hits[0:top_k]:
        print("\t{:.3f}\t{}".format(hit['score'],passages[hit['corpus_id']].replace("\n", " ")))

    # #Add re-ranking
    # docs = [passages[hit['corpus_id']] for hit in bm25_hits]
    # print(f"\nTop-3 hits by rank-API ({len(bm25_hits)} BM25 hits re-ranked)")
    # print("-------------------------------------------------")
    # results = co.rerank(query=query,documents=docs, top_n=top_k)
    
    # for hit in results:
    #     hit.index+=1
    #     print("\t{:.3f} was({})\t{}".format(hit.relevance_score, hit.index, hit.document["text"].replace("\n", " ")))

# %%
search("dashboard", top_k=3, num_candidates=100)
# Out:
# Input question: dashboard
#
# Top-3 lexical search (BM25) hits
# -----------------------------------
# 	4.771	view,hr,dashboard,hr,dashboard
# 	4.771	view,payroll,dashboard,payroll,dashboard
# 	4.566	registration,dashboard,dashboard,track,associate,registration

# %% [markdown]
# ### Extract Keywords

# %%
# Compute frequency distribution and get top K
keyword_chunks: List[str] = []
for tokens in processed_tokens:
    token_list = tokens.split(",")
    freq_dist = nltk.FreqDist(token_list)
    top_keywords = [word for word, _ in freq_dist.most_common(5)]
    keyword_chunks.append(",".join(top_keywords))
pdf_action['keywords'] = keyword_chunks
pdf_action.drop(['combined'], axis=1, inplace=True)

# %%
display(pdf_action)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>caption</th><th>subtitle</th><th>views</th><th>keywords</th></tr></thead><tbody><tr><td>119fb43320ab44c9847c9b2284f7e848</td><td>View My Associate Profile</td><td>View My Associate Profile</td><td>1298</td><td>view,associate,profile</td></tr><tr><td>d0adbfea7381492e976ec090d26777ba</td><td>Manage Benefits Supplemental Fields</td><td>View and Manage Associate's benefit related supplemental eligibility and compliance values.</td><td>1213</td><td>manage,benefit,supplemental,field,view</td></tr><tr><td>7843598ab66a41d28253f40b5e9a3c56</td><td>Manage Associate's Pay Profile</td><td>Maintain and capture Associate's pay data records within a legal entity and/or pay group.</td><td>1184</td><td>pay,associate,manage,profile,maintain</td></tr><tr><td>899c324e3f2742ce9cd9d27a97048cc5</td><td>View Company Org Chart</td><td>View Company Org Chart</td><td>1148</td><td>view,company,org,chart</td></tr><tr><td>0429ea12a5974851ab47620c9d7205c9</td><td>View Criteria Control Center</td><td>Setup and manage the search queries that give eligibility, approvals, authorizations and other apps the flexibility and power they need to evolve with your workforce.</td><td>1001</td><td>view,criterion,control,center,setup</td></tr><tr><td>df6e2b589b0d462ebcdfb01bae2106c3</td><td>Add My Personal Contacts</td><td>Add a contact to your profile</td><td>998</td><td>add,contact,personal,profile</td></tr><tr><td>846b123c190448f8a7b82f942d7609bd</td><td>View and Manage Associates' Benefits</td><td>Manage changes to associates' Benefits</td><td>993</td><td>manage,associate,benefit,view,change</td></tr><tr><td>2a1ec3581d634da888cc03ce2dd8d818</td><td>Benefits Data Management</td><td>View and edit benefits data, add new records, and download benefits reports for all associates.</td><td>965</td><td>benefit,data,management,view,edit</td></tr><tr><td>6aa709dc9ad44b7ea7e61424086e2415</td><td>View Your Pay</td><td>Access your pay details.</td><td>915</td><td>pay,view,access,detail</td></tr><tr><td>9925c8101c7b43e98eeb2c6539728764</td><td>Manage Payroll Company Data</td><td>Configure company pay data and maintain payroll settings within a legal entity and/or pay group.</td><td>881</td><td>payroll,company,data,pay,manage</td></tr><tr><td>50f79735cf8647e1902b132b8063e3ae</td><td>Edit My Personal Demographics</td><td>Edit your gender, race, nationality, marital status and other birth details</td><td>856</td><td>edit,personal,demographic,gender,race</td></tr><tr><td>229bbf0c07a449b08fd7731656cee98e</td><td>Create Criteria</td><td>Create a new search query for an app or domain.</td><td>768</td><td>create,criterion,new,search,query</td></tr><tr><td>b3cc3ceac4d24c2e843aa13078bd2f8e</td><td>Hiring Dashboard</td><td>Navigate to the new hire dashboard to start a hire.</td><td>704</td><td>dashboard,hire,hiring,navigate,new</td></tr><tr><td>4766e323575849acb389a0ba42353f89</td><td>Work Authorization Type Configuration</td><td>Manage work visas, permits and other documents</td><td>702</td><td>work,authorization,type,configuration,manage</td></tr><tr><td>6152f780beef4fb3806ba3f43d3f88cb</td><td>Manage Licenses & Certifications</td><td>Manage the Library of Licenses and Certifications</td><td>697</td><td>manage,license,certification,library</td></tr><tr><td>61879fc535b74accb21081bda19bdd92</td><td>User Management Troubleshooting</td><td>Access CRUD pages for user registration, product access, passwords/usernames and more.</td><td>696</td><td>user,access,management,troubleshooting,crud</td></tr><tr><td>ff3b3f8391b7490c95f3c0c693327aa5</td><td>Reports & Analytics</td><td>Run, create and manage reports and analytics with benchmarks</td><td>680</td><td>report,analytics,run,create,manage</td></tr><tr><td>51ad5ab7fdeb47e380a43e00359373d4</td><td>View My Org</td><td>View your direct reports, peers, and managers.</td><td>677</td><td>view,org,direct,report,peer</td></tr>< ...

# %%
import numpy as np

def search(query, top_k=3, num_candidates=100):
    print("Input question:", query)
    ##### BM25 search (lexical search) #####
    bm25_scores = bm25.get_scores(query)
    print(bm25_scores)
    top_n = np.argpartition(bm25_scores, -num_candidates)[-num_candidates:]
    bm25_hits = [{'corpus_id': idx, 'score': bm25_scores[idx]} for idx in top_n]
    bm25_hits = sorted(bm25_hits, key=lambda x: x['score'], reverse=True)
    print(f"\nTop-3 lexical search (BM25) hits")
    print("-----------------------------------")
    for hit in bm25_hits[0:top_k]:
        print("\t{:.3f}\t{}".format(hit['score'], processed_tokens[hit['corpus_id']].replace("\n", " ")))

# %% [markdown]
# ### Top 3 Query with Clicks

# %%
ml_catalog = "onedata_us_east_1_shared_dit"
ml_search_db = "nas_raw_lyric_search_dit"

df_action = spark.sql(f"""
with click as (
    select request_correlation_id,
        _token_session_id, 
        _token_associate_id, 
        object_id, 
        time_stamp, 
        label, 
        client_id, 
        category, 
        details_caption 
    from {ml_catalog}.{ml_search_db}.ml_search_click 
    where request_correlation_id is not null and lower(request_correlation_id) != 'nan'
),

search_click as (
        select search.request_correlation_id,
        search._token_client_id as client_id,
        search.label AS query,
        search.resPos,
        search.traceId,
        search.caption,
        search.subtitle,
        search.solrScore,
        search.finalScore,
        rank() over (partition by search.request_correlation_id, search.resPos, search.traceId order by click.time_stamp) as rank,
        1 AS click_count,
        click._token_session_id as click_session_id, 
        click._token_associate_id as click_associate_id, 
        click.object_id as click_object_id, 
        click.time_stamp as click_time_stamp, 
        click.label as click_label, 
        click.client_id as click_client_id, 
        click.category as click_category, 
        click.details_caption as click_details_caption
    from {ml_catalog}.{ml_search_db}.ml_search_action search
    inner join click
    on search.request_correlation_id = click.request_correlation_id
    and search._id = click.object_id
),

click_aggregation AS (
    SELECT query,
           caption,
           subtitle,
           sum(click_count) AS total_clicks,
           DENSE_RANK() OVER (PARTITION BY query ORDER BY sum(click_count) DESC) AS action_rank
    FROM search_click
    WHERE rank = 1
    GROUP BY query, caption, subtitle
),

ranked_clicks AS (
    SELECT query,
           caption,
           subtitle,
           total_clicks,
           action_rank,
           max(action_rank) over (PARTITION BY query) AS max_action_rank
    FROM click_aggregation
)

SELECT query,
       caption,
       subtitle,
       total_clicks,
       action_rank,
       max_action_rank
FROM ranked_clicks
WHERE max_action_rank >= 3
AND action_rank <= 3
ORDER BY query, action_rank
""")

# %%
display(df_action)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-4886578537347935>, line 1
# ----> 1 display(df_action)
#
# NameError: name 'df_action' is not defined
