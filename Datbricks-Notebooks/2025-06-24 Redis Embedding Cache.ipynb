# %%
# !pip uninstall --yes redis
# !pip uninstall --yes redisvl
# !pip uninstall --yes pydantic
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Menlo", "Monaco", "Consolas", "Ubuntu Mono", "Source Code Pro", monospace;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>

# %%
# %pip install redis redisvl

# %pip install redis==6.2.0 redisvl>=0.7.0
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Collecting redis==6.2.0
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/13/67/e60968d3b0e077495a8fee89cf3f2373db98e528288a48f1ee44967f6e8c/redis-6.2.0-py3-none-any.whl (278 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/278.7 kB ? eta -:--:--
#      ━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.7/278.7 kB 2.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 276.5/278.7 kB 4.2 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.7/278.7 kB 3.9 MB/s eta 0:00:00
# Collecting redisvl>=0.7.0
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/ea/74/484d1adefe84ab4eb3cd77bb6aa5dc7a1d3920bb0d5ca281bcceedf89ad4/redisvl-0.8.0-py3-none-any.whl (152 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/152.3 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.3/152.3 kB 5.3 MB/s eta 0:00:00
# Collecting jsonpath-ng>=1.5.0 (from redisvl>=0.7.0)
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/35/5a/73ecb3d82f8615f32ccdadeb9356726d6cae3a4bbc840b437ceb95708063/jsonpath_ng-1.7.0-py3-none-any.whl (30 kB)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from redisvl>=0.7.0) (0.4.1)
# Requirement already satisfied: numpy<3,>=1.26.0 in /databricks/python3/lib/python3.12/site-packages (from redisvl>=0.7.0) (1.26.4)
# Requirement already satisfied: pydantic<3,>=2 in /databricks/python3/lib/python3.12/site-packages (from redisvl>=0.7.0) (2.8.2)
# Collecting python-ulid>=3.0.0 (from redisvl>=0.7.0)
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/63/4e/cc2ba2c0df2589f35a4db8473b8c2ba9bbfc4acdec4a94f1c78934d2350f/python_ulid-3.0.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: pyyaml<7.0,>=5.4 in /databricks/python3/lib/python3.12/site-packages (from redisvl>=0.7.0) (6.0.1)
# Requirement already satisfied: tenacity>=8.2.2 in /databricks/python3/lib/python3.12/site-packages (from redisvl>=0.7.0) (8.2.2)
# Collecting ply (from jsonpath-ng>=1.5.0->redisvl>=0.7.0)
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/a3/58/35da89ee790598a0700ea49b2a66594140f44dec458c07e8e3d4979137fc/ply-3.11-py2.py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/49.6 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.6/49.6 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: annotated-types>=0.4.0 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2->redisvl>=0.7.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2->redisvl>=0.7.0) (2.20.1)
# Requirement already satisfied: typing-extensions>=4.6.1 in /databricks/python3/lib/python3.12/site-packages (from pydantic<3,>=2->redisvl>=0.7.0) (4.11.0)
# Installing collected packages: ply, redis, python-ulid, jsonpath-ng, redisvl
# Successfully installed jsonpath-ng-1.7.0 ply-3.11 python-ulid-3.0.0 redis-6.2.0 redisvl-0.8.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# dbutils.library.restartPython()  # Ensure the kernel is active before calling this

# %%
ml_catalog = "onedata_us_east_1_shared_dit"
ml_search_db = "nas_raw_lyric_search_dit"

# df_action = spark.sql(f"""
#     SELECT 
#     client_id, 
#     _id, caption, subtitle, count(*) AS views
#     FROM {ml_catalog}.{ml_search_db}.ml_search_action
#     WHERE context='US'
#     GROUP BY 1, 2, 3, 4
#     ORDER BY 4 DESC
# """)

df_action = spark.sql(f"""
    SELECT 
    _id, caption, subtitle, count(*) AS views
    FROM {ml_catalog}.{ml_search_db}.ml_search_action
    WHERE context='US'
    GROUP BY 1, 2, 3
    ORDER BY 4 DESC
""")

# %%
display(df_action)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>caption</th><th>subtitle</th><th>views</th></tr></thead><tbody><tr><td>92e3eae6ab5e4f8cab69c0c0b87eb7c1</td><td>Manage Pay Runs</td><td>Process payroll data within a pay group for a given pay period and to review and commit Pay Runs.</td><td>754</td></tr><tr><td>7843598ab66a41d28253f40b5e9a3c56</td><td>Manage Associate's Pay Profile</td><td>Maintain and capture Associate's pay data records within a legal entity and/or pay group.</td><td>591</td></tr><tr><td>119fb43320ab44c9847c9b2284f7e848</td><td>View My Associate Profile</td><td>View My Associate Profile</td><td>570</td></tr><tr><td>d0adbfea7381492e976ec090d26777ba</td><td>Manage Benefits Supplemental Fields</td><td>View and Manage Associate's benefit related supplemental eligibility and compliance values.</td><td>465</td></tr><tr><td>9925c8101c7b43e98eeb2c6539728764</td><td>Manage Payroll Company Data</td><td>Configure company pay data and maintain payroll settings within a legal entity and/or pay group.</td><td>457</td></tr><tr><td>0429ea12a5974851ab47620c9d7205c9</td><td>View Criteria Control Center</td><td>Setup and manage the search queries that give eligibility, approvals, authorizations and other apps the flexibility and power they need to evolve with your workforce.</td><td>445</td></tr><tr><td>df6e2b589b0d462ebcdfb01bae2106c3</td><td>Add My Personal Contacts</td><td>Add a contact to your profile</td><td>445</td></tr><tr><td>846b123c190448f8a7b82f942d7609bd</td><td>View and Manage Associates' Benefits</td><td>Manage changes to associates' Benefits</td><td>436</td></tr><tr><td>6aa709dc9ad44b7ea7e61424086e2415</td><td>View Your Pay</td><td>Access your pay details.</td><td>411</td></tr><tr><td>855c3abcdde94c4b8c1c6c46b98d3bf3</td><td>View Your Benefits</td><td>View Your Benefits</td><td>397</td></tr><tr><td>899c324e3f2742ce9cd9d27a97048cc5</td><td>View Company Org Chart</td><td>View Company Org Chart</td><td>389</td></tr><tr><td>dcfb1c00f6414037935ad05e2c69d10c</td><td>View My Time Off</td><td>Time Off</td><td>322</td></tr><tr><td>3a59d8daae5147c389cdaaffbcad7d64</td><td>Manage Authorizations</td><td>Manage permissions for users and apps.</td><td>317</td></tr><tr><td>50f79735cf8647e1902b132b8063e3ae</td><td>Edit My Personal Demographics</td><td>Edit your gender, race, nationality, marital status and other birth details</td><td>304</td></tr><tr><td>2a1ec3581d634da888cc03ce2dd8d818</td><td>Benefits Data Management</td><td>View and edit benefits data, add new records, and download benefits reports for all associates.</td><td>302</td></tr><tr><td>d27d5dcf28b442e09b090540cf80f3cd</td><td>View and Manage Benefits</td><td>View and Manage all Benefits</td><td>294</td></tr><tr><td>ee544330568e4ff7bf2f305c06d2e695</td><td>Manage Hours and Earnings</td><td>View and manage your company’s hours and earnings.</td><td>270</td></tr><tr><td>8e4afe543af047828adfc0a4fc19eb25</td><td>Approval Management Dashboard</td><td>View and manage approval requests</td><td>261</td></tr><tr><td>6152f780beef4fb3806ba3f43d3f88cb</td><td>Manage Licenses & Certifications</td><td>Manage the Library of Licenses and Certifications</td><td>254</td></tr><tr><td>f9f9329010a5420aa998fd61892f7100</td><td>View and Approve Team Time Off</td><td>View and approve team time off</td><td>252</td></tr><tr><td>51ad5ab7fdeb47e380a43e00359373d4</td><td>View My Org</td><td>View your direct reports, peers, and managers.</td><td>250</td></tr><tr><td>61879fc535b74accb21081bda19bdd92</td><td>User Management Troubleshooting</td><td>Access CRUD pages for user registration, product access, passwords/usernames and more.</td><td>248</td></tr><tr><td>6afa39d14e934381be22f819df8377e4</td><td>Bulk Leave of Absence</td><td>Update associates to/from leave of absence status in bulk.</td><td>245</td></tr><tr><td>9ca43b27a0ed48d699f0e126a9dcbe14</td><td>View Time Dashboard</td><td>Navigate to the Time Dashboard t ...

# %% [markdown]
# ### LLM Embedding

# %%
from pathlib import Path
parent_path = Path.cwd().resolve()
cert_path = parent_path / "utils/ADP_Internal_Root_CA_GN2.pem"
print(cert_path)
# Out:
# /Workspace/Users/ling.huang@adp.com/utils/ADP_Internal_Root_CA_GN2.pem

# %%
# %pip install openai
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: openai in /databricks/python3/lib/python3.11/site-packages (1.35.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /databricks/python3/lib/python3.11/site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /databricks/python3/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /databricks/python3/lib/python3.11/site-packages (from openai) (1.10.6)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.11/site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /databricks/python3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /databricks/python3/lib/python3.11/site-packages (from openai) (4.10.0)
# Requirement already satisfied: idna>=2.8 in /databricks/python3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from pyspark.sql.functions import concat_ws

df_action = df_action.withColumn(
    "combined", 
    concat_ws(" | ", df_action["caption"], df_action["subtitle"])
)
df = df_action.select("combined").dropDuplicates()

pdf = df.sample(fraction=0.1).toPandas()
pdf = df.sample(fraction=0.1).toPandas()
pdf = df_action.toPandas()
# Out:
# 21:09:54 py4j.clientserver INFO   Received command c on object id p0
# 21:09:55 py4j.clientserver INFO   Received command c on object id p0
# 21:09:55 py4j.clientserver INFO   Received command c on object id p0
# 21:09:56 py4j.clientserver INFO   Received command c on object id p0
# 21:09:57 py4j.clientserver INFO   Received command c on object id p0
# 21:09:57 py4j.clientserver INFO   Received command c on object id p0

# %%
import time
from utils.data_profiling import get_openai_embedding

embed_start_time = time.time()

pdf["embedding"] = pdf.combined.apply(lambda x: get_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z", x))

embed_time = time.time() - embed_start_time
print(f"Embedding took {embed_time} seconds")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Embedding took 634.2383530139923 seconds
# [Trace(request_id=tr-1d168d83387941589c3b804f3059da3a), Trace(request_id=tr-b13218db16ef4f79a88c7edc60583a88), Trace(request_id=tr-939981b7aaae4bdc94a1b1a3e9cdfe12), Trace(request_id=tr-84b53055882543f6b6d3e5a1e30203d2), Trace(request_id=tr-2666dd221d6340868ce32765cbbe5695), Trace(request_id=tr-ebad5f38f35242de8dbdeba9b84c2df0), Trace(request_id=tr-cc63718a592d47e881e65ccd2f8399ac), Trace(request_id=tr-1f9943b0747148ad9eb8bedce29d406c), Trace(request_id=tr-fe444e3510ae437f9773c00b0a8cead4), Trace(request_id=tr-4cc04687191440259070fe14bd64dae2)]

# %%
len(pdf)
# Out:
# 442

# %%
len(pdf['embedding'][0])
# Out:
# 3072

# %%
pdf
# Out:
#                                       _id  ...                                          embedding
# 0        92e3eae6ab5e4f8cab69c0c0b87eb7c1  ...  [-0.024025030434131622, 0.013467968441545963, ...
# 1        7843598ab66a41d28253f40b5e9a3c56  ...  [-0.004524508025497198, -0.004205494187772274,...
# 2        119fb43320ab44c9847c9b2284f7e848  ...  [0.013958286494016647, -0.016372742131352425, ...
# 3        d0adbfea7381492e976ec090d26777ba  ...  [0.01579403504729271, -0.01657865010201931, -0...
# 4        9925c8101c7b43e98eeb2c6539728764  ...  [-7.250589987961575e-05, 0.008863282389938831,...
# ..                                    ...  ...                                                ...
# 437      ab150121f3bb4406acb5dc6a49c7fd2d  ...  [0.005336832720786333, 0.01653945818543434, -0...
# 438      6ba0b72c0d3e426eb55f7cdf9d961b8e  ...  [0.002766735153272748, -0.002150274347513914, ...
# 439      60c2dd26439a47a09c01ef205baec43d  ...  [-0.02239520661532879, 0.01600535400211811, -0...
# 440  9353234d-272c-4f7c-bca9-b9c60f5952e3  ...  [-0.0032243847381323576, -0.024755246937274933...
# 441      cead43da873f498a91725ada14b40524  ...  [-0.034592535346746445, 0.011076066642999649, ...
#
# [442 rows x 6 columns]

# %%
# import numpy as np

# pdf['embedding'] = pdf['embedding'].apply(lambda x: np.array(x).astype(np.float32).tobytes())

# %%
pdf.to_csv("data/df_action_embedding.csv", index=False)

# %% [markdown]
# ### Caching Embeddings

# %%
import pandas as pd

pdf = pd.read_csv("data/df_action_embedding.csv")
# Out:
# 21:10:12 py4j.clientserver INFO   Received command c on object id p0

# %%
import ast
import numpy as np

# Convert string representation of list to np.float32 array, then to bytes
pdf['embedding'] = pdf['embedding'].apply(lambda x: np.array(ast.literal_eval(x), dtype=np.float32).tobytes())
# Out:
# 21:10:16 py4j.clientserver INFO   Received command c on object id p0
# 21:10:17 py4j.clientserver INFO   Received command c on object id p0
# 21:10:18 py4j.clientserver INFO   Received command c on object id p0
# 21:10:19 py4j.clientserver INFO   Received command c on object id p0
# 21:10:20 py4j.clientserver INFO   Received command c on object id p0

# %%
pdf.iloc[0]
# Out:
# _id                           92e3eae6ab5e4f8cab69c0c0b87eb7c1
# caption                                        Manage Pay Runs
# subtitle     Process payroll data within a pay group for a ...
# views                                                      754
# combined     Manage Pay Runs | Process payroll data within ...
# embedding    b'$\xd0\xc4\xbc\xc1\xa8\\<\xad@\x9d\xbc<et<s\x...
# Name: 0, dtype: object

# %% [markdown]
# ### Set up Redis

# %%
import os
import redis

# Redis connection params
REDIS_HOST = 'search01d.us.caas.oneadp.com'
REDIS_PORT = 443
REDIS_PASSWORD = '***'

# Create Redis client
redis_client = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True, 
  ssl_cert_reqs="none", 
  ssl=True)
# Test connection
redis_client.ping()
# Out:
# True
# 21:11:01 py4j.clientserver INFO   Received command c on object id p0

# %%
# redis_client.flushall()

# %%
redis_client.dbsize()
# Out:
# 442

# %%
redis_client.dbsize()
# Out:
# 442

# %% [markdown]
# ### Initializing the EmbeddingsCache

# %%
from redisvl.extensions.cache.embeddings import EmbeddingsCache
# Out:
# /databricks/python/lib/python3.12/site-packages/pydantic/_internal/_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
cache = EmbeddingsCache(
    name="embedcache",                  # name prefix for Redis keys
    redis_client=redis_client,  # Redis connection URL
    ttl=None                            # Optional TTL in seconds (None means no expiration)
)
# Out:
# 20:58:36 py4j.clientserver INFO   Received command c on object id p0

# %%
import time
from utils.data_profiling import get_openai_embedding

# Text to embed
text = "What is machine learning?"
model_name = "redis/langcache-embed-v1"

# Generate the embedding
embedding = get_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z", text)

# Optional metadata
metadata = {"category": "ai", "source": "user_query"}

# Store in cache
key = cache.set(
    text=text,
    model_name=model_name,
    embedding=embedding,
    metadata=metadata
)

print(f"Stored with key: {key[:15]}...")
# Out:
# Received Bearer token
# 20:58:45 py4j.clientserver INFO   Received command c on object id p0
# 20:58:45 httpx INFO   HTTP Request: POST https://aigateway-amrs-nonprod.oneadp.com/v0/r0/openai/deployments/text-embedding-3-large_1-pgo-amrs/embeddings?api-version=2024-06-01 "HTTP/1.1 200 OK"
# 20:58:46 py4j.clientserver INFO   Received command c on object id p0
# Stored with key: embedcache:909f...
# Trace(request_id=tr-bd94a56f772a48ff9e138006f8ec195a)

# %% [markdown]
# ### Retrieving Embeddings

# %%
if result := cache.get(text=text, model_name=model_name):
    print(f"Found in cache: {result['text']}")
    print(f"Model: {result['model_name']}")
    print(f"Metadata: {result['metadata']}")
    print(f"Embedding shape: {np.array(result['embedding']).shape}")
else:
    print("Not found in cache.")
# Out:
# Found in cache: What is machine learning?
# Model: redis/langcache-embed-v1
# Metadata: {'category': 'ai', 'source': 'user_query'}
# Embedding shape: (3072,)

# %%
# Check if existing text is in cache
exists = cache.exists(text=text, model_name=model_name)
print(f"First query exists in cache: {exists}")

# Check if a new text is in cache
new_text = "What is deep learning?"
exists = cache.exists(text=new_text, model_name=model_name)
print(f"New query exists in cache: {exists}")
# Out:
# First query exists in cache: True
# New query exists in cache: False

# %% [markdown]
# ### Advanced Usage

# %%
# Store an entry again
key = cache.set(
    text=text,
    model_name=model_name,
    embedding=embedding,
    metadata=metadata
)
print(f"Stored with key: {key[:15]}...")

# Check existence by key
exists_by_key = cache.exists_by_key(key)
print(f"Exists by key: {exists_by_key}")

# Retrieve by key
result_by_key = cache.get_by_key(key)
print(f"Retrieved by key: {result_by_key['text']}")

# Drop by key
cache.drop_by_key(key)
# Out:
# Stored with key: embedcache:909f...
# Exists by key: True
# Retrieved by key: What is machine learning?

# %% [markdown]
# ### Batch Operation

# %%
# Create multiple embeddings
texts = [
    "What is machine learning?",
    "How do neural networks work?",
    "What is deep learning?"
]
embeddings = [get_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z",t) for t in texts]

# Prepare batch items as dictionaries
batch_items = [
    {
        "text": texts[0],
        "model_name": model_name,
        "embedding": embeddings[0],
        "metadata": {"category": "ai", "type": "question"}
    },
    {
        "text": texts[1],
        "model_name": model_name,
        "embedding": embeddings[1],
        "metadata": {"category": "ai", "type": "question"}
    },
    {
        "text": texts[2],
        "model_name": model_name,
        "embedding": embeddings[2],
        "metadata": {"category": "ai", "type": "question"}
    }
]

# Store multiple embeddings in one operation
keys = cache.mset(batch_items)
print(f"Stored {len(keys)} embeddings with batch operation")

# Check if multiple embeddings exist in one operation
exist_results = cache.mexists(texts, model_name)
print(f"All embeddings exist: {all(exist_results)}")

# Retrieve multiple embeddings in one operation
results = cache.mget(texts, model_name)
print(f"Retrieved {len(results)} embeddings in one operation")

# Delete multiple embeddings in one operation
cache.mdrop(texts, model_name)

# Alternative: key-based batch operations
# cache.mget_by_keys(keys)     # Retrieve by keys
# cache.mexists_by_keys(keys)  # Check existence by keys
# cache.mdrop_by_keys(keys)    # Delete by keys
# Out:
# 21:21:09 py4j.clientserver INFO   Received command c on object id p0
# Received Bearer token
# 21:21:10 httpx INFO   HTTP Request: POST https://aigateway-amrs-nonprod.oneadp.com/v0/r0/openai/deployments/text-embedding-3-large_1-pgo-amrs/embeddings?api-version=2024-06-01 "HTTP/1.1 200 OK"
# 21:21:10 py4j.clientserver INFO   Received command c on object id p0
# Received Bearer token
# 21:21:11 py4j.clientserver INFO   Received command c on object id p0
# 21:21:11 httpx INFO   HTTP Request: POST https://aigateway-amrs-nonprod.oneadp.com/v0/r0/openai/deployments/text-embedding-3-large_1-pgo-amrs/embeddings?api-version=2024-06-01 "HTTP/1.1 200 OK"
# Received Bearer token
# 21:21:12 py4j.clientserver INFO   Received command c on object id p0
# 21:21:12 httpx INFO   HTTP Request: POST https://aigateway-amrs-nonprod.oneadp.com/v0/r0/openai/deployments/text-embedding-3-large_1-pgo-amrs/embeddings?api-version=2024-06-01 "HTTP/1.1 200 OK"
# Stored 3 embeddings with batch operation
# All embeddings exist: True
# Retrieved 3 embeddings in one operation
# [Trace(request_id=tr-e7c35278cf4d4823a38292cd85ee93a7), Trace(request_id=tr-323b2449cb5640ba83ff874e29f936fd), Trace(request_id=tr-9df7818799a3463fb7e0dc1f5253b089)]

# %% [markdown]
# ### Working with TTL (Time-To-LIve)

# %%
# Create a cache with a default 5-second TTL
ttl_cache = EmbeddingsCache(
    name="ttl_cache",
    redis_client=redis_client,
    ttl=5  # 5 second TTL
)

# Store an entry
key = ttl_cache.set(
    text=text,
    model_name=model_name,
    embedding=embedding
)

# Check if it exists
exists = ttl_cache.exists_by_key(key)
print(f"Immediately after setting: {exists}")

# Wait for it to expire
time.sleep(6)

# Check again
exists = ttl_cache.exists_by_key(key)
print(f"After waiting: {exists}")
# Out:
# Immediately after setting: True
# 21:25:53 py4j.clientserver INFO   Received command c on object id p0
# 21:25:54 py4j.clientserver INFO   Received command c on object id p0
# 21:25:55 py4j.clientserver INFO   Received command c on object id p0
# 21:25:56 py4j.clientserver INFO   Received command c on object id p0
# 21:25:57 py4j.clientserver INFO   Received command c on object id p0
# 21:25:58 py4j.clientserver INFO   Received command c on object id p0
# After waiting: False

# %%
# Store an entry with a custom 1-second TTL
key1 = ttl_cache.set(
    text="Short-lived entry",
    model_name=model_name,
    embedding=embedding,
    ttl=1  # Override with 1 second TTL
)

# Store another entry with the default TTL (5 seconds)
key2 = ttl_cache.set(
    text="Default TTL entry",
    model_name=model_name,
    embedding=embedding
    # No TTL specified = uses the default 5 seconds
)

# Wait for 2 seconds
time.sleep(2)

# Check both entries
exists1 = ttl_cache.exists_by_key(key1)
exists2 = ttl_cache.exists_by_key(key2)

print(f"Entry with custom TTL after 2 seconds: {exists1}")
print(f"Entry with default TTL after 2 seconds: {exists2}")

# Cleanup
ttl_cache.drop_by_key(key2)
# Out:
# 21:26:17 py4j.clientserver INFO   Received command c on object id p0
# 21:26:18 py4j.clientserver INFO   Received command c on object id p0
# Entry with custom TTL after 2 seconds: False
# Entry with default TTL after 2 seconds: True

# %% [markdown]
# ### Async Support

# %%
async def async_cache_demo():
    # Store an entry asynchronously
    key = await cache.aset(
        text="Async embedding",
        model_name=model_name,
        embedding=embedding,
        metadata={"async": True}
    )
    
    # Check if it exists
    exists = await cache.aexists_by_key(key)
    print(f"Async set successful? {exists}")
    
    # Retrieve it
    result = await cache.aget_by_key(key)
    success = result is not None and result["text"] == "Async embedding"
    print(f"Async get successful? {success}")
    
    # Remove it
    await cache.adrop_by_key(key)

# Run the async demo
await async_cache_demo()
# Out:
# 21:27:06 py4j.clientserver INFO   Received command c on object id p0
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:1151, in ConnectionPool.get_available_connection(self)
#    1150 try:
# -> 1151     connection = self._available_connections.pop()
#    1152 except IndexError:
#
# IndexError: pop from empty list
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File <command-8251706527472130>, line 23
#      20     await cache.adrop_by_key(key)
#      22 # Run the async demo
# ---> 23 await async_cache_demo()
#
# File <command-8251706527472130>, line 3, in async_cache_demo()
#       1 async def async_cache_demo():
#       2     # Store an entry asynchronously
# ----> 3     key = await cache.aset(
#       4         text="Async embedding",
#       5         model_name=model_name,
#       6         embedding=embedding,
#       7         metadata={"async": True}
#       8     )
#      10     # Check if it exists
#      11     exists = await cache.aexists_by_key(key)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redisvl/extensions/cache/embeddings/embeddings.py:696, in EmbeddingsCache.aset(self, text, model_name, embedding, metadata, ttl)
#     694 # Store in Redis
#     695 client = await self._get_async_redis_client()
# --> 696 await client.hset(name=key, mapping=cache_entry)  # type: ignore
#     698 # Set TTL if specified
#     699 await self.aexpire(key, ttl)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/client.py:672, in Redis.execute_command(self, *args, **options)
#     670 pool = self.connection_pool
#     671 command_name = args[0]
# --> 672 conn = self.connection or await pool.get_connection()
#     674 if self.single_connection_client:
#     675     await self._single_conn_lock.acquire()
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:1139, in ConnectionPool.get_connection(self, command_name, *keys, **options)
#    1137 async with self._lock:
#    1138     """Get a connected connection from the pool"""
# -> 1139     connection = self.get_available_connection()
#    1140     try:
#    1141         await self.ensure_connection(connection)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:1155, in ConnectionPool.get_available_connection(self)
#    1153     if len(self._in_use_connections) >= self.max_connections:
#    1154         raise ConnectionError("Too many connections") from None
# -> 1155     connection = self.make_connection()
#    1156 self._in_use_connections.add(connection)
#    1157 return connection
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:1170, in ConnectionPool.make_connection(self)
#    1168 def make_connection(self):
#    1169     """Create a new connection.  Can be overridden by child classes."""
# -> 1170     return self.connection_class(**self.connection_kwargs)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:811, in SSLConnection.__init__(self, ssl_keyfile, ssl_certfile, ssl_cert_reqs, ssl_ca_certs, ssl_ca_data, ssl_check_hostname, ssl_min_version, ssl_ciphers, **kwargs)
#     799     raise RedisError("Python wasn't built with SSL support")
#     801 self.ssl_context: RedisSSLContext = RedisSSLContext(
#     802     keyfile=ssl_keyfile,
#     803     certfile=ssl_certfile,
#    (...)
#     809     ciphers=ssl_ciphers,
#     810 )
# --> 811 super().__init__(**kwargs)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-f6f30415-dfd1-4d4b-8e57-04cb09204464/lib/python3.12/site-packages/redis/asyncio/connection.py:741, in Connection.__init__(self, host, port, socket_keepalive, socket_keepalive_options, socket_type, **kwargs)
#     739 self.socket_keepalive_options = socket_keepalive_options or {}
#     740 self.socket_type = socket_type
# --> 741 super().__init__(**kwargs)
#
# TypeError: AbstractConnection.__init__() got an unexpected keyword argument 'ssl_password'

# %%
import numpy as np


data = [
    {
        'user': 'john',
        'age': 1,
        'job': 'engineer',
        'credit_score': 'high',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes()
    },
    {
        'user': 'mary',
        'age': 2,
        'job': 'doctor',
        'credit_score': 'low',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes()
    },
    {
        'user': 'joe',
        'age': 3,
        'job': 'dentist',
        'credit_score': 'medium',
        'user_embedding': np.array([0.9, 0.9, 0.1], dtype=np.float32).tobytes()
    }
]

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>job</th><th>user</th><th>user_embedding</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>engineer</td><td>john</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>2</td><td>low</td><td>doctor</td><td>mary</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>3</td><td>medium</td><td>dentist</td><td>joe</td><td>ZmZmP2ZmZj/NzMw9</td></tr></tbody></table></div>

# %%
import os
import redis

# Redis connection params
REDIS_HOST = 'search01d.us.caas.oneadp.com'
REDIS_PORT = 443
REDIS_PASSWORD = 'fZq7XT1c'

# Create Redis client
client = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True, 
  ssl_cert_reqs="none", 
  ssl=True)
# Test connection
client.ping()
# Out:
# True

# %%
schema = {
    "index": {
        "name": "user_simple",
        "prefix": "user_simple_docs",
    },
    "fields": [
        {"name": "user", "type": "tag"},
        {"name": "credit_score", "type": "tag"},
        {"name": "job", "type": "text"},
        {"name": "age", "type": "numeric"},
        {
            "name": "user_embedding",
            "type": "vector",
            "attrs": {
                "dims": 3,
                "distance_metric": "cosine",
                "algorithm": "flat",
                "datatype": "float32"
            }
        }
    ]
}

# %%
from redisvl.index import SearchIndex
from redis import Redis

index = SearchIndex.from_dict(schema, redis_client=client, validate_on_load=True)

# %%
index.create(overwrite=True)

# %%
# !rvl index listall
# Out:
# 02:10:22 py4j.clientserver INFO   Received command c on object id p0
# 02:10:23 py4j.clientserver INFO   Received command c on object id p0
# 02:10:24 py4j.clientserver INFO   Received command c on object id p0
# 02:10:25 py4j.clientserver INFO   Received command c on object id p0
# 02:10:26 py4j.clientserver INFO   Received command c on object id p0
# 02:10:27 py4j.clientserver INFO   Received command c on object id p0
# 02:10:28 py4j.clientserver INFO   Received command c on object id p0
# 02:10:29 py4j.clientserver INFO   Received command c on object id p0
# 02:10:30 py4j.clientserver INFO   Received command c on object id p0
# 02:10:31 py4j.clientserver INFO   Received command c on object id p0
# 02:10:32 py4j.clientserver INFO   Received command c on object id p0
# 02:10:33 py4j.clientserver INFO   Received command c on object id p0
# 02:10:34 py4j.clientserver INFO   Received command c on object id p0
# 02:10:35 py4j.clientserver INFO   Received command c on object id p0
# 02:10:36 py4j.clientserver INFO   Received command c on object id p0
# 02:10:37 py4j.clientserver INFO   Received command c on object id p0
# 02:10:38 py4j.clientserver INFO   Received command c on object id p0
# 02:10:39 py4j.clientserver INFO   Received command c on object id p0
# 02:10:40 py4j.clientserver INFO   Received command c on object id p0
# 02:10:41 py4j.clientserver INFO   Received command c on object id p0
# 02:10:42 py4j.clientserver INFO   Received command c on object id p0
# 02:10:43 py4j.clientserver INFO   Received command c on object id p0
# 02:10:44 py4j.clientserver INFO   Received command c on object id p0
# 02:10:45 py4j.clientserver INFO   Received command c on object id p0
# 02:10:46 py4j.clientserver INFO   Received command c on object id p0
# 02:10:47 py4j.clientserver INFO   Received command c on object id p0
# 02:10:48 py4j.clientserver INFO   Received command c on object id p0
# 02:10:49 py4j.clientserver INFO   Received command c on object id p0
# 02:10:50 py4j.clientserver INFO   Received command c on object id p0
# 02:10:51 py4j.clientserver INFO   Received command c on object id p0
# 02:10:52 py4j.clientserver INFO   Received command c on object id p0
# 02:10:53 py4j.clientserver INFO   Received command c on object id p0
# 02:10:54 py4j.clientserver INFO   Received command c on object id p0
# 02:10:55 py4j.clientserver INFO   Received command c on object id p0
# 02:10:56 py4j.clientserver INFO   Received command c on object id p0
# 02:10:57 py4j.clientserver INFO   Received command c on object id p0
# 02:10:58 py4j.clientserver INFO   Received command c on object id p0
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:473)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequest$1(Chauffeur.scala:911)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.$anonfun$applyOrElse$4(Chauffeur.scala:937)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:22)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:936)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:991)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:776)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:174)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:171)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:147)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:22)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:146)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:1033)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:953)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:548)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:513)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$13(ActivityContextFactory.scala:831)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:53)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$3(ActivityContextFactory.scala:831)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:794)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:776)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$15(ActivityContextFactory.scala:285)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:53)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:285)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:513)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:408)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:110)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:110)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:92)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
# !rvl index info -i user_simple
# Out:
# 02:11:07 py4j.clientserver INFO   Received command c on object id p0
# 02:11:08 py4j.clientserver INFO   Received command c on object id p0
# 02:11:09 py4j.clientserver INFO   Received command c on object id p0
# 02:11:10 py4j.clientserver INFO   Received command c on object id p0
# 02:11:11 py4j.clientserver INFO   Received command c on object id p0
# 02:11:12 py4j.clientserver INFO   Received command c on object id p0
# com.databricks.backend.common.rpc.CommandCancelledException
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$5(SequenceExecutionState.scala:132)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3(SequenceExecutionState.scala:132)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.$anonfun$cancel$3$adapted(SequenceExecutionState.scala:129)
# 	at scala.collection.immutable.Range.foreach(Range.scala:158)
# 	at com.databricks.spark.chauffeur.SequenceExecutionState.cancel(SequenceExecutionState.scala:129)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancelRunningSequence(ExecContextState.scala:715)
# 	at com.databricks.spark.chauffeur.ExecContextState.$anonfun$cancel$1(ExecContextState.scala:435)
# 	at scala.Option.getOrElse(Option.scala:189)
# 	at com.databricks.spark.chauffeur.ExecContextState.cancel(ExecContextState.scala:435)
# 	at com.databricks.spark.chauffeur.ExecutionContextManagerV1.cancelExecution(ExecutionContextManagerV1.scala:473)
# 	at com.databricks.spark.chauffeur.ChauffeurState.$anonfun$process$1(ChauffeurState.scala:750)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionContext(ChauffeurState.scala:84)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.spark.chauffeur.ChauffeurState.withAttributionTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperationWithResultTags(ChauffeurState.scala:84)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.spark.chauffeur.ChauffeurState.recordOperation(ChauffeurState.scala:84)
# 	at com.databricks.spark.chauffeur.ChauffeurState.process(ChauffeurState.scala:728)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequest$1(Chauffeur.scala:911)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.$anonfun$applyOrElse$4(Chauffeur.scala:937)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:22)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.handleDriverRequestWithUsageLogging$1(Chauffeur.scala:936)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:991)
# 	at com.databricks.spark.chauffeur.Chauffeur$$anon$1$$anonfun$receive$1.applyOrElse(Chauffeur.scala:776)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive0$2(ServerBackend.scala:174)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend$$anonfun$commonReceive$1.applyOrElse(ServerBackend.scala:200)
# 	at com.databricks.rpc.ServerBackend.internalReceive0(ServerBackend.scala:171)
# 	at com.databricks.rpc.ServerBackend.$anonfun$internalReceive$1(ServerBackend.scala:147)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperation$1(UsageLogging.scala:510)
# 	at com.databricks.logging.UsageLogging.executeThunkAndCaptureResultTags$1(UsageLogging.scala:616)
# 	at com.databricks.logging.UsageLogging.$anonfun$recordOperationWithResultTags$4(UsageLogging.scala:643)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.ServerBackend.withAttributionContext(ServerBackend.scala:22)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags(AttributionContextTracing.scala:96)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionTags$(AttributionContextTracing.scala:77)
# 	at com.databricks.rpc.ServerBackend.withAttributionTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags(UsageLogging.scala:611)
# 	at com.databricks.logging.UsageLogging.recordOperationWithResultTags$(UsageLogging.scala:519)
# 	at com.databricks.rpc.ServerBackend.recordOperationWithResultTags(ServerBackend.scala:22)
# 	at com.databricks.logging.UsageLogging.recordOperation(UsageLogging.scala:511)
# 	at com.databricks.logging.UsageLogging.recordOperation$(UsageLogging.scala:475)
# 	at com.databricks.rpc.ServerBackend.recordOperation(ServerBackend.scala:22)
# 	at com.databricks.rpc.ServerBackend.internalReceive(ServerBackend.scala:146)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRPC(JettyServer.scala:1033)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleRequestAndRespond(JettyServer.scala:953)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5(JettyServer.scala:548)
# 	at com.databricks.rpc.JettyServer$RequestManager.$anonfun$handleHttp$5$adapted(JettyServer.scala:513)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$13(ActivityContextFactory.scala:831)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:53)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withActivityInternal$3(ActivityContextFactory.scala:831)
# 	at com.databricks.context.integrity.IntegrityCheckContext$ThreadLocalStorage$.withValue(IntegrityCheckContext.scala:73)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:794)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withActivityInternal(ActivityContextFactory.scala:776)
# 	at com.databricks.logging.activity.ActivityContextFactory$.$anonfun$withServiceRequestActivity$15(ActivityContextFactory.scala:285)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withAttributionContext(ActivityContextFactory.scala:53)
# 	at com.databricks.logging.activity.ActivityContextFactory$.withServiceRequestActivity(ActivityContextFactory.scala:285)
# 	at com.databricks.rpc.JettyServer$RequestManager.handleHttp(JettyServer.scala:513)
# 	at com.databricks.rpc.JettyServer$RequestManager.doPost(JettyServer.scala:408)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:665)
# 	at com.databricks.rpc.HttpServletWithPatch.service(HttpServletWithPatch.scala:33)
# 	at javax.servlet.http.HttpServlet.service(HttpServlet.java:750)
# 	at org.eclipse.jetty.servlet.ServletHolder.handle(ServletHolder.java:799)
# 	at org.eclipse.jetty.servlet.ServletHandler.doHandle(ServletHandler.java:554)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.nextScope(ScopedHandler.java:190)
# 	at org.eclipse.jetty.servlet.ServletHandler.doScope(ServletHandler.java:505)
# 	at org.eclipse.jetty.server.handler.ScopedHandler.handle(ScopedHandler.java:141)
# 	at org.eclipse.jetty.server.handler.HandlerWrapper.handle(HandlerWrapper.java:127)
# 	at org.eclipse.jetty.server.Server.handle(Server.java:516)
# 	at org.eclipse.jetty.server.HttpChannel.lambda$handle$1(HttpChannel.java:487)
# 	at org.eclipse.jetty.server.HttpChannel.dispatch(HttpChannel.java:732)
# 	at org.eclipse.jetty.server.HttpChannel.handle(HttpChannel.java:479)
# 	at org.eclipse.jetty.server.HttpConnection.onFillable(HttpConnection.java:277)
# 	at org.eclipse.jetty.io.AbstractConnection$ReadCallback.succeeded(AbstractConnection.java:311)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ssl.SslConnection$DecryptedEndPoint.onFillable(SslConnection.java:555)
# 	at org.eclipse.jetty.io.ssl.SslConnection.onFillable(SslConnection.java:410)
# 	at org.eclipse.jetty.io.ssl.SslConnection$2.succeeded(SslConnection.java:164)
# 	at org.eclipse.jetty.io.FillInterest.fillable(FillInterest.java:105)
# 	at org.eclipse.jetty.io.ChannelEndPoint$1.run(ChannelEndPoint.java:104)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.runTask(EatWhatYouKill.java:338)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.doProduce(EatWhatYouKill.java:315)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.tryProduce(EatWhatYouKill.java:173)
# 	at org.eclipse.jetty.util.thread.strategy.EatWhatYouKill.run(EatWhatYouKill.java:131)
# 	at org.eclipse.jetty.util.thread.ReservedThreadExecutor$ReservedThread.run(ReservedThreadExecutor.java:409)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$2(InstrumentedQueuedThreadPool.scala:110)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.logging.AttributionContextTracing.$anonfun$withAttributionContext$1(AttributionContextTracing.scala:49)
# 	at com.databricks.logging.AttributionContext$.$anonfun$withValue$1(AttributionContext.scala:293)
# 	at scala.util.DynamicVariable.withValue(DynamicVariable.scala:62)
# 	at com.databricks.logging.AttributionContext$.withValue(AttributionContext.scala:289)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext(AttributionContextTracing.scala:47)
# 	at com.databricks.logging.AttributionContextTracing.withAttributionContext$(AttributionContextTracing.scala:44)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.withAttributionContext(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.$anonfun$run$1(InstrumentedQueuedThreadPool.scala:110)
# 	at scala.runtime.java8.JFunction0$mcV$sp.apply(JFunction0$mcV$sp.java:23)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads(QueuedThreadPoolInstrumenter.scala:132)
# 	at com.databricks.instrumentation.QueuedThreadPoolInstrumenter.trackActiveThreads$(QueuedThreadPoolInstrumenter.scala:129)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool.trackActiveThreads(InstrumentedQueuedThreadPool.scala:45)
# 	at com.databricks.rpc.InstrumentedQueuedThreadPool$$anon$1.run(InstrumentedQueuedThreadPool.scala:92)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool.runJob(QueuedThreadPool.java:883)
# 	at org.eclipse.jetty.util.thread.QueuedThreadPool$Runner.run(QueuedThreadPool.java:1034)
# 	at java.base/java.lang.Thread.run(Thread.java:840)

# %%
keys = index.load(data)

print(keys)
# Out:
# 02:11:25 py4j.clientserver INFO   Received command c on object id p0
# ['user_simple_docs:01JZS1M5B75W0B949SY81HKJRG', 'user_simple_docs:01JZS1M5BCRDZAVVP8H17NF5M7', 'user_simple_docs:01JZS1M5BD69CHXMH9YA7P49CZ']

# %%
try:
    keys = index.load([{"user_embedding": True}])
except Exception as e:
    print(str(e))
# Out:
# 02:12:59 redisvl.index.index ERROR   Data validation failed during load operation
# Schema validation failed for object at index 0. Field 'user_embedding' expects bytes (vector data), but got boolean value 'True'. If this should be a vector field, provide a list of numbers or bytes. If this should be a different field type, check your schema definition.
# Object data: {
#   "user_embedding": true
# }
# Hint: Check that your data types match the schema field definitions. Use index.schema.fields to view expected field types.

# %%
# Add more data
new_data = [{
    'user': 'tyler',
    'age': 9,
    'job': 'engineer',
    'credit_score': 'high',
    'user_embedding': np.array([0.1, 0.3, 0.5], dtype=np.float32).tobytes()
}]
keys = index.load(new_data)

print(keys)
# Out:
# ['user_simple_docs:01JZS1QMK2D8NB7Z7NVMRJ3XCZ']
# 02:13:19 py4j.clientserver INFO   Received command c on object id p0

# %%
from redisvl.query import VectorQuery

query = VectorQuery(
    vector=[0.1, 0.1, 0.5],
    vector_field_name="user_embedding",
    return_fields=["user", "age", "job", "credit_score", "vector_distance"],
    num_results=3
)

# %%
results = index.query(query)
print(results)
# Out:
# [{'id': 'user_simple_docs:01JZS1M5B75W0B949SY81HKJRG', 'vector_distance': '0', 'user': 'john', 'age': '1', 'job': 'engineer', 'credit_score': 'high'}, {'id': 'user_simple_docs:01JZS1M5BCRDZAVVP8H17NF5M7', 'vector_distance': '0', 'user': 'mary', 'age': '2', 'job': 'doctor', 'credit_score': 'low'}, {'id': 'user_simple_docs:01JZS1QMK2D8NB7Z7NVMRJ3XCZ', 'vector_distance': '0.0566298961639', 'user': 'tyler', 'age': '9', 'job': 'engineer', 'credit_score': 'high'}]

# %%
schema
# Out:
# {'index': {'name': 'user_simple', 'prefix': 'user_simple_docs'},
#  'fields': [{'name': 'user', 'type': 'tag'},
#   {'name': 'credit_score', 'type': 'tag'},
#   {'name': 'job', 'type': 'text'},
#   {'name': 'age', 'type': 'numeric'},
#   {'name': 'user_embedding',
#    'type': 'vector',
#    'attrs': {'dims': 3,
#     'distance_metric': 'cosine',
#     'algorithm': 'flat',
#     'datatype': 'float32'}}]}

# %% [markdown]
# ### Using an Asynchronous Redis Client

# %%
from redisvl.index import AsyncSearchIndex
from redis.asyncio import Redis

# %%
# Redis connection params
REDIS_HOST = 'search01d.us.caas.oneadp.com'
REDIS_PORT = 443
REDIS_PASSWORD = 'fZq7XT1c'

# Create Redis client
redis_client = Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True, 
  ssl_cert_reqs="none", 
  ssl=True)

# %%
index = AsyncSearchIndex.from_dict(schema, redis_client=client)

# %%
index

# %%
# execute the vector query async
results = await index.query(query)
print(results)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1730, in AsyncSearchIndex.search(self, *args, **kwargs)
#    1729 try:
# -> 1730     client = await self._get_client()
#    1731     if isinstance(client, AsyncRedisCluster):
#    1732         # Use special cluster search for AsyncRedisCluster
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1265, in AsyncSearchIndex._get_client(self)
#    1264 if not self._validated_client:
# -> 1265     await RedisConnectionFactory.validate_async_redis(
#    1266         self._redis_client,
#    1267         self._lib_name,
#    1268     )
#    1269     self._validated_client = True
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/redis/connection.py:421, in RedisConnectionFactory.validate_async_redis(redis_client, lib_name, required_modules)
#     420 if not issubclass(type(redis_client), (AsyncRedis, AsyncRedisCluster)):
# --> 421     raise TypeError(
#     422         "Invalid async Redis client instance. Must be async Redis or async RedisCluster."
#     423     )
#     424 # Set client library name
#
# TypeError: Invalid async Redis client instance. Must be async Redis or async RedisCluster.
#
# The above exception was the direct cause of the following exception:
#
# RedisSearchError                          Traceback (most recent call last)
# File <command-7342070529837172>, line 2
#       1 # execute the vector query async
# ----> 2 results = await index.query(query)
#       3 print(results)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1808, in AsyncSearchIndex.query(self, query)
#    1806     return await self._aggregate(query)
#    1807 else:
# -> 1808     return await self._query(query)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1776, in AsyncSearchIndex._query(self, query)
#    1774 except QueryValidationError as e:
#    1775     raise QueryValidationError(f"Invalid query: {str(e)}") from e
# -> 1776 results = await self.search(query.query, query_params=query.params)
#    1777 return process_results(results, query=query, schema=self.schema)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1747, in AsyncSearchIndex.search(self, *args, **kwargs)
#    1745     raise RedisSearchError(f"Error while searching: {str(e)}") from e
#    1746 except Exception as e:
# -> 1747     raise RedisSearchError(f"Unexpected error while searching: {str(e)}") from e
#
# RedisSearchError: Unexpected error while searching: Invalid async Redis client instance. Must be async Redis or async RedisCluster.

# %%
# Modify this schema to have what we want

index.schema.remove_field("job")
index.schema.remove_field("user_embedding")
index.schema.add_fields([
    {"name": "job", "type": "tag"},
    {
        "name": "user_embedding",
        "type": "vector",
        "attrs": {
            "dims": 3,
            "distance_metric": "cosine",
            "algorithm": "hnsw",
            "datatype": "float32"
        }
    }
])

# %%
# Run the index update but keep underlying data in place
await index.create(overwrite=True, drop=False)
# Out:
# 02:20:39 py4j.clientserver INFO   Received command c on object id p0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File <command-7342070529837184>, line 2
#       1 # Run the index update but keep underlying data in place
# ----> 2 await index.create(overwrite=True, drop=False)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1330, in AsyncSearchIndex.create(self, overwrite, drop)
#    1305 async def create(self, overwrite: bool = False, drop: bool = False) -> None:
#    1306     """Asynchronously create an index in Redis with the current schema
#    1307         and properties.
#    1308
#    (...)
#    1328         await index.create(overwrite=True, drop=True)
#    1329     """
# -> 1330     client = await self._get_client()
#    1331     redis_fields = self.schema.redis_fields
#    1333     if not redis_fields:
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/index/index.py:1265, in AsyncSearchIndex._get_client(self)
#    1261             self._redis_client = (
#    1262                 await RedisConnectionFactory._get_aredis_connection(**kwargs)
#    1263             )
#    1264 if not self._validated_client:
# -> 1265     await RedisConnectionFactory.validate_async_redis(
#    1266         self._redis_client,
#    1267         self._lib_name,
#    1268     )
#    1269     self._validated_client = True
#    1270 return self._redis_client
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-d5ba1681-e524-4aed-be1e-8d46330f0e74/lib/python3.12/site-packages/redisvl/redis/connection.py:421, in RedisConnectionFactory.validate_async_redis(redis_client, lib_name, required_modules)
#     419 """Validates the async Redis client."""
#     420 if not issubclass(type(redis_client), (AsyncRedis, AsyncRedisCluster)):
# --> 421     raise TypeError(
#     422         "Invalid async Redis client instance. Must be async Redis or async RedisCluster."
#     423     )
#     424 # Set client library name
#     425 _lib_name = make_lib_name(lib_name)
#
# TypeError: Invalid async Redis client instance. Must be async Redis or async RedisCluster.

# %%
import numpy as np

data = [
    {
        'user': 'john',
        'age': 1,
        'job': 'engineer',
        'credit_score': 'high',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes(),
        'office_location': '-122.4194,37.7749',
        'last_updated': 1741627789
    },
    {
        'user': 'mary',
        'age': 2,
        'job': 'doctor',
        'credit_score': 'low',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes(),
        'office_location': '-122.4194, 37.7749',
        'last_updated': 1741627789
    },
    {
        'user': 'joe',
        'age': 3,
        'job': 'dentist',
        'credit_score': 'medium',
        'user_embedding': np.array([0.9, 0.9, 0.1], dtype=np.float32).tobytes(),
        'office_location': '-122.4194, 37.7749',
        'last_updated': 1741627789
    },
    {
        'user': 'tyler',
        'age': 100,
        'job': 'doctor',
        'credit_score': 'high',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes(),
        'office_location': '-122.0839, 37.3861',
        'last_updated': 1741627789
    },
    {
        'user': 'tim',
        'age': 2,
        'job': 'doctor',
        'credit_score': 'low',
        'user_embedding': np.array([0.1, 0.1, 0.5], dtype=np.float32).tobytes(),
        'office_location': '-122.0839, 37.3861',
        'last_updated': 1741627789
    },
    {
        'user': 'taimur',
        'age': 3,
        'job': 'dentist',
        'credit_score': 'medium',
        'user_embedding': np.array([0.9, 0.9, 0.1], dtype=np.float32).tobytes(),
        'office_location': '-122.4194, 37.7749',
        'last_updated': 1741627789
    }
]

# %%
display(data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>user_embedding</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>2</td><td>low</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>3</td><td>medium</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>ZmZmP2ZmZj/NzMw9</td></tr><tr><td>100</td><td>high</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>2</td><td>low</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>zczMPc3MzD0AAAA/</td></tr><tr><td>3</td><td>medium</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>ZmZmP2ZmZj/NzMw9</td></tr></tbody></table></div>

# %%
schema = {
    "index": {
        "name": "user_queries",
        "prefix": "user_queries_docs",
        "storage_type": "hash", # default setting -- HASH
    },
    "fields": [
        {"name": "user", "type": "tag"},
        {"name": "credit_score", "type": "tag"},
        {"name": "job", "type": "text"},
        {"name": "age", "type": "numeric"},
        {"name": "last_updated", "type": "numeric"},
        {"name": "office_location", "type": "geo"},
        {
            "name": "user_embedding",
            "type": "vector",
            "attrs": {
                "dims": 3,
                "distance_metric": "cosine",
                "algorithm": "flat",
                "datatype": "float32"
            }
        }
    ],
}
# Out:
# 03:03:45 py4j.clientserver INFO   Received command c on object id p0

# %%
import os
import redis

# Redis connection params
REDIS_HOST = 'search01d.us.caas.oneadp.com'
REDIS_PORT = 443
REDIS_PASSWORD = 'fZq7XT1c'

# Create Redis client
client = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True, 
  ssl_cert_reqs="none", 
  ssl=True)
# Test connection
client.ping()
# Out:
# True

# %%
from redisvl.index import SearchIndex

# construct a search index from the schema
index = SearchIndex.from_dict(schema, redis_client=client)

# create the index (no data yet)
index.create(overwrite=True)
# Out:
# 03:03:52 redisvl.index.index INFO   Index already exists, overwriting.
# 03:03:53 py4j.clientserver INFO   Received command c on object id p0

# %%
# load data to redis
keys = index.load(data)

# %%
index.info()['num_docs']
# Out:
# 6

# %%
from redisvl.query import VectorQuery
from redisvl.query.filter import Tag

t = Tag("credit_score") == "high"

v = VectorQuery(
    vector=[0.1, 0.1, 0.5],
    vector_field_name="user_embedding",
    return_fields=["user", "credit_score", "age", "job", "office_location", "last_updated"],
    filter_expression=t
)

results = index.query(v)
display(results)
# Out:
# 03:04:42 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr></tbody></table></div>

# %%
# negation
t = Tag("credit_score") != "high"

v.set_filter(t)
display(index.query(v))
# Out:
# 03:05:07 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# use multiple tags as a list
t = Tag("credit_score") == ["high", "medium"]

v.set_filter(t)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# use multiple tags as a set (to enforce uniqueness)
t = Tag("credit_score") == set(["high", "high", "medium"])

v.set_filter(t)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# gracefully fallback to "*" filter if empty case
empty_case = Tag("credit_score") == []

v.set_filter(empty_case)
display(index.query(v))
# Out:
# 03:06:07 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query.filter import Num

numeric_filter = Num("age").between(2, 35)

v.set_filter(numeric_filter)
display(index.query(v))
# Out:
# 03:07:41 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# exact match query
numeric_filter = Num("age") == 2

v.set_filter(numeric_filter)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
# negation
numeric_filter = Num("age") != 2

v.set_filter(numeric_filter)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query.filter import Timestamp
from datetime import datetime

dt = datetime(2024, 3, 16, 13, 45, 39, 132589)
print(f'Epoch comparison: {dt.timestamp()}')

timestamp_filter = Timestamp("last_updated") > dt

v.set_filter(timestamp_filter)
display(index.query(v))
# Out:
# Epoch comparison: 1710596739.132589
# 03:09:42 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query.filter import Timestamp
from datetime import datetime

dt = datetime(2025, 3, 16, 13, 45, 39, 132589)

print(f'Epoch comparison: {dt.timestamp()}')

timestamp_filter = Timestamp("last_updated") < dt

v.set_filter(timestamp_filter)
display(index.query(v))
# Out:
# Epoch comparison: 1742132739.132589
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query.filter import Timestamp
from datetime import datetime

dt_1 = datetime(2025, 1, 14, 13, 45, 39, 132589)
dt_2 = datetime(2025, 3, 16, 13, 45, 39, 132589)

print(f'Epoch between: {dt_1.timestamp()} - {dt_2.timestamp()}')

timestamp_filter = Timestamp("last_updated").between(dt_1, dt_2)

v.set_filter(timestamp_filter)
display(index.query(v))
# Out:
# Epoch between: 1736862339.132589 - 1742132739.132589
# 03:12:17 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query.filter import Text

# exact match filter -- document must contain the exact word doctor
text_filter = Text("job") == "doctor"

v.set_filter(text_filter)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
# negation -- document must not contain the exact word doctor
negate_text_filter = Text("job") != "doctor"

v.set_filter(negate_text_filter)
display(index.query(v))
# Out:
# 03:12:48 py4j.clientserver INFO   Received command c on object id p1
# 03:12:48 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# wildcard match filter
wildcard_filter = Text("job") % "doct*"

v.set_filter(wildcard_filter)
display(index.query(v))
# Out:
# 03:13:02 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr></tbody></table></div>
# 03:13:03 py4j.clientserver INFO   Received command c on object id p0

# %%
# fuzzy match filter
fuzzy_match = Text("job") % "%%engine%%"

v.set_filter(fuzzy_match)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr></tbody></table></div>

# %%
# conditional -- match documents with job field containing engineer OR doctor
conditional = Text("job") % "engineer|doctor"

v.set_filter(conditional)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr></tbody></table></div>
# 03:13:33 py4j.clientserver INFO   Received command c on object id p0

# %%
# gracefully fallback to "*" filter if empty case
empty_case = Text("job") % ""

v.set_filter(empty_case)
display(index.query(v))
# Out:
# 03:13:48 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
v.set_filter("(~(@job:engineer))")
v.scorer("BM25").with_scores()

index.query(v)
# Out:
# [{'id': 'user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33',
#   'score': 0.0,
#   'vector_distance': '0',
#   'user': 'mary',
#   'credit_score': 'low',
#   'age': '2',
#   'job': 'doctor',
#   'office_location': '-122.4194, 37.7749',
#   'last_updated': '1741627789'},
#  {'id': 'user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8',
#   'score': 0.0,
#   'vector_distance': '0',
#   'user': 'tyler',
#   'credit_score': 'high',
#   'age': '100',
#   'job': 'doctor',
#   'office_location': '-122.0839, 37.3861',
#   'last_updated': '1741627789'},
#  {'id': 'user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75',
#   'score': 1.3636363340803421,
#   'vector_distance': '0',
#   'user': 'john',
#   'credit_score': 'high',
#   'age': '1',
#   'job': 'engineer',
#   'office_location': '-122.4194,37.7749',
#   'last_updated': '1741627789'},
#  {'id': 'user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84',
#   'score': 0.0,
#   'vector_distance': '0',
#   'user': 'tim',
#   'credit_score': 'low',
#   'age': '2',
#   'job': 'doctor',
#   'office_location': '-122.0839, 37.3861',
#   'last_updated': '1741627789'},
#  {'id': 'user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN',
#   'score': 0.0,
#   'vector_distance': '0.653301358223',
#   'user': 'joe',
#   'credit_score': 'medium',
#   'age': '3',
#   'job': 'dentist',
#   'office_location': '-122.4194, 37.7749',
#   'last_updated': '1741627789'},
#  {'id': 'user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G',
#   'score': 0.0,
#   'vector_distance': '0.653301358223',
#   'user': 'taimur',
#   'credit_score': 'medium',
#   'age': '3',
#   'job': 'dentist',
#   'office_location': '-122.4194, 37.7749',
#   'last_updated': '1741627789'}]

# %%
from redisvl.query.filter import Geo, GeoRadius

# within 10 km of San Francisco office
geo_filter = Geo("office_location") == GeoRadius(-122.4194, 37.7749, 10, "km")

v.set_filter(geo_filter)
display(index.query(v))
# Out:
# 03:14:21 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>score</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>mary</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>0.4545454446934474</td><td>john</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# within 100 km Radius of San Francisco office
geo_filter = Geo("office_location") == GeoRadius(-122.4194, 37.7749, 100, "km")

v.set_filter(geo_filter)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>score</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>0.4545454446934474</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>1741627789</td><td>-122.4194,37.7749</td><td>0.4545454446934474</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>0.4545454446934474</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>1741627789</td><td>-122.4194, 37.7749</td><td>0.4545454446934474</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
# not within 10 km Radius of San Francisco office
geo_filter = Geo("office_location") != GeoRadius(-122.4194, 37.7749, 10, "km")

v.set_filter(geo_filter)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>last_updated</th><th>office_location</th><th>score</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>0.0</td><td>tyler</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>1741627789</td><td>-122.0839, 37.3861</td><td>0.0</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
t = Tag("credit_score") == "high"
low = Num("age") >= 2
high = Num("age") <= 100
ts = Timestamp("last_updated") > datetime(2022, 3, 16, 13, 45, 39, 132589)

combined = t & low & high & ts

v = VectorQuery([0.1, 0.1, 0.5],
                "user_embedding",
                return_fields=["user", "credit_score", "age", "job",  "office_location"],
                filter_expression=combined)


display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr></tbody></table></div>
# 03:15:32 py4j.clientserver INFO   Received command c on object id p0

# %%
low = Num("age") < 18
high = Num("age") > 93

combined = low | high

v.set_filter(combined)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
def make_filter(age=None, credit=None, job=None):
    flexible_filter = (
        (Num("age") >= age) &
        (Tag("credit_score") == credit) &
        (Text("job") % job)
    )
    return flexible_filter

# %%
# all parameters
combined = make_filter(age=2, credit="low", job="doctor")
v.set_filter(combined)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
# just age and credit_score
combined = make_filter(age=18, credit="high")
v.set_filter(combined)
display(index.query(v))
# Out:
# 03:19:09 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr></tbody></table></div>

# %%
# just age
combined = make_filter(age=18)
v.set_filter(combined)
display(index.query(v))
# Out:
# 03:19:22 py4j.clientserver INFO   Received command c on object id p1
# 03:19:22 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr></tbody></table></div>

# %%
# no filters
combined = make_filter()
v.set_filter(combined)
display(index.query(v))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>-122.4194, 37.7749</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>-122.0839, 37.3861</td><td>tim</td><td>0</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1Q9SCBYG8N3GDHAFN</td><td>dentist</td><td>-122.4194, 37.7749</td><td>joe</td><td>0.653301358223</td></tr><tr><td>3</td><td>medium</td><td>user_queries_docs:01JZS4MCK1SJ36PVX8AEDMEZ2G</td><td>dentist</td><td>-122.4194, 37.7749</td><td>taimur</td><td>0.653301358223</td></tr></tbody></table></div>

# %%
from redisvl.query import FilterQuery

has_low_credit = Tag("credit_score") == "low"

filter_query = FilterQuery(
    return_fields=["user", "credit_score", "age", "job", "location"],
    filter_expression=has_low_credit
)

results = index.query(filter_query)

display(results)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>user</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>mary</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>tim</td></tr></tbody></table></div>

# %%
from redisvl.query import CountQuery

has_low_credit = Tag("credit_score") == "low"

filter_query = CountQuery(filter_expression=has_low_credit)

count = index.query(filter_query)

print(f"{count} records match the filter expression {str(has_low_credit)} for the given index.")
# Out:
# 2 records match the filter expression @credit_score:{low} for the given index.

# %%
from redisvl.query import RangeQuery

range_query = RangeQuery(
    vector=[0.1, 0.1, 0.5],
    vector_field_name="user_embedding",
    return_fields=["user", "credit_score", "age", "job", "location"],
    distance_threshold=0.2
)

# same as the vector query or filter query
results = index.query(range_query)

display(results)
# Out:
# 03:20:25 py4j.clientserver INFO   Received command c on object id p1
# 03:20:26 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
range_query.set_distance_threshold(0.1)

display(index.query(range_query))
# Out:
# 03:20:49 py4j.clientserver INFO   Received command c on object id p1
# 03:20:49 py4j.clientserver INFO   Received command c on object id p0
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1J4HF4CM25EPAYK33</td><td>doctor</td><td>mary</td><td>0</td></tr><tr><td>100</td><td>high</td><td>user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8</td><td>doctor</td><td>tyler</td><td>0</td></tr><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>john</td><td>0</td></tr><tr><td>2</td><td>low</td><td>user_queries_docs:01JZS4MCK1XQ6KZXZP8PTMMS84</td><td>doctor</td><td>tim</td><td>0</td></tr></tbody></table></div>

# %%
is_engineer = Text("job") == "engineer"

range_query.set_filter(is_engineer)

display(index.query(range_query))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>john</td><td>0</td></tr></tbody></table></div>
# 03:21:12 py4j.clientserver INFO   Received command c on object id p0

# %%
# Sort by a different field and change dialect
v = VectorQuery(
    vector=[0.1, 0.1, 0.5],
    vector_field_name="user_embedding",
    return_fields=["user", "credit_score", "age", "job",  "office_location"],
    num_results=5,
    filter_expression=is_engineer
).sort_by("age", asc=False).dialect(3)

result = index.query(v)
display(result)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>credit_score</th><th>id</th><th>job</th><th>office_location</th><th>user</th><th>vector_distance</th></tr></thead><tbody><tr><td>1</td><td>high</td><td>user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75</td><td>engineer</td><td>-122.4194,37.7749</td><td>john</td><td>0</td></tr></tbody></table></div>

# %%
# check out the complex query from above
str(v)
# Out:
# '@job:("engineer")=>[KNN 5 @user_embedding $vector AS vector_distance] RETURN 6 user credit_score age job office_location vector_distance SORTBY age DESC DIALECT 3 LIMIT 0 5'

# %%
t = Tag("credit_score") == "high"

str(t)
# Out:
# '@credit_score:{high}'

# %%
t = Tag("credit_score") == "high"
low = Num("age") >= 18
high = Num("age") <= 100

combined = t & low & high

str(combined)
# Out:
# 03:21:57 py4j.clientserver INFO   Received command c on object id p1
# '((@credit_score:{high} @age:[18 +inf]) @age:[-inf 100])'

# %%
results = index.search(str(t))
for r in results.docs:
    print(r.__dict__)
# Out:
# 03:22:07 py4j.clientserver INFO   Received command c on object id p1
# {'id': 'user_queries_docs:01JZS4MCK1P1K0EAQBW3M6CKS8', 'payload': None, 'user': 'tyler', 'age': '100', 'job': 'doctor', 'credit_score': 'high', 'user_embedding': '==\x00\x00\x00?', 'office_location': '-122.0839, 37.3861', 'last_updated': '1741627789'}
# {'id': 'user_queries_docs:01JZS4MCK1V8Y39N262SEC4Z75', 'payload': None, 'user': 'john', 'age': '1', 'job': 'engineer', 'credit_score': 'high', 'user_embedding': '==\x00\x00\x00?', 'office_location': '-122.4194,37.7749', 'last_updated': '1741627789'}

# %%
index.delete()
# Out:
# 03:22:19 py4j.clientserver INFO   Received command c on object id p0
