# %%
# !pip uninstall --yes redis
# !pip uninstall --yes redisvl
# !pip uninstall --yes pydantic
# Out:
# WARNING: Skipping redis as it is not installed.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# WARNING: Skipping redisvl as it is not installed.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.
# Found existing installation: pydantic 1.10.6
# Not uninstalling pydantic at /databricks/python3/lib/python3.11/site-packages, outside environment /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b
# Can't uninstall 'pydantic'. No files were found to uninstall.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# !pip install redis==6.2.0 redisvl>=0.7.0
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.16.1 requires ml-dtypes~=0.3.1, but you have ml-dtypes 0.5.1 which is incompatible.
# ydata-profiling 4.5.1 requires pydantic<2,>=1.8.1, but you have pydantic 2.11.6 which is incompatible.
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
# !rvl version
# Out:
# 21:03:42 [RedisVL] INFO   RedisVL version 0.7.0

# %%
ml_catalog = "onedata_us_east_1_shared_dit"
ml_search_db = "nas_raw_lyric_search_dit"

# df_action = spark.sql(f"""
#     SELECT 
#     client_id, 
#     _id, caption, subtitle, count(*) AS views
#     FROM {ml_catalog}.{ml_search_db}.ml_search_action
#     WHERE context='US'
#     GROUP BY 1, 2, 3, 4
#     ORDER BY 4 DESC
# """)

df_action = spark.sql(f"""
    SELECT 
    _id, caption, subtitle, count(*) AS views
    FROM {ml_catalog}.{ml_search_db}.ml_search_action
    WHERE context='US'
    GROUP BY 1, 2, 3
    ORDER BY 4 DESC
""")

# %%
display(df_action)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>caption</th><th>subtitle</th><th>views</th></tr></thead><tbody><tr><td>92e3eae6ab5e4f8cab69c0c0b87eb7c1</td><td>Manage Pay Runs</td><td>Process payroll data within a pay group for a given pay period and to review and commit Pay Runs.</td><td>1042</td></tr><tr><td>7843598ab66a41d28253f40b5e9a3c56</td><td>Manage Associate's Pay Profile</td><td>Maintain and capture Associate's pay data records within a legal entity and/or pay group.</td><td>904</td></tr><tr><td>119fb43320ab44c9847c9b2284f7e848</td><td>View My Associate Profile</td><td>View My Associate Profile</td><td>865</td></tr><tr><td>899c324e3f2742ce9cd9d27a97048cc5</td><td>View Company Org Chart</td><td>View Company Org Chart</td><td>799</td></tr><tr><td>df6e2b589b0d462ebcdfb01bae2106c3</td><td>Add My Personal Contacts</td><td>Add a contact to your profile</td><td>743</td></tr><tr><td>d0adbfea7381492e976ec090d26777ba</td><td>Manage Benefits Supplemental Fields</td><td>View and Manage Associate's benefit related supplemental eligibility and compliance values.</td><td>717</td></tr><tr><td>855c3abcdde94c4b8c1c6c46b98d3bf3</td><td>View Your Benefits</td><td>View Your Benefits</td><td>702</td></tr><tr><td>6aa709dc9ad44b7ea7e61424086e2415</td><td>View Your Pay</td><td>Access your pay details.</td><td>640</td></tr><tr><td>0429ea12a5974851ab47620c9d7205c9</td><td>View Criteria Control Center</td><td>Setup and manage the search queries that give eligibility, approvals, authorizations and other apps the flexibility and power they need to evolve with your workforce.</td><td>637</td></tr><tr><td>9925c8101c7b43e98eeb2c6539728764</td><td>Manage Payroll Company Data</td><td>Configure company pay data and maintain payroll settings within a legal entity and/or pay group.</td><td>615</td></tr><tr><td>50f79735cf8647e1902b132b8063e3ae</td><td>Edit My Personal Demographics</td><td>Edit your gender, race, nationality, marital status and other birth details</td><td>575</td></tr><tr><td>846b123c190448f8a7b82f942d7609bd</td><td>View and Manage Associates' Benefits</td><td>Manage changes to associates' Benefits</td><td>534</td></tr><tr><td>2a1ec3581d634da888cc03ce2dd8d818</td><td>Benefits Data Management</td><td>View and edit benefits data, add new records, and download benefits reports for all associates.</td><td>516</td></tr><tr><td>229bbf0c07a449b08fd7731656cee98e</td><td>Create Criteria</td><td>Create a new search query for an app or domain.</td><td>482</td></tr><tr><td>3a59d8daae5147c389cdaaffbcad7d64</td><td>Manage Authorizations</td><td>Manage permissions for users and apps.</td><td>450</td></tr><tr><td>ff3b3f8391b7490c95f3c0c693327aa5</td><td>Reports & Analytics</td><td>Run, create and manage reports and analytics with benchmarks</td><td>450</td></tr><tr><td>6cb4e781195c4727a8fcf1d851bceb04</td><td>Configure Additional Associate Identifiers</td><td>Add new identification types that can be assigned to associates.</td><td>434</td></tr><tr><td>b3cc3ceac4d24c2e843aa13078bd2f8e</td><td>Hiring Dashboard</td><td>Navigate to the new hire dashboard to start a hire.</td><td>413</td></tr><tr><td>d27d5dcf28b442e09b090540cf80f3cd</td><td>View and Manage Benefits</td><td>View and Manage all Benefits</td><td>384</td></tr><tr><td>61879fc535b74accb21081bda19bdd92</td><td>User Management Troubleshooting</td><td>Access CRUD pages for user registration, product access, passwords/usernames and more.</td><td>381</td></tr><tr><td>dcfb1c00f6414037935ad05e2c69d10c</td><td>View My Time Off</td><td>Time Off</td><td>379</td></tr><tr><td>4766e323575849acb389a0ba42353f89</td><td>Work Authorization Type Configuration</td><td>Manage work visas, permits and other documents</td><td>372</td></tr><tr><td>11b1aaa5a57d42e195d60b0fc0db17f3</td><td>Add My Mailing Address</td><td>Add your Mailing Address</td><td>364</td></tr><tr><td>d8d26b81f56a4260b44b43b997371e91</td><td>Add My Physical Address</td><t ...

# %%
import string

# %%
pdf_action = df_action.toPandas()
pdf_action['combined'] = pdf_action.apply(
    lambda x: x.caption if x.caption.lower() == x.subtitle.lower() else ','.join([x.caption, x.subtitle]), 
    axis=1
)
documents = "\n\n".join(pdf_action.combined)
documents[:100]
# Out:
# 'Manage Pay Runs,Process payroll data within a pay group for a given pay period and to review and com'

# %%
from pathlib import Path
import sys

current_dir = Path.cwd()
parent_dir = current_dir.parent.parent
sys.path.append(str(parent_dir))

# %%
from utils.data_profiling_nlp import CustomTextSplitter

splitter = CustomTextSplitter(separator="\n\n")
processed_tokens = splitter.split_text(documents)

# %%
from collections import Counter
import pandas as pd

words = ','.join(processed_tokens)
w = words.split(',')

most_common_keywords = Counter(w).most_common(50)
sorted_keywords = sorted(most_common_keywords, key=lambda x: x[1])
top_keywords = pd.DataFrame(sorted_keywords, columns=['keyword', 'count'])
display(top_keywords)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>keyword</th><th>count</th></tr></thead><tbody><tr><td>approval</td><td>10</td></tr><tr><td>hire</td><td>10</td></tr><tr><td>work</td><td>10</td></tr><tr><td>position</td><td>10</td></tr><tr><td>performance</td><td>10</td></tr><tr><td>group</td><td>11</td></tr><tr><td>user</td><td>11</td></tr><tr><td>list</td><td>11</td></tr><tr><td>adp</td><td>11</td></tr><tr><td>gestionar</td><td>11</td></tr><tr><td>document</td><td>12</td></tr><tr><td>perfil</td><td>12</td></tr><tr><td>exibir</td><td>12</td></tr><tr><td>benefícios</td><td>12</td></tr><tr><td>da</td><td>12</td></tr><tr><td>company</td><td>13</td></tr><tr><td>new</td><td>13</td></tr><tr><td>integration</td><td>13</td></tr><tr><td>client</td><td>13</td></tr><tr><td>editar</td><td>13</td></tr><tr><td>visualizar</td><td>13</td></tr><tr><td>add</td><td>14</td></tr><tr><td>pago</td><td>14</td></tr><tr><td>empresa</td><td>14</td></tr><tr><td>benefit</td><td>15</td></tr><tr><td>request</td><td>15</td></tr><tr><td>import</td><td>17</td></tr><tr><td>payroll</td><td>18</td></tr><tr><td>edit</td><td>18</td></tr><tr><td>management</td><td>19</td></tr><tr><td>para</td><td>20</td></tr><tr><td>report</td><td>21</td></tr><tr><td>create</td><td>21</td></tr><tr><td>configurar</td><td>21</td></tr><tr><td>data</td><td>23</td></tr><tr><td>administrar</td><td>23</td></tr><tr><td>pay</td><td>24</td></tr><tr><td>los</td><td>24</td></tr><tr><td>ver</td><td>24</td></tr><tr><td>gerenciar</td><td>25</td></tr><tr><td>team</td><td>26</td></tr><tr><td>time</td><td>29</td></tr><tr><td>e</td><td>29</td></tr><tr><td>associate</td><td>32</td></tr><tr><td>dashboard</td><td>32</td></tr><tr><td>configure</td><td>40</td></tr><tr><td>la</td><td>46</td></tr><tr><td>manage</td><td>112</td></tr><tr><td>view</td><td>133</td></tr><tr><td>de</td><td>222</td></tr></tbody></table></div>

# %%
from typing import List
import nltk

# Compute frequency distribution and get top K
keyword_chunks: List[str] = []
for tokens in processed_tokens:
    token_list = tokens.split(",")
    freq_dist = nltk.FreqDist(token_list)
    top_keywords = [word for word, _ in freq_dist.most_common(5)]
    keyword_chunks.append(",".join(top_keywords))
pdf_action['keywords'] = keyword_chunks
pdf_action.drop(['combined'], axis=1, inplace=True)
display(pdf_action)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>_id</th><th>caption</th><th>subtitle</th><th>views</th><th>keywords</th></tr></thead><tbody><tr><td>92e3eae6ab5e4f8cab69c0c0b87eb7c1</td><td>Manage Pay Runs</td><td>Process payroll data within a pay group for a given pay period and to review and commit Pay Runs.</td><td>1042</td><td>pay,run,manage,process,payroll</td></tr><tr><td>7843598ab66a41d28253f40b5e9a3c56</td><td>Manage Associate's Pay Profile</td><td>Maintain and capture Associate's pay data records within a legal entity and/or pay group.</td><td>904</td><td>pay,associate,manage,profile,maintain</td></tr><tr><td>119fb43320ab44c9847c9b2284f7e848</td><td>View My Associate Profile</td><td>View My Associate Profile</td><td>865</td><td>view,associate,profile</td></tr><tr><td>899c324e3f2742ce9cd9d27a97048cc5</td><td>View Company Org Chart</td><td>View Company Org Chart</td><td>799</td><td>view,company,org,chart</td></tr><tr><td>df6e2b589b0d462ebcdfb01bae2106c3</td><td>Add My Personal Contacts</td><td>Add a contact to your profile</td><td>743</td><td>add,contact,personal,profile</td></tr><tr><td>d0adbfea7381492e976ec090d26777ba</td><td>Manage Benefits Supplemental Fields</td><td>View and Manage Associate's benefit related supplemental eligibility and compliance values.</td><td>717</td><td>manage,benefit,supplemental,field,view</td></tr><tr><td>855c3abcdde94c4b8c1c6c46b98d3bf3</td><td>View Your Benefits</td><td>View Your Benefits</td><td>702</td><td>view,benefit</td></tr><tr><td>6aa709dc9ad44b7ea7e61424086e2415</td><td>View Your Pay</td><td>Access your pay details.</td><td>640</td><td>pay,view,access,detail</td></tr><tr><td>0429ea12a5974851ab47620c9d7205c9</td><td>View Criteria Control Center</td><td>Setup and manage the search queries that give eligibility, approvals, authorizations and other apps the flexibility and power they need to evolve with your workforce.</td><td>637</td><td>view,criterion,control,center,setup</td></tr><tr><td>9925c8101c7b43e98eeb2c6539728764</td><td>Manage Payroll Company Data</td><td>Configure company pay data and maintain payroll settings within a legal entity and/or pay group.</td><td>615</td><td>payroll,company,data,pay,manage</td></tr><tr><td>50f79735cf8647e1902b132b8063e3ae</td><td>Edit My Personal Demographics</td><td>Edit your gender, race, nationality, marital status and other birth details</td><td>575</td><td>edit,personal,demographic,gender,race</td></tr><tr><td>846b123c190448f8a7b82f942d7609bd</td><td>View and Manage Associates' Benefits</td><td>Manage changes to associates' Benefits</td><td>534</td><td>manage,associate,benefit,view,change</td></tr><tr><td>2a1ec3581d634da888cc03ce2dd8d818</td><td>Benefits Data Management</td><td>View and edit benefits data, add new records, and download benefits reports for all associates.</td><td>516</td><td>benefit,data,management,view,edit</td></tr><tr><td>229bbf0c07a449b08fd7731656cee98e</td><td>Create Criteria</td><td>Create a new search query for an app or domain.</td><td>482</td><td>create,criterion,new,search,query</td></tr><tr><td>3a59d8daae5147c389cdaaffbcad7d64</td><td>Manage Authorizations</td><td>Manage permissions for users and apps.</td><td>450</td><td>manage,authorization,permission,user,apps</td></tr><tr><td>ff3b3f8391b7490c95f3c0c693327aa5</td><td>Reports & Analytics</td><td>Run, create and manage reports and analytics with benchmarks</td><td>450</td><td>report,analytics,run,create,manage</td></tr><tr><td>6cb4e781195c4727a8fcf1d851bceb04</td><td>Configure Additional Associate Identifiers</td><td>Add new identification types that can be assigned to associates.</td><td>434</td><td>associate,configure,additional,identifier,add</td></tr><tr><td>b3cc3ceac4d24c2e843aa13078bd2f8e</td><td>Hiring Dashboard</td><td>Navigate to the new hire dashboard to start a hire.</td><td>413</td><td>dashboard,hire,hiring,navigate,new</td></tr><tr><td>d27d5dcf28b442e09b090540cf80f3cd</td><td>Vie ...

# %%
print(f"--{processed_tokens[1]}\n--{processed_tokens[2]}")
# Out:
# --manage,associate,pay,profile,maintain,capture,associate,pay,data,record,within,legal,entity,andor,pay,group
# --view,associate,profile

# %%
# !pip install rank_bm25
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: rank_bm25 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.11/site-packages (from rank_bm25) (1.23.5)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from rank_bm25 import BM25Okapi


def bm25_tokenizer(text):
    tokenized_doc = []
    for token in text.split(','):
        token = token.strip(string.punctuation)
        if len(token) > 0:
            tokenized_doc.append(token)
    return tokenized_doc

tokenized_corpus = []
for passage in processed_tokens:
    tokenized_corpus.append(bm25_tokenizer(passage))

# #Create a BM25 index from the tokenized document corpus
bm25 = BM25Okapi(tokenized_corpus)

# %%
import numpy as np


def search(query, top_k=3, num_candidates=100):
    print("Input question:", query)

    ##### BM25 search (lexical search) #####
    bm25_scores = bm25.get_scores(bm25_tokenizer(query))
    top_n = np.argpartition(bm25_scores, -num_candidates)[-num_candidates:]
    bm25_hits = [{'corpus_id': idx, 'score': bm25_scores[idx]} for idx in top_n]
    bm25_hits = sorted(bm25_hits, key=lambda x: x['score'], reverse=True)
    
    print(f"\nTop-3 lexical search (BM25) hits")
    print("-----------------------------------")

    for hit in bm25_hits[0:top_k]:
        print("\t{:.3f}\t{}".format(hit['score'], processed_tokens[hit['corpus_id']].replace("\n", " ")))

# %%
search("dashboard", top_k=3, num_candidates=100)
# Out:
# Input question: dashboard
#
# Top-3 lexical search (BM25) hits
# -----------------------------------
# 	4.450	view,payroll,dashboard,payroll,dashboard
# 	4.450	view,hr,dashboard,hr,dashboard
# 	4.245	registration,dashboard,dashboard,track,associate,registration

# %% [markdown]
# ### LLM Embedding

# %%
from pathlib import Path
parent_path = Path.cwd().resolve()
cert_path = parent_path / "utils/ADP_Internal_Root_CA_GN2.pem"
print(cert_path)
# Out:
# /Workspace/Users/ling.huang@adp.com/utils/ADP_Internal_Root_CA_GN2.pem

# %%
# !pip install openai
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: openai in /databricks/python3/lib/python3.11/site-packages (1.35.3)
# Requirement already satisfied: anyio<5,>=3.5.0 in /databricks/python3/lib/python3.11/site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /databricks/python3/lib/python3.11/site-packages (from openai) (0.27.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (from openai) (2.11.6)
# Requirement already satisfied: sniffio in /databricks/python3/lib/python3.11/site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in /databricks/python3/lib/python3.11/site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (from openai) (4.14.0)
# Requirement already satisfied: idna>=2.8 in /databricks/python3/lib/python3.11/site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in /databricks/python3/lib/python3.11/site-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /databricks/python3/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-8b2a0d82-4870-43b2-9817-ab0ffc13d07b/lib/python3.11/site-packages (from pydantic<3,>=1.9.0->openai) (0.4.1)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
from pyspark.sql.functions import concat_ws

df_action = df_action.withColumn(
    "combined", 
    concat_ws(" | ", df_action["caption"], df_action["subtitle"])
)
df = df_action.select("combined").dropDuplicates()

pdf = df.sample(fraction=0.1).toPandas()
pdf = df_action.toPandas()

# %%
import time
from utils.data_profiling import get_openai_embedding

embed_start_time = time.time()

pdf["embedding"] = pdf.combined.apply(lambda x: get_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z", x))

embed_time = time.time() - embed_start_time
print(f"Embedding took {embed_time} seconds")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Received Bearer token
# Embedding took 537.9692025184631 seconds
# [Trace(request_id=tr-400b293c68ac46e3bb2f4bf2a839912b), Trace(request_id=tr-1aea43d377a747f08a2202e3b4b60d91), Trace(request_id=tr-fc8a546d808c493eb47caf2806c6c22e), Trace(request_id=tr-710d406c300a457ba851db3a5882f150), Trace(request_id=tr-18c3675fd0fc44769f8188eb76966486), Trace(request_id=tr-f86d05ee99c84512a8982747eab7cc7e), Trace(request_id=tr-d7867f4bbe4f4149b4882c8decdf1e6f), Trace(request_id=tr-4604b81e70ed45169df5da6c8e91a084), Trace(request_id=tr-01956cc0024e4e008145ecc15df42fac), Trace(request_id=tr-3dc663600dfb43319fa09ee6534e909e)]

# %%
len(pdf)
# Out:
# 439

# %%
len(pdf['embedding'][0])
# Out:
# 3072

# %%
import numpy as np

pdf['embedding'] = pdf['embedding'].apply(lambda x: np.array(x).astype(np.float32).tobytes())

# %%
pdf.to_csv("df_action.csv")

# %% [markdown]
# ### Define Redis index schema

# %%
import os
import redis

# Redis connection params
REDIS_HOST = 'search01d.us.caas.oneadp.com'
REDIS_PORT = 443
REDIS_PASSWORD = 'fZq7XT1c'

# Create Redis client
redis_client = redis.Redis(
  host=REDIS_HOST,
  port=REDIS_PORT,
  password=REDIS_PASSWORD,
  decode_responses=True, 
  ssl_cert_reqs="none", 
  ssl=True)
# Test connection
redis_client.ping()
# Out:
# True

# %%
redis_client.flushall()
# Out:
# True

# %%
from redisvl.schema import IndexSchema
from redisvl.index import SearchIndex

index_name = "action_links"

schema = IndexSchema.from_dict({
  "index": {
    "name": index_name,
    "prefix": index_name,
    "storage_type": "hash"
  },
  "fields": [
    {"type" : "tag", "name" : "caption","attrs": {"sortable": True}},
    {"type" : "text", "name" : "subtitle"},
    {"type" : "text", "name" : "combined"},
    {"type" : "numeric", "name" : "views", "attrs": {"sortable": True}},
    {
        "type" : "vector",
        "name" : "embedding",
        "attrs" : {
            "dims": 3072,
            "distance_metric": "cosine",
            "algorithm": "flat",
            "datatype": "float32"
        }
    }
  ],
})

index = SearchIndex(schema, redis_client)
index.create(overwrite=True, drop=True)

# %%
redis_client.dbsize()
# Out:
# 0

# %%
index.load(pdf.to_dict(orient="records"))
# Out:
# ['action_links:01JXNKM532MA6D9YNJZ3D592XJ',
#  'action_links:01JXNKM532WQPPS882TSMH925G',
#  'action_links:01JXNKM532118JC2WSF2CBFZY1',
#  'action_links:01JXNKM532SZZJZ9PKRXWMMYVV',
#  'action_links:01JXNKM532JH6A7MDSMG100S7W',
#  'action_links:01JXNKM5326HMKF4AYX7YPXMC7',
#  'action_links:01JXNKM5324RARRWQYNZYQ50RD',
#  'action_links:01JXNKM5329W884SYWKCZJJSGX',
#  'action_links:01JXNKM533QT8FXDTVFWHH8GYB',
#  'action_links:01JXNKM533G2MNPD4N473SCB4B',
#  'action_links:01JXNKM533QA78CARH0H8991R4',
#  'action_links:01JXNKM533JHDVVKXMSE3JHGHC',
#  'action_links:01JXNKM533NWYM7HHM2BACSPMX',
#  'action_links:01JXNKM533079APFQY3XYNJ5KV',
#  'action_links:01JXNKM533E49ZRWN2NESY90AM',
#  'action_links:01JXNKM533HG1777VCCN6ERZ34',
#  'action_links:01JXNKM533E2Q5NRV4ZNDWE726',
#  'action_links:01JXNKM5334YJVDDT0GJ8CHMZ8',
#  'action_links:01JXNKM533W9FT46F119R6VRB4',
#  'action_links:01JXNKM53336QRCGGJHS5ASDH9',
#  'action_links:01JXNKM5335V60D7W2R1NMHXAD',
#  'action_links:01JXNKM533V3R6T53YXQ8XS5M9',
#  'action_links:01JXNKM5330DJ04KY7VY0EA04T',
#  'action_links:01JXNKM5336NZ448PZXFJQYE65',
#  'action_links:01JXNKM533V9M3V6TGM42Z5S5X',
#  'action_links:01JXNKM533H3DR7S6WPBFAEAQ1',
#  'action_links:01JXNKM533ZBP11NZYBFH2NQ8V',
#  'action_links:01JXNKM533V60HN84NHS55W9D0',
#  'action_links:01JXNKM533S01E39A5PD1FYZC2',
#  'action_links:01JXNKM533ETG52Z3Y6PJ7S3BT',
#  'action_links:01JXNKM533FY73V0HZNR09VNY0',
#  'action_links:01JXNKM5338RR1M19JZ3Z54HV4',
#  'action_links:01JXNKM533JQNVNKPDRFD99438',
#  'action_links:01JXNKM533R7A11K8HVF5SPYT4',
#  'action_links:01JXNKM533QZFG5WT5GKWPQ3ZP',
#  'action_links:01JXNKM533BFDPZK8YS1JW9BPE',
#  'action_links:01JXNKM533N8ES4J6RZ6AJ2BY9',
#  'action_links:01JXNKM533GF554SVEZQGQPAR3',
#  'action_links:01JXNKM53319Q0G86XBQBBEJ0X',
#  'action_links:01JXNKM533425QCEVF0ZMFYX91',
#  'action_links:01JXNKM533MVW3W9MBBK07AAN3',
#  'action_links:01JXNKM533CY2R6D27B81S0WMF',
#  'action_links:01JXNKM533TQZBB882QEAFVWWD',
#  'action_links:01JXNKM533XS6P37S3HXVMVTZ9',
_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z", user_query)
# Out:
# Received Bearer token
# Trace(request_id=tr-ffaa276e5aa34db19c511a82ca72f24a)

# %%
from redisvl.query import VectorQuery

vec_query = VectorQuery(
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    num_results=5,
    return_fields=["caption", "subtitle"],
    return_score=True,
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...                 subtitle
# 0  action_links:01JXNKM534JM5TRGXEF65RB8PR  ...
# 1  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...         Asset Management
# 2  action_links:01JXNKM534NC57DNZ2Q9KCR83V  ...              Manage Time
# 3  action_links:01JXNKM534BPC4R06669S2TRSQ  ...        Tenant Management
# 4  action_links:01JXNKM5345CR6N34WCPWP8M4H  ...  Organization Management
#
# [5 rows x 4 columns]

# %% [markdown]
# ### Vector search with filters

# %%
from redisvl.query.filter import Tag

tag_filter = Tag("caption") == "Asset Management"

vec_query.set_filter(tag_filter)

result=index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...          subtitle
# 0  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...  Asset Management
#
# [1 rows x 4 columns]

# %%
from redisvl.query.filter import Num

# build combined filter expressions
tag_filter = Tag("caption") == "Asset Management"
num_filter = Num("views") >= 2
combined_filter = tag_filter & num_filter

# build vector query
vec_query = VectorQuery(
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    num_results=5,
    return_fields=["caption", "subtitle"],
    return_score=True,
    filter_expression=combined_filter
)

result=index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...          subtitle
# 0  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...  Asset Management
#
# [1 rows x 4 columns]

# %%
from redisvl.query.filter import Text

text_filter = Text("subtitle") % "Asset Management"

vec_query = VectorQuery(
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    num_results=3,
    return_fields=["caption", "subtitle"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...          subtitle
# 0  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...  Asset Management
#
# [1 rows x 4 columns]

# %%
text_filter =  Text("combined") % "mana*"

vec_query = VectorQuery(vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    num_results=10,
    return_fields=["caption", "subtitle", "combined"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...                                           combined
# 0  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...                Asset Management | Asset Management
# 1  action_links:01JXNKM534NC57DNZ2Q9KCR83V  ...                          Manage Time | Manage Time
# 2  action_links:01JXNKM534BPC4R06669S2TRSQ  ...              Tenant Management | Tenant Management
# 3  action_links:01JXNKM5345CR6N34WCPWP8M4H  ...  Organization Management | Organization Management
# 4  action_links:01JXNKM534EYZMCPC7H0QJC4FC  ...        Manage Talent Cycles | Manage Talent Cycles
# 5  action_links:01JXNKM534A9P5W6YMPG4GS5QJ  ...                            Manage EDA | Manage EDA
# 6  action_links:01JXNKM534SEM719BWMH5DB6A2  ...              Policy Management | Policy Management
# 7  action_links:01JXNKM534MCCZMXQ3794XTDM4  ...  Classroom Training Management | This Link For ...
# 8  action_links:01JXNKM534WQ04B04Q0JT4GH6Y  ...  Case Management | This is to enable users to s...
# 9  action_links:01JXNKM534PK4X0GP6ZPFWXRNS  ...                        Manage Leave | Manage Leave
#
# [10 rows x 5 columns]

# %%
text_filter =  Text("combined") % "%mana%"

vec_query = VectorQuery(vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    num_results=10,
    return_fields=["caption", "subtitle", "combined"],
    return_score=True,
    filter_expression=text_filter
)

result = index.query(vec_query)
pd.DataFrame(result)
# Out:
#                                         id  ...                                           combined
# 0  action_links:01JXNKM535XTH35X7VD3TMCQCQ  ...  Importar valores de campo fluido | Importar va...
# 1  action_links:01JXNKM533XS6P37S3HXVMVTZ9  ...  Send Registration Emails | Send a registration...
#
# [2 rows x 5 columns]

# %%
from redisvl.query import RangeQuery

range_query = RangeQuery(
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    return_fields=["caption", "subtitle", "combined"],
    return_score=True,
    distance_threshold=0.8
)

result = index.query(range_query)
pd.DataFrame(result)
# Out:
#                                         id  ...                                           combined
# 0  action_links:01JXNKM534JM5TRGXEF65RB8PR  ...                              Manuel test Google |
# 1  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...                Asset Management | Asset Management
# 2  action_links:01JXNKM534NC57DNZ2Q9KCR83V  ...                          Manage Time | Manage Time
# 3  action_links:01JXNKM534BPC4R06669S2TRSQ  ...              Tenant Management | Tenant Management
# 4  action_links:01JXNKM5345CR6N34WCPWP8M4H  ...  Organization Management | Organization Management
# 5  action_links:01JXNKM534EYZMCPC7H0QJC4FC  ...        Manage Talent Cycles | Manage Talent Cycles
# 6  action_links:01JXNKM534BY2JAK9W021T37TJ  ...                                        TEST | Test
# 7  action_links:01JXNKM534E6FDKS39WK61JHZ3  ...                                        TEST | Test
# 8  action_links:01JXNKM5354A9EH2M4HQCSNWRX  ...                                        TEST | Test
# 9  action_links:01JXNKM534A9P5W6YMPG4GS5QJ  ...                            Manage EDA | Manage EDA
#
# [10 rows x 5 columns]

# %%
range_query = RangeQuery(
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    return_fields=["caption", "subtitle", "combined"],
    distance_threshold=0.8
)

numeric_filter = Num("views") >= 20

range_query.set_filter(numeric_filter)

# in this case we want to do a simple filter search or the vector so we execute as a joint filter directly
result = index.query(range_query)
pd.DataFrame(result)
# Out:
#                                         id  ...                                           combined
# 0  action_links:01JXNKM534Z24X9M0JEXHTM5ED  ...                Asset Management | Asset Management
# 1  action_links:01JXNKM534NC57DNZ2Q9KCR83V  ...                          Manage Time | Manage Time
# 2  action_links:01JXNKM5345CR6N34WCPWP8M4H  ...  Organization Management | Organization Management
# 3  action_links:01JXNKM534EYZMCPC7H0QJC4FC  ...        Manage Talent Cycles | Manage Talent Cycles
# 4  action_links:01JXNKM534A9P5W6YMPG4GS5QJ  ...                            Manage EDA | Manage EDA
#
# [5 rows x 5 columns]

# %%
# from redisvl.query import TextQuery

# user_query = "Manange"

# text_query = TextQuery(
#     text=user_query,
#     text_field_name="caption",
#     text_scorer="BM25STD",
#     num_results=20,
#     return_fields=["caption", "subtitle", "combined"],
# )

# result = index.query(text_query)
# pd.DataFrame(result)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
from redisvl.query import HybridQuery

hybrid_query = HybridQuery(
    text=user_query,
    text_field_name="subtitle",
    text_scorer="BM25",
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    return_fields=["caption", "subtitle", "combined"],
)

result = index.query(hybrid_query)
pd.DataFrame(result)
# Out:
#                    caption  ... vector_distance
# 0       Manuel test Google  ...  0.739207684994
# 1         Asset Management  ...  0.744464993477
# 2              Manage Time  ...  0.765155136585
# 3        Tenant Management  ...  0.767837584019
# 4  Organization Management  ...  0.791345834732
# 5     Manage Talent Cycles  ...  0.791500508785
# 6                     TEST  ...  0.792008459568
# 7                     TEST  ...  0.792008459568
# 8                     TEST  ...  0.792008459568
# 9               Manage EDA  ...  0.794311881065
#
# [10 rows x 7 columns]

# %%
user_query = "Manage"
hybrid_query = HybridQuery(
    text=user_query,
    text_field_name="subtitle",
    text_scorer="BM25",
    vector=np.array(vector).astype(np.float32).tobytes(),
    vector_field_name="embedding",
    alpha=0.7, # weight the vector score lower
    num_results=20,
    return_fields=["caption", "subtitle", "combined"],
)

result = index.query(hybrid_query)
pd.DataFrame(result)
# Out:
#                           caption  ... vector_distance
# 0                     Manage Time  ...  0.765155136585
# 1            Manage Talent Cycles  ...  0.791500508785
# 2                      Manage EDA  ...  0.794311881065
# 3                    Manage Leave  ...  0.811369538307
# 4              Manuel test Google  ...  0.739207684994
# 5                Asset Management  ...  0.744464993477
# 6               Tenant Management  ...  0.767837584019
# 7         Organization Management  ...  0.791345834732
# 8                            TEST  ...  0.792008459568
# 9                            TEST  ...  0.792008459568
# 10                           TEST  ...  0.792008459568
# 11              Policy Management  ...  0.801048755646
# 12                           test  ...  0.802343845367
# 13           Performance Settings  ...  0.802726268768
# 14                           Bing  ...  0.803064465523
# 15                           Bing  ...  0.803064465523
# 16  Classroom Training Management  ...  0.805212020874
# 17                Case Management  ...  0.806366920471
# 18                    DHModalsize  ...    0.8071641922
# 19                          hello  ...  0.808554887772
#
# [20 rows x 7 columns]

# %%
def fuse_rankings_rrf(*ranked_lists, weights=None, k=60):
    """
    Perform Weighted Reciprocal Rank Fusion on N number of ordered lists.
    """
    item_scores = {}
    
    if weights is None:
        weights = [1.0] * len(ranked_lists)
    else:
        assert len(weights) == len(ranked_lists), "Number of weights must match number of ranked lists"
        assert all(0 <= w <= 1 for w in weights), "Weights must be between 0 and 1"
    
    for ranked_list, weight in zip(ranked_lists, weights):
        for rank, item in enumerate(ranked_list, start=1):
            if item not in item_scores:
                item_scores[item] = 0
            item_scores[item] += weight * (1 / (rank + k))
    
    # Sort items by their weighted RRF scores in descending order
    return sorted(item_scores.items(), key=lambda x: x[1], reverse=True)

# %%
# Function to create a vector query using RedisVL helpers for ease of use
from redisvl.query import VectorQuery, TextQuery


def make_vector_query(user_query: str, num_results: int, filters = None) -> VectorQuery:
    """Generate a Redis vector query given user query string."""
    vector = get_openai_embedding("yPm8Q~CZ54Jiae2VliOVmFdVHCKswXScw9jQha4z", user_query)
    vector = np.array(vector).astype(np.float32).tobytes()
    query = VectorQuery(
        vector=vector,
        vector_field_name="embedding",
        num_results=num_results,
        return_fields=["caption", "subtitle", "combined"],
    )
    if filters:
        query.set_filter(filters)
    return query


def make_ft_query(text_field: str, user_query: str, num_results: int) -> TextQuery:
    """Generate a Redis full-text query given a user query string."""
    return TextQuery(
        text=user_query,
        text_field_name=text_field,
        text_scorer="BM25",
        num_results=num_results,
        return_fields=["caption", "subtitle", "combined"],
    )

# %%
from typing import List, Dict, Any


def weighted_rrf(
    user_query: str,
    alpha: float = 0.5,
    num_results: int = 4,
    k: int = 60,
) -> List[Dict[str, Any]]:
    """Implemented client-side RRF after querying from Redis."""
    # Create the vector query
    vector_query = make_vector_query(user_query, num_results=len(data))

    # Create the full-text query
    full_text_query = make_ft_query("caption", user_query, num_results=len(data))

    # Run queries individually
    vector_query_results = index.query(vector_query)
    full_text_query_results = index.query(full_text_query)

    # Extract titles from results
    vector_titles = [movie["title"] for movie in vector_query_results]
    full_text_titles = [movie["title"] for movie in full_text_query_results]

    # Perform weighted RRF
    return fuse_rankings_rrf(vector_titles, full_text_titles, weights=[alpha, 1-alpha], k=k)[:num_results]
