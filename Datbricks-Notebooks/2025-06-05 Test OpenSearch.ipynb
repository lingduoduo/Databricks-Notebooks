# %%
# !pip install opensearch-py
# !pip install requests_auth_aws_sigv4 requests-aws4auth
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/371.5 kB ? eta -:--:--
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/371.5 kB ? eta -:--:--
#      ━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.2/371.5 kB 1.1 MB/s eta 0:00:01
#      ━━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.2/371.5 kB 1.1 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━━━━ 225.3/371.5 kB 2.0 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 371.5/371.5 kB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/129.8 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.8/129.8 kB 13.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/64.8 kB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.8/64.8 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/157.7 kB ? eta -:--:--
# ...

# %%
dbutils.library.restartPython()

# %%
import boto3

boto3_session = boto3.Session(
    botocore_session=dbutils.credentials.getServiceCredentialsProvider(
        'service-cred-nas-lifion_ml-sdq-dit'
    )
)

sts = boto3_session.client('sts')
identity = sts.get_caller_identity()
print(identity)
# Out:
# {'UserId': 'AROA2JWRYV3XYBCADKAZL:m=I8KKQZJQQ5S0imHA@6BusA,s=usGnVB@cRNeD0KMr1uTxkw', 'Account': '708035784431', 'Arn': 'arn:aws:sts::708035784431:assumed-role/dit-uc-nas-lifion_ml-sdq-cdktf/m=I8KKQZJQQ5S0imHA@6BusA,s=usGnVB@cRNeD0KMr1uTxkw', 'ResponseMetadata': {'RequestId': '19880640-9755-400d-8f23-f84da700349f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'x-amzn-requestid': '19880640-9755-400d-8f23-f84da700349f', 'content-type': 'text/xml', 'content-length': '535', 'date': 'Mon, 23 Jun 2025 20:21:58 GMT'}, 'RetryAttempts': 0}}

# %%
import boto3

boto3_session = boto3.Session(
    botocore_session=dbutils.credentials.getServiceCredentialsProvider(
        'service-cred-nas-lifion_ml-sdq-dit'
    )
)
s3_client = boto3_session.client('s3')

# %%
import pandas as pd
from datetime import datetime

bucket_name = "ml-models-bucket-appbuild-02"

s3_client.list_objects(Bucket=bucket_name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File <command-5105651380917941>, line 6
#       2 from datetime import datetime
#       4 bucket_name = "ml-models-bucket-appbuild-02"
# ----> 6 s3_client.list_objects(Bucket=bucket_name)
#
# NameError: name 's3_client' is not defined

# %% [markdown]
# ### AWSSigV4

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection
import json
from requests_auth_aws_sigv4 import AWSSigV4

# %% [markdown]
# https://bitbucket.es.ad.adp.com/projects/TOT/repos/hro-hrbp-augmentation/browse/opensearch/OpenSearch.py#106,112,128,130,143,151,261,274,291

# %%
MAX_ERRORS = 10
OPENSEARCH_DOMAIN_FQDN = 'vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com'

HEADERS = {
    'Content-Type': 'application/json',
    'Accept-Encoding': 'gzip',
}
auth = AWSSigV4('es', region='us-east-1')
client = OpenSearch(
    hosts=[{'host': OPENSEARCH_DOMAIN_FQDN, 'port':443}],
    http_auth=auth,
    use_ssl=True,
    connection_class=RequestsHttpConnection
)

# %%
print(client.ping())
# Out:
# WARNING:opensearch:HEAD https://vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com:443/ [status:N/A request:10.079s]
# Traceback (most recent call last):
#   File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-bcc174b5-5104-46df-9d8d-e9713cd39a55/lib/python3.11/site-packages/urllib3/connectionpool.py", line 534, in _make_request
#     response = conn.getresponse()
#                ^^^^^^^^^^^^^^^^^^
#   File "/local_disk0/.ephemeral_nfs/envs/pythonEnv-bcc174b5-5104-46df-9d8d-e9713cd39a55/lib/python3.11/site-packages/urllib3/connection.py", line 565, in getresponse
#     httplib_response = super().getresponse()
#                        ^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/http/client.py", line 1395, in getresponse
#     response.begin()
#   File "/usr/lib/python3.11/http/client.py", line 325, in begin
#     version, status, reason = self._read_status()
#                               ^^^^^^^^^^^^^^^^^^^
# ...

# %%
# %sh curl -s ifconfig.me
# Out:
# <!-- IE friendly error message walkround.
#      if error message from server is less than
#      512 bytes IE v5+ will use its own error
#      message instead of the one returned by
#      server.                                 -->
#
#
#
#
#
#
# <!DOCTYPE html>
# <html lang="en">
#     <head>
#         <meta charset="UTF-8">
#         <meta http-equiv="X-UA-Compatible" content="IE=8; IE=EDGE">
#         <meta name="viewport" content="width=device-width, initial-scale=1">
#         <style type="text/css">
#             body {
#                 height: 100%;
#                 font-family: Helvetica, Arial, sans-serif;
#                 color: #6a6a6a;
#                 margin: 0;
#                 display: flex;
#                 align-items: center;
#                 justify-content: center;
#             }
# ...

# %% [markdown]
# https://jira.service.tools-pi.com/plugins/servlet/desk/portal/541/SGDPSD-13723

# %% [markdown]
# ### AWS4Auth

# %%
host = 'vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com'
region = 'us-east-1'
service = 'es'

# %%
import boto3
from requests_aws4auth import AWS4Auth

credentials = boto3.Session(
    botocore_session=dbutils.credentials.getServiceCredentialsProvider('service-cred-nas-lifion_ml-sdq-dit')
                            ).get_credentials()
esawsauth = AWS4Auth(credentials.access_key, credentials.secret_key, region, service, session_token=credentials.token)

# %% [markdown]
# ### Connect to Lyric Open Search

# %%
# %sh

curl -v https://vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com


# Elastic url: lyric-eck-poc.us.caas.oneadp.com
# Kibana url: lyric-eck-poc-kb.us.caas.oneadp.com
# Username: elastic
# Password: 9Kmh3L9t1Vf3zQ3594t9oARj
# Out:
# *   Trying 10.210.81.201:443...
# * connect to 10.210.81.201 port 443 failed: Connection timed out
# *   Trying 10.210.82.75:443...
# * After 83263ms connect time, move on!
# * connect to 10.210.82.75 port 443 failed: Connection timed out
# * Failed to connect to vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com port 443 after 216738 ms: Connection timed out
# * Closing connection 0
# curl: (28) Failed to connect to vpc-int-use1-opensearch-ml-c32nkeiaudrckcr2ep7jghefje.us-east-1.es.amazonaws.com port 443 after 216738 ms: Connection timed out

# %%
from opensearchpy import OpenSearch, RequestsHttpConnection

client = OpenSearch(
hosts= [{'host': host, 'port': 443}],
http_auth= esawsauth, # admin and credentials
use_ssl=True,
verify_certs=True,
connection_class= RequestsHttpConnection,
pool_maxsize=20
)

# %%
print(client.ping())
# Out:
# True

# %%
indices = client.indices.get(index='*')
indices
# Out:
# {'.kibana_1': {'aliases': {'.kibana': {}},
#   'mappings': {'dynamic': 'strict',
#    '_meta': {'migrationMappingPropertyHashes': {'augment-vis': '88f930f6b43c089a12bfc276c359d1eb',
#      'application_usage_daily': '43b8830d5d0df85a6823d290885fc9fd',
#      'visualization': 'f819cf6636b75c9e76ba733a0c6ef355',
#      'observability-search': '638ae3ab28e5faf2e02f00dd8091abaf',
#      'references': '7997cf5a56cc02bdc9c93361bde732b0',
#      'type': '2f4316de49999235636386fe51dc06c1',
#      'sample-data-telemetry': '7d3cfeb915303c9641c59681967ffeb4',
#      'search': '43012c7ebc4cb57054e0a490e4b43023',
#      'originId': '2f4316de49999235636386fe51dc06c1',
#      'application_usage_totals': '3d1b76c39bfb2cc8296b024d73854724',
#      'updated_at': '00da57df13e94e9d98437d13ace4bfe0',
#      'dql-telemetry': 'd12a98a6f19a2d273696597547e064ee',
#      'search-telemetry': '3d1b76c39bfb2cc8296b024d73854724',
#      'integration-instance': '17ab914d1f92a5b03bbb194651c23b1c',
# ...

# %%
# Check index
INDEX_NAME = 'search-data-titan-embed-3'
query={
    "query": {
        "match_all": {}
    }
}
print(client.search(index=INDEX_NAME, body=query))
print("-"*50)
# Out:
# {'took': 1858, 'timed_out': False, '_shards': {'total': 5, 'successful': 5, 'skipped': 0, 'failed': 0}, 'hits': {'total': {'value': 184, 'relation': 'eq'}, 'max_score': 1.0, 'hits': [{'_index': 'search-data-titan-embed-3', '_id': '4XmnRpYBQcDw23OdoLqL', '_score': 1.0, '_source': {'id': '8a5610ad-0f84-40c6-971f-404a5f13cde3', 'description_s': 'How do float holidays work?', 'description_t': 'How do float holidays work?', 'description_txt_edgeNgram': 'How do float holidays work?', '_lw_milvus_id_l': 4605368567017393334, 'type_t': 'qna', 'type_s': 'qna', 'clientId_s': '', 'clientId_t': '', 'metadata_s': '{"question":"How do float holidays work?","answer":"Full-time employees receive 3 paid float holidays per year to use for personal reasons with manager approval."}', 'nodeId_t': '8a5610ad-0f84-40c6-971f-404a5f13cde3', 'nodeId_s': '8a5610ad-0f84-40c6-971f-404a5f13cde3', 'metadata_t': '{"question":"How do float holidays work?","answer":"Full-time employees receive 3 paid float holidays per
# ...
