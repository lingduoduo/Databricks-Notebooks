# %%
from datetime import datetime, timedelta
import os
import pandas as pd

local_path = "data/"
local_click_file = "search_click.csv"
local_item_file = "item_desc.csv"
local_click_ts_file = "search_click_ts.csv"
local_item_clientid_file = "item_desc_clientid.csv"

# %%
def query_search_with_click(output_path=local_click_file, output_file=local_click_file, date_range=7):
    """
    Export search and click data for the last `date_range` days to a CSV file.

    Args:
        output_path (str): The file path to save the CSV.
        date_range (int): The number of days to look back for data.
    """
    end_date = datetime.now() - timedelta(days=1)
    if date_range > 7:
        date_range = 7
    start_date = max(datetime(2025, 3, 18), end_date - timedelta(days=date_range))
    date_range = (end_date - start_date).days

    # Query the data
    query = f"""
        SELECT _token_associate_id AS user_id, 
               click_object_id AS item_id, 
               SUM(click) AS rating
        FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
        GROUP BY 1, 2
    """
    df = spark.sql(query)
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    df.toPandas().to_csv('/'.join([output_path, output_file]), index=False)

# %%
query_search_with_click(output_path=local_path, output_file=local_click_file, date_range=7)

# %%
def query_click_description(output_path=local_path, output_file=local_item_file):
    """
    Export click item data to a CSV file.

    Args:
        output_path (str): The file path to save the CSV.
    """
    # SQL query to fetch click item descriptions
    query = """
        SELECT click_object_id AS item_id, 
               click_details_caption AS title  
        FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
        GROUP BY click_object_id, click_details_caption
    """
    # Execute the query and save the result to a CSV file
    df = spark.sql(query)
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    df.toPandas().to_csv('/'.join([output_path, output_file]), index=False)

# %%
query_click_description(output_path=local_path, output_file=local_item_file)

# %%
def query_search_with_click_ts(output_path=local_path, output_file=local_click_ts_file):
    """
    Export click item data to a CSV file.

    Args:
        output_path (str): The file path to save the CSV.
    """
    # SQL query to fetch click item descriptions
    query = """
        SELECT _token_associate_id AS user_id,
                click_object_id AS item_id,
                to_unix_timestamp(time_stamp, "yyyy-MM-dd\'T\'HH:mm:ss.SSS\'Z\'") AS unix_time_stamp,
                SUM(click) AS rating
            FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
            WHERE click_object_id IS NOT NULL
            GROUP BY 1, 2, 3;
    """
    # Execute the query and save the result to a CSV file
    df = spark.sql(query)
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    df.toPandas().to_csv('/'.join([output_path, output_file]), index=False)

# %%
query_search_with_click_ts(output_path=local_path, output_file=local_click_ts_file)

# %%
def query_click_description_clientid(output_path=local_path, output_file=local_item_clientid_file):
    """
    Export click item data to a CSV file.

    Args:
        output_path (str): The file path to save the CSV.
    """
    # SQL query to fetch click item descriptions
    query = """
        SELECT click_object_id AS item_id, 
               click_details_caption AS title,
               click_client_id
        FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
        WHERE click_object_id IS NOT NULL
        GROUP BY click_object_id, click_details_caption, click_client_id
    """
    # Execute the query and save the result to a CSV file
    df = spark.sql(query)
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    df.toPandas().to_csv('/'.join([output_path, output_file]), index=False)

# %%
query_click_description_clientid(output_path=local_path, output_file=local_item_clientid_file)

# %%
def load_click_data(input_path=local_path, input_file=local_click_file):
    """
    Load click data from a CSV file.

    Args:
        input_path (str): The file path to load the CSV from.

    Returns:
        pandas.DataFrame: The loaded click data.
    """
    df = pd.read_csv('/'.join([input_path, input_file]),
                       skiprows=0,
                       names=["user_id", "item_id", "rating"],
                       dtype={"user_id": str, "item_id": str, "rating": str}
                       )
    df["rating"] = pd.to_numeric(df['rating'], errors='coerce').fillna(0).astype(int)
    print(len(df))
    return df

# %%
df = load_click_data(input_path=local_path, input_file=local_click_file)
# Out:
# 513

# %%
def load_item_data(input_path=local_item_file, input_file=local_item_file):
    """
    Load item data from a CSV file.

    Args:
        input_path (str): The file path to load the CSV from.

    Returns:
        pandas.DataFrame: The loaded item data.
    """
    df = pd.read_csv('/'.join([input_path, input_file]),
                       skiprows=0,
                       names=["item_id", "title"],
                       dtype={"item_id": str, "title": str}
                       )
    print(len(df))
    return df

# %%
data = load_item_data(input_path=local_path, input_file=local_item_file)
# Out:
# 211

# %%
def query_click_description_clientid(output_path=local_path, output_file=local_item_clientid_file):
    """
    Export click item data to a CSV file.

    Args:
        output_path (str): The file path to save the CSV.
    """
    # SQL query to fetch click item descriptions
    query = """
        SELECT click_object_id AS item_id, 
               click_details_caption AS title,
               click_client_id
        FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
        WHERE click_object_id IS NOT NULL
        GROUP BY click_object_id, click_details_caption, click_client_id
    """
    # Execute the query and save the result to a CSV file
    df = spark.sql(query)
    if not os.path.exists(output_path):
        os.makedirs(output_path)
    df.toPandas().to_csv('/'.join([output_path, output_file]), index=False)

# %%
df = spark.sql(f"""
SELECT
    view._token_associate_id AS user_id,
    view._id AS item_id,
    view.click AS rating
FROM
    onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click AS view
JOIN
    (
        SELECT
            traceId,
            MAX(resPos) AS max_resPos
        FROM
            onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
        WHERE
            click_object_id IS NOT NULL
        GROUP BY
            traceId
    ) AS click
ON
    view.traceId = click.traceId
    AND view.resPos <= click.max_resPos
 """)
df.toPandas().to_csv("data/view_click.csv", index=False)

# %%
df = spark.sql(f"""
        SELECT DISTINCT
            _token_associate_id as user_id,
            LAST_VALUE(user_agent) OVER (PARTITION BY _token_associate_id ORDER BY time_stamp ROWS BETWEEN UNBOUNDED PRECEDING AND UNBOUNDED FOLLOWING) AS last_user_agent
        FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click 
 """)
df.toPandas().to_csv("data/user_desc.csv", index=False)

# %%
# !pip install torch torchvision
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: torch in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (2.6.0)
# Collecting torchvision
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/36/63/0722e153fd27d64d5b0af45b5c8cb0e80b35a68cf0130303bc9a8bb095c7/torchvision-0.21.0-cp312-cp312-manylinux1_x86_64.whl (7.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/7.2 MB ? eta -:--:--
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/7.2 MB 3.4 MB/s eta 0:00:03
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/7.2 MB 4.1 MB/s eta 0:00:02
#      ━━━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.8/7.2 MB 8.6 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━━━ 3.3/7.2 MB 24.9 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╸ 7.2/7.2 MB 44.8 MB/s eta 0:00:01
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.2/7.2 MB 39.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.10.0 in /databricks/python3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (74.0.0)
# Requirement already satisfied: sympy==1.13.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /databricks/python3/lib/python3.12/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-281db5e6-3ea7-44a2-a207-9eaa481aabe0/lib/python3.12/site-packages (from jinja2->torch) (3.0.2)
# Installing collected packages: torchvision
# Successfully installed torchvision-0.21.0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %% [markdown]
# ### Preprocessing and Cleaning the Data

# %%
query = f"""
    SELECT _token_associate_id AS user_id, 
            click_object_id AS item_id, 
            SUM(click) AS rating
    FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
    WHERE click_object_id is not null
    GROUP BY 1, 2
"""
df = spark.sql(query)

# %%
from pyspark.sql import functions as F

# Calculate the mean of the ratings column
ratings_mean = df.groupBy().avg('rating').collect()[0][0]
print(f"Mean rating: {ratings_mean}")

# Modify all ratings less than the mean to 0 and greater than the mean to 1 and using a UDF to apply the transformation
modify_rating_udf = F.udf(lambda x: 0 if x < ratings_mean else 1, 'int')
relevant_df = df.withColumn('rating', modify_rating_udf('rating'))

# Rename rating to label
relevant_df = relevant_df.withColumnRenamed('rating', 'label')

# Displaying the dataframe
display(relevant_df)
# Out:
# Mean rating: 1.1316062176165802
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>item_id</th><th>label</th></tr></thead><tbody><tr><td>3829c698-e618-47a4-a560-264450c55e9b</td><td>null</td><td>0</td></tr><tr><td>570ade82-fdef-4be5-9193-7c8869834bef</td><td>cf885bac-24ce-45fe-85ec-a8e578890b42</td><td>1</td></tr><tr><td>319ae8a7-9ab6-4c19-9cdd-8d80d1c9d12b</td><td>f6676d24a90242689b35c45333ef8d40</td><td>0</td></tr><tr><td>7864e425-bbea-4537-9425-f807f60bf131</td><td>73c5155e042b4f228ce1822c51e52fed</td><td>1</td></tr><tr><td>818c47d0-4ffd-4e41-a9c0-4430771bfe28</td><td>null</td><td>0</td></tr><tr><td>e9252582-aeb7-4993-8c17-a975e520599b</td><td>null</td><td>0</td></tr><tr><td>7c287dcc-9efb-40e6-9fa9-94f92c0dd2d5</td><td>null</td><td>0</td></tr><tr><td>3d365bbc-267e-42c2-ad46-33635a96c841</td><td>b29ed30996ac49c99bef20bd295ef677</td><td>1</td></tr><tr><td>5cddd9c3-d785-4a8f-b78e-1a569c76596e</td><td>b3cc3ceac4d24c2e843aa13078bd2f8e</td><td>0</td></tr><tr><td>8b215b29-f375-4561-a792-915a4b23315d</td><td>417ff59ee1c442b0bffb43ec4847a908</td><td>0</td></tr><tr><td>321d47b1-78de-438f-b6c3-2479e06d3bd2</td><td>f0b0e94638cd4ffb8ee446fbca6c9086</td><td>1</td></tr><tr><td>5fc03d75-2ac8-4143-99f5-d7e43a7673a9</td><td>60c2dd26439a47a09c01ef205baec43d</td><td>0</td></tr><tr><td>da20163b-ee16-4c21-af62-cdc31d36b2c2</td><td>null</td><td>0</td></tr><tr><td>319ae8a7-9ab6-4c19-9cdd-8d80d1c9d12b</td><td>55f6dd02c4da4ec59ecaa3543f860b6e</
# %%
# Split the dataframe into train, test, and validation sets
train_df, validation_df, test_df = relevant_df.randomSplit([0.7, 0.2, 0.1], seed=42)

# Show the count of each split to verify the distribution
print(f"Training Dataset Count: {train_df.count()}")
print(f"Validation Dataset Count: {validation_df.count()}")
print(f"Test Dataset Count: {test_df.count()}")
# Out:
# Training Dataset Count: 719
# Validation Dataset Count: 172
# Test Dataset Count: 74

# %%
# !conda install pytorch cudatoolkit=11.3 -c pytorch-nightly -y
# Out:
# /bin/bash: line 1: conda: command not found

# %%
# !pip3 install torchrec-nightly
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Collecting torchrec-nightly
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/b1/ce/da1e04aa387fdfc28e0541bd9fda735b9f31e346fd18b85c1a1cb8243244/torchrec_nightly-2023.8.20-py310-none-any.whl (390 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 390.3/390.3 kB 4.3 MB/s eta 0:00:00
# Collecting iopath (from torchrec-nightly)
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/72/73/b3d451dfc523756cf177d3ebb0af76dc7751b341c60e2a21871be400ae29/iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.3 MB/s eta 0:00:00
# done
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.12/site-packages (from torchrec-nightly) (1.5.3)
# Requirement already satisfied: tabulate in /databricks/python3/lib/python3.12/site-packages (from torchrec-nightly) (0.9.0)
# Requirement already satisfied: torchmetrics in /databricks/python3/lib/python3.12/site-packages (from torchrec-nightly) (1.6.0)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from torchrec-nightly) (4.66.4)
# Collecting fbgemm-gpu-nightly-cpu (from torchrec-nightly)
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/42/8a/24fca63eb6a890e57a0728eeeb6ad0fac272bcc92d0cf38927f1c4b805d1/fbgemm_gpu_nightly_cpu-2025.3.26-cp312-cp312-manylinux_2_28_x86_64.whl (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 29.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from fbgemm-gpu-nightly-cpu->torchrec-nightly) (1.26.4)
# Requirement already satisfied: typing_extensions in /databricks/python3/lib/python3.12/site-packages (from iopath->torchrec-nightly) (4.11.0)
# Requirement already satisfied: portalocker in /databricks/python3/lib/python3.12/site-packages (from iopath->torchrec-nightly) (2.10.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->torchrec-nightly) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /databricks/python3/lib/python3.12/site-packages (from pandas->torchrec-nightly) (2024.1)
# Requirement already satisfied: packaging>17.1 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics->torchrec-nightly) (24.1)
# Requirement already satisfied: torch>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics->torchrec-nightly) (2.5.1+cpu)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics->torchrec-nightly) (0.11.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.8.0->torchmetrics->torchrec-nightly) (74.0.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas->torchrec-nightly) (1.16.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics->torchrec-nightly) (3.13.1)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics->torchrec-nightly) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics->torchrec-nightly) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics->torchrec-nightly) (2023.5.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch>=2.0.0->torchmetrics->torchrec-nightly) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.0.0->torchmetrics->torchrec-nightly) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch>=2.0.0->torchmetrics->torchrec-nightly) (2.1.3)
# Building wheels for collected packages: iopath
# done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31532 sha256=9cc0d444cd5a502e8425a23442c3f29b5ca72c64717406115762f24a955a2ee6
#   Stored in directory: /root/.cache/pip/wheels/a0/7d/15/9961f743665708fde84129dde57994f5a629fe674ed46db6d1
# Successfully built iopath
# Installing collected packages: iopath, fbgemm-gpu-nightly-cpu, torchrec-nightly
# Successfully installed fbgemm-gpu-nightly-cpu-2025.3.26 iopath-0.1.10 torchrec-nightly-2023.8.20
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
# %pip install scikit-learn
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: scikit-learn in /databricks/python3/lib/python3.12/site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.12/site-packages (from scikit-learn) (2.2.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
query = f"""
    SELECT _token_associate_id AS user_id, 
            click_object_id AS item_id, 
            SUM(click) AS rating
    FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
    GROUP BY 1, 2
"""
df_click = spark.sql(query).toPandas()

# %%
import pandas as pd

# %%
MAX_USERS = 500

# %%
from sklearn import preprocessing
item_id_encoder = preprocessing.LabelEncoder()
user_id_encoder = preprocessing.LabelEncoder()

# %%
user_id_encoder .fit(df_click['user_id'])
len(user_id_encoder.classes_)
# Out:
# 286

# %%
item_id_encoder .fit(df_click['item_id'])
len(item_id_encoder.classes_)
# Out:
# 278

# %%
data = dict()
for idx, row in df_click.iterrows():
  if user_id_encoder.transform([row['user_id']])[0] not in data:
    data[user_id_encoder.transform([row['user_id']])[0]] = list(item_id_encoder.transform([row['item_id']]))
  else:
    data[user_id_encoder.transform([row['user_id']])[0]].extend(list(item_id_encoder.transform([row['item_id']])))

# %%
data
# Out:
# {54: [277, 163, 191],
#  85: [225, 277, 112, 231, 42, 0, 83, 143, 191, 164],
#  44: [265, 76, 277, 240, 22, 80],
#  129: [114,
#   76,
#   166,
#   205,
#   151,
#   119,
#   277,
#   48,
#   190,
#   144,
#   259,
#   210,
#   33,
#   153,
#   126,
#   87,
#   276,
#   227,
#   253,
#   275,
#   239,
#   256,
#   88,
#   204,
#   164,
#   191,
#   255,
#   258],
#  142: [277, 166, 48, 151, 191, 183, 23, 133, 67],
#  262: [277, 189],
#  138: [277],
#  60: [190, 277, 45],
#  94: [191, 277, 275],
#  152: [54,
#   151,
#   15,
#   141,
#   6,
#   277,
#   247,
#   78,
#   191,
#   87,
#   93,
#   19,
#   77,
#   193,
#   31,
#   169,
#   96,
#   165],
#  45: [259,
#   138,
#   22,
#   166,
#   114,
#   87,
#   190,
#   256,
#   277,
#   191,
#   51,
#   79,
#   84,
#   275,
#   142,
#   220,
#   127,
#   30,
#   169,
#   58,
#   8,
#   48,
#   16,
#   40,
#   56,
#   204,
#   151,
#   93,
#   202,
#   196,
#   47,
#   71,
#   233,
#   119,
#   239,
#   213,
#   108,
#   276,
#   184,
#   63,
#   109,
#   181,
#   106,
#   137,
#   228,
#   163,
#   122,
#   107,
#   133,
#   160,
#   64,
#   136,
#   172,
#   244,
#   139,
#   156,
#   130,
#   192,
#   96,
#   273,
#   208,
#   89,
#   24,
#   175,
#   223,
#   174,
#   110],
#  97: [87, 277],
#  246: [277, 233],
#  235: [189, 277],
#  100: [11, 50, 153, 268, 277, 191, 114, 151, 45, 44, 256],
#  52: [277, 48, 162, 175],
#  73: [229, 48, 275, 277, 87, 148, 79, 64, 190, 196],
#  51: [276, 277, 123, 243],
#  231: [277,
#   29,
#   161,
#   232,
#   4,
#   48,
#   27,
#   131,
#   185,
#   146,
#   152,
#   191,
#   199,
#   95,
#   238,
#   37,
#   89,
#   186,
#   121,
#   180,
#   97,
#   147,
#   257],
#  1: [20, 277],
#  274: [190, 277],
#  252: [277, 204],
#  68: [190, 151, 48, 277, 268, 3],
#  96: [259, 92, 277, 43, 151, 48, 269],
#  137: [277, 26, 249, 128, 200],
#  201: [277],
#  126: [275, 277, 20],
#  90: [87, 113, 277, 151, 84, 99, 144, 93, 90],
#  102: [3, 277, 48, 148, 94],
#  267: [277, 144, 87, 127],
#  203: [277, 250],
#  106: [277, 190],
#  150: [87, 277, 48, 135],
#  282: [277],
#  22: [183, 277, 127, 133, 166],
#  256: [277, 87, 53, 20, 127, 162, 259, 123, 111],
#  172: [277, 87, 48, 151, 79],
#  175: [277],
#  104: [277],
#  195: [277, 48, 275, 191, 175, 195, 136, 179, 150, 133],
#  278: [268, 277],
#  119: [277, 87],
#  261: [127, 277],
#  37: [277, 10],
#  271: [210, 190, 277, 22, 275, 114, 194, 239, 88, 151, 204, 191, 35, 87],
#  174: [277],
#  169: [277],
#  136: [87, 277, 191, 79],
#  110: [277, 264],
#  145: [277],
#  211: [74, 277],
#  75: [87, 113, 79, 277, 56, 84, 127, 166],
#  79: [277, 87, 252, 127, 107, 84, 79, 169, 67, 160, 56],
#  259: [277, 84],
#  93: [277],
#  148: [277],
#  153: [277],
#  29: [277],
#  77: [277, 275, 263, 35, 183],
#  17: [49, 277, 173, 212, 46, 198, 70, 21, 275],
#  173: [277, 34, 189],
#  194: [67, 277, 151, 275],
#  35: [277, 263, 182, 262],
#  111: [277, 264],
#  121: [134, 277, 123],
#  247: [277, 151, 59, 66],
#  128: [277, 67, 203, 243, 41, 87, 132],
#  147: [277, 9, 101],
#  209: [48, 262, 7, 277, 93, 221, 238, 259, 179, 224, 191],
#  253: [277, 189],
#  144: [154, 277, 276, 275, 20, 2, 201, 261, 57, 169, 87, 48, 22],
#  55: [277],
#  158: [277],
#  200: [162, 277, 154, 116, 191],
#  16: [151, 277, 246, 191, 241],
#  84: [277],
#  205: [1,
#   277,
#   272,
#   159,
#   75,
#   266,
#   13,
#   218,
#   60,
#   104,
#   140,
#   145,
#   39,
#   170,
#   52,
#   86,
#   68,
#   166,
#   55,
#   69,
#   79,
#   215,
#   12,
#   216,
#   168,
#   73,
#   117,
#   226,
#   118,
#   115,
#   91,
#   235,
#   167,
#   183,
#   123],
#  186: [151, 277, 87],
#  182: [277, 164, 162],
#  230: [154, 277],
#  245: [277, 191, 164, 276],
#  276: [277, 123, 87, 162],
#  185: [111, 277, 154],
#  105: [191, 277, 93, 166],
#  164: [277, 175],
#  15: [127],
#  225: [277, 190],
#  218: [277, 88, 22, 151],
#  117: [277, 166, 162],
#  25: [277],
#  191: [277],
#  131: [277, 210, 162, 48, 123, 275, 89],
#  168: [277, 123, 162, 210],
#  57: [277, 230],
#  72: [277, 133],
#  198: [162, 277, 123, 191],
#  46: [191, 277, 48, 188],
#  67: [253, 277, 3, 149, 198, 125, 206, 158, 251, 87, 189, 234],
#  250: [277],
#  5: [277],
#  244: [277, 191],
#  159: [277, 191],
#  228: [138, 87, 277, 133],
#  264: [277],
#  42: [277],
#  279: [277, 214],
#  180: [277, 84, 151],
#  98: [277, 154],
#  210: [189, 277, 103],
#  81: [277, 18, 189, 48, 81, 105],
#  133: [277, 191],
#  118: [242, 277],
#  149: [65, 256, 277, 21, 46, 22],
#  151: [277, 3],
#  125: [277, 154],
#  241: [277, 22],
#  78: [277, 190, 175, 64],
#  277: [195, 277],
#  36: [277, 151, 191],
#  4: [277, 189],
#  157: [123, 277],
#  192: [277, 111, 48],
#  114: [277],
#  6: [20, 277],
#  214: [154, 277, 101, 259],
#  71: [277, 198, 253, 212],
#  181: [277],
#  32: [277, 32, 48],
#  284: [277, 85],
#  184: [151, 190, 196, 277],
#  285: [277, 61, 162],
#  122: [277],
#  89: [162, 277, 120],
#  190: [277, 175, 100, 24],
#  199: [277, 84],
#  237: [277, 275, 84],
#  21: [277, 101, 164],
#  50: [114, 277, 84, 22, 82, 151],
#  162: [253, 198, 277, 124],
#  166: [277],
#  254: [277, 164, 171],
#  120: [277, 64, 274, 187, 157, 178, 270],
#  88: [154, 277, 191, 275, 162],
#  86: [277, 191, 162],
#  222: [277, 191, 127],
#  167: [277, 129],
#  41: [277],
#  115: [277],
#  139: [277, 72, 191],
#  74: [277, 256],
#  56: [277, 21, 36, 212, 49],
#  140: [277, 87],
#  43: [277],
#  80: [277],
#  236: [277, 197],
#  70: [277, 22, 275],
#  109: [277, 211],
#  238: [190, 277, 82, 275],
#  221: [48, 277, 154],
#  91: [79],
#  266: [277],
#  257: [277, 265, 207],
#  34: [277],
#  82: [277, 195, 102, 149, 198],
#  270: [277, 123],
#  65: [277],
#  269: [7, 277],
#  224: [259],
#  273: [164, 277],
#  31: [156, 277],
#  226: [277],
#  268: [277, 234, 198],
#  101: [277],
#  59: [277, 263],
#  196: [277],
#  146: [191, 277, 5],
#  9: [214, 189, 277, 162, 236],
#  154: [277, 191, 164],
#  48: [114, 127, 277, 275, 166, 162, 185],
#  23: [277],
#  30: [277],
#  240: [79, 277, 93],
#  204: [191, 277, 107],
#  124: [87, 277],
#  24: [277],
#  161: [277, 189],
#  11: [277],
#  188: [3, 277],
#  176: [275, 277],
#  258: [277, 176],
#  255: [277, 275],
#  107: [154, 277],
#  265: [277],
#  7: [277, 20],
#  127: [277, 144],
#  229: [277, 84, 67, 155, 87, 138],
#  83: [277, 151],
#  179: [277, 191],
#  61: [277, 79, 151],
#  69: [277, 209],
#  219: [277, 191],
#  165: [191, 277],
#  234: [277],
#  215: [136, 277],
#  0: [277, 166, 35, 81, 48, 62, 185, 183, 80, 3],
#  207: [277],
#  170: [277, 166, 35],
#  217: [277, 151, 275],
#  187: [277, 49],
#  99: [277, 276, 191, 17],
#  216: [277],
#  62: [123, 277, 154],
#  275: [277, 222, 38, 237],
#  14: [277, 191],
#  132: [185, 164, 277, 271, 238],
#  2: [277, 164],
#  163: [277, 164],
#  12: [277],
#  13: [234],
#  95: [277, 154],
#  208: [277],
#  103: [277, 3],
#  28: [277, 248, 151, 217, 22, 177],
#  239: [277],
#  135: [277],
#  26: [277],
#  58: [277],
#  40: [277, 98],
#  197: [154, 277],
#  141: [277],
#  123: [277],
#  134: [277, 28],
#  156: [277],
#  18: [277, 84],
#  38: [277, 154, 219],
#  233: [277, 3],
#  155: [277, 191],
#  171: [277],
#  227: [277],
#  280: [277, 267],
#  113: [277],
#  272: [277],
#  10: [277, 275],
#  63: [277, 113],
#  39: [277],
#  243: [277, 84],
#  183: [277, 162],
#  64: [277, 195],
#  8: [277, 238, 191],
#  249: [277],
#  3: [277, 123],
#  33: [277],
#  143: [277, 189],
#  130: [277],
#  92: [277],
#  177: [277, 275],
#  242: [277],
#  193: [277],
#  213: [259],
#  202: [201],
#  19: [48, 245, 277, 3],
#  232: [48, 277, 210],
#  116: [277, 114],
#  251: [277, 38],
#  248: [277],
#  260: [277, 48],
#  263: [277, 49],
#  189: [277],
#  283: [5, 277],
#  49: [277],
#  20: [277],
#  212: [277, 25],
#  76: [277],
#  53: [277, 123],
#  206: [93, 277],
#  160: [136, 277],
#  223: [277, 191],
#  66: [277, 49],
#  27: [275, 277],
#  281: [260, 277, 254, 14, 166, 183],
#  220: [277, 191],
#  108: [277],
#  47: [277],
#  112: [277, 127],
#  178: [277],
#  87: [198]}

# %%
# %pip install --trusted-host artifactory.us.caas.oneadp.com -i https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/ torch torchvision torchrec fbgemm-gpu
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: torch in /databricks/python3/lib/python3.12/site-packages (2.5.1+cpu)
# Requirement already satisfied: torchvision in /databricks/python3/lib/python3.12/site-packages (0.20.1+cpu)
# Requirement already satisfied: torchrec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: fbgemm-gpu in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /databricks/python3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch) (2023.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (74.0.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /databricks/python3/lib/python3.12/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: torchmetrics==1.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (from torchrec) (1.0.3)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from torchrec) (4.66.4)
# Requirement already satisfied: pyre-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (from torchrec) (0.0.32)
# Requirement already satisfied: iopath in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (from torchrec) (0.1.10)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (24.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (0.11.9)
# Requirement already satisfied: portalocker in /databricks/python3/lib/python3.12/site-packages (from iopath->torchrec) (2.10.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: typing-inspect in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (from pyre-extensions->torchrec) (0.9.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from typing-inspect->pyre-extensions->torchrec) (1.0.0)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install --upgrade pip fbgemm-gpu-nightly-cpu
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: pip in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (25.0.1)
# Requirement already satisfied: fbgemm-gpu-nightly-cpu in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (2025.3.26)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from fbgemm-gpu-nightly-cpu) (1.26.4)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# !pip3 install --pre torch --index-url https://download.pytorch.org/whl/nightly/cu121 -U
# !pip3 install fbgemm_gpu --index-url https://download.pytorch.org/whl/nightly/cu121
# !pip3 install torchmetrics==1.0.3
# !pip3 install torchrec --index-url https://download.pytorch.org/whl/nightly/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu121
# Requirement already satisfied: torch in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (2.6.0)
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))': /whl/nightly/cu121/torch/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))': /whl/nightly/cu121/torch/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))': /whl/nightly/cu121/torch/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))': /whl/nightly/cu121/torch/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))': /whl/nightly/cu121/torch/
# Could not fetch URL https://download.pytorch.org/whl/nightly/cu121/torch/: There was a problem confirming the ssl certificate: HTTPSConnectionPool(host='download.pytorch.org', port=443): Max retries exceeded with url: /whl/nightly/cu121/torch/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: self-signed certificate in certificate chain (_ssl.c:1000)'))) - skipping
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /databricks/python3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch) (2023.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch) (3.2.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (74.0.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu121
# Requirement already satisfied: fbgemm_gpu in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from fbgemm_gpu) (1.26.4)
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: torchmetrics==1.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (1.0.3)
# Requirement already satisfied: numpy>1.20.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3) (1.26.4)
# Requirement already satisfied: torch>=1.8.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchmetrics==1.0.3) (2.6.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3) (24.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3) (0.11.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.7.0->torchmetrics==1.0.3) (74.0.0)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.12/site-packages (from lightning-utilities>=0.7.0->torchmetrics==1.0.3) (4.11.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (3.13.1)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (2023.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.1->torchmetrics==1.0.3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch>=1.8.1->torchmetrics==1.0.3) (2.1.3)
# Looking in indexes: https://download.pytorch.org/whl/nightly/cu121
# Requirement already satisfied: torchrec in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: fbgemm-gpu in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchrec) (1.1.0)
# Requirement already satisfied: torchmetrics==1.0.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchrec) (1.0.3)
# Requirement already satisfied: tqdm in /databricks/python3/lib/python3.12/site-packages (from torchrec) (4.66.4)
# Requirement already satisfied: pyre-extensions in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchrec) (0.0.32)
# Requirement already satisfied: iopath in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchrec) (0.1.10)
# Requirement already satisfied: numpy>1.20.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (1.26.4)
# Requirement already satisfied: torch>=1.8.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (2.6.0)
# Requirement already satisfied: packaging in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (24.1)
# Requirement already satisfied: lightning-utilities>=0.7.0 in /databricks/python3/lib/python3.12/site-packages (from torchmetrics==1.0.3->torchrec) (0.11.9)
# Requirement already satisfied: typing-extensions in /databricks/python3/lib/python3.12/site-packages (from iopath->torchrec) (4.11.0)
# Requirement already satisfied: portalocker in /databricks/python3/lib/python3.12/site-packages (from iopath->torchrec) (2.10.1)
# Requirement already satisfied: typing-inspect in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from pyre-extensions->torchrec) (0.9.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from lightning-utilities>=0.7.0->torchmetrics==1.0.3->torchrec) (74.0.0)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (3.13.1)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (2023.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-f7ad5eb1-995d-4365-b967-41c0889a6d04/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch>=1.8.1->torchmetrics==1.0.3->torchrec) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch>=1.8.1->torchmetrics==1.0.3->torchrec) (1.3.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /databricks/python3/lib/python3.12/site-packages (from typing-inspect->pyre-extensions->torchrec) (1.0.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch>=1.8.1->torchmetrics==1.0.3->torchrec) (2.1.3)

# %%
dbutils.library.restartPython()

# %%
# %pip install --trusted-host artifactory.us.caas.oneadp.com -i https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/ torch torchvision
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: torch in /databricks/python3/lib/python3.12/site-packages (2.5.1+cpu)
# Requirement already satisfied: torchvision in /databricks/python3/lib/python3.12/site-packages (0.20.1+cpu)
# Requirement already satisfied: filelock in /databricks/python3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /databricks/python3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /databricks/python3/lib/python3.12/site-packages (from torch) (3.2.1)
# Requirement already satisfied: jinja2 in /databricks/python3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /databricks/python3/lib/python3.12/site-packages (from torch) (2023.5.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch) (74.0.0)
# Requirement already satisfied: sympy==1.13.1 in /databricks/python3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /databricks/python3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from torchvision) (1.26.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /databricks/python3/lib/python3.12/site-packages (from torchvision) (10.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /databricks/python3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
# %pip install --trusted-host artifactory.us.caas.oneadp.com -i https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/ fbgemm-gpu
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Requirement already satisfied: fbgemm-gpu in /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages (1.1.0)
# Requirement already satisfied: numpy in /databricks/python3/lib/python3.12/site-packages (from fbgemm-gpu) (1.26.4)
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
dbutils.library.restartPython()

# %%
# %pip install --upgrade --no-deps --force-reinstall torch torchvision fbgemm-gpu torchrec --trusted-host artifactory.us.caas.oneadp.com --extra-index-url https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/


# Successfully installed fbgemm-gpu-1.1.0 torch-2.6.0 torchrec-1.1.0 torchvision-0.21.0

dbutils.library.restartPython()
# Out:
# Looking in indexes: https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/, https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/simple/
# Collecting torch
#   Downloading https://artifactory.us.caas.oneadp.com/artifactory/api/pypi/pypi/packages/packages/e5/35/0c52d708144c2deb595cd22819a609f78fdd699b95ff6f0ebcd456e3c7c1/torch-2.6.0-cp312-cp312-manylinux1_x86_64.whl (766.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0/766.6 MB ? eta -:--:--
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.1/766.6 MB 3.2 MB/s eta 0:04:04
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.3/766.6 MB 4.4 MB/s eta 0:02:54
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/766.6 MB 10.4 MB/s eta 0:01:14
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/766.6 MB 30.8 MB/s eta 0:00:25
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/766.6 MB 56.2 MB/s eta 0:00:14
#      ╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.3/766.6 MB 159.6 MB/s eta 0:00:05
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/766.6 MB 164.9 MB/s eta 0:00:05
#      ━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.2/766.6 MB 165.2 MB/s eta 0:00:05
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.3/766.6 MB 144.9 MB/s eta 0:00:06
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 31.8/766.6 MB 103.0 MB/s eta 0:00:08
#      ━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.6/766.6 MB 101.6 MB/s eta 0:00:08
#      ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.8/766.6 MB 91.8 MB/s eta 0:00:08
#      ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/766.6 MB 129.8 MB/s eta 0:00:06
#      ━━╺━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/766.6 MB 137.8 MB/s eta 0:00:06
#      ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.4/766.6 MB 168.2 MB/s eta 0:00:05
#      ━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.4
0
# Note: you may need to restart the kernel using %restart_python or dbutils.library.restartPython() to use updated packages.

# %%
import torch
import torchrec
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages/torch/__init__.py:318, in _load_global_deps()
#     317 try:
# --> 318     ctypes.CDLL(global_deps_lib_path, mode=ctypes.RTLD_GLOBAL)
#     319     # Workaround slim-wheel CUDA dependency bugs in cusparse and cudnn by preloading nvjitlink
#     320     # and nvrtc. In CUDA-12.4+ cusparse depends on nvjitlink, but does not have rpath when
#     321     # shipped as wheel, which results in OS picking wrong/older version of nvjitlink library
#     322     # if `LD_LIBRARY_PATH` is defined, see https://github.com/pytorch/pytorch/issues/138460
#     323     # Similar issue exist in cudnn that dynamically loads nvrtc, unaware of its relative path.
#     324     # See https://github.com/pytorch/pytorch/issues/145580
#
# File /usr/lib/python3.12/ctypes/__init__.py:379, in CDLL.__init__(self, name, mode, handle, use_errno, use_last_error, winmode)
#     378 if handle is None:
# --> 379     self._handle = _dlopen(self._name, mode)
#     380 else:
#
# OSError: libcudart.so.12: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# File <command-3674116869486874>, line 1
# ----> 1 import torch
#       2 import torchrec
#
# File /databricks/python_shell/lib/dbruntime/autoreload/discoverability/hook.py:71, in AutoreloadDiscoverabilityHook._patched_import(self, name, *args, **kwargs)
#      65 if not self._should_hint and (
#      66     (module := sys.modules.get(absolute_name)) is not None and
#      67     (fname := get_allowed_file_name_or_none(module)) is not None and
#      68     (mtime := os.stat(fname).st_mtime) > self.last_mtime_by_modname.get(
#      69         absolute_name, float("inf")) and not self._should_hint):
#      70     self._should_hint = True
# ---> 71 module = self._original_builtins_import(name, *args, **kwargs)
#      72 if (fname := fname or get_allowed_file_name_or_none(module)) is not None:
#      73     mtime = mtime or os.stat(fname).st_mtime
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages/torch/__init__.py:404
#     393 else:
#     394     # Easy way.  You want this most of the time, because it will prevent
#     395     # C++ symbols from libtorch clobbering C++ symbols from other
#    (...)
#     401     #
#     402     # See Note [Global dependencies]
#     403     if USE_GLOBAL_DEPS:
# --> 404         _load_global_deps()
#     405     from torch._C import *  # noqa: F403
#     408 class SymInt:
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages/torch/__init__.py:362, in _load_global_deps()
#     360     raise err
#     361 for lib_folder, lib_name in cuda_libs.items():
# --> 362     _preload_cuda_deps(lib_folder, lib_name)
#     363 ctypes.CDLL(global_deps_lib_path, mode=ctypes.RTLD_GLOBAL)
#
# File /local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages/torch/__init__.py:302, in _preload_cuda_deps(lib_folder, lib_name)
#     300         break
#     301 if not lib_path:
# --> 302     raise ValueError(f"{lib_name} not found in the system path {sys.path}")
#     303 ctypes.CDLL(lib_path)
#
# ValueError: libcublas.so.*[0-9] not found in the system path ['/databricks/python_shell/scripts', '/local_disk0/spark-0921d102-f032-4ea2-8ba3-9201e25702a5/userFiles-a9232a52-82d2-407e-bfa1-5350e3698454', '/databricks/spark/python', '/databricks/spark/python/lib/py4j-0.10.9.7-src.zip', '/databricks/jars/spark--maven-trees--ml--16.x--graphframes--org.graphframes--graphframes_2.12--org.graphframes__graphframes_2.12__0.8.4-db1-spark3.5.jar', '/databricks/python_shell/lib', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/local_disk0/.ephemeral_nfs/envs/pythonEnv-e2204beb-e1db-47d7-9048-9791d2b0172d/lib/python3.12/site-packages', '/local_disk0/.ephemeral_nfs/cluster_libraries/python/lib/python3.12/site-packages', '/databricks/python/lib/python3.12/site-packages', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages', '/databricks/.python_edge_libs', '/usr/local/lib/python3.12/dist-packages/setuptools/_vendor', '', '/Workspace/Users/ling.huang@adp.com']

# %% [markdown]
# ### Sample Data Set

# %%
### collect all clicks

query = f"""
    SELECT _token_associate_id AS user_id, 
            click_object_id AS item_id, 
            SUM(click) AS rating
    FROM onedata_us_east_1_shared_dit.nas_raw_lyric_search_dit.ml_search_with_click
    WHERE click_object_id is not null
    GROUP BY 1, 2
"""
df = spark.sql(query)

# %%
df.select('user_id').distinct().count()
# Out:
# 229

# %%
df.select('item_id').distinct().count()
# Out:
# 302

# %%
df.groupby('rating').count().show()
# Out:
# +------+-----+
# |rating|count|
# +------+-----+
# |     7|    4|
# |     6|    5|
# |    17|    1|
# |    28|    1|
# |     5|   12|
# |     1|  552|
# |     3|   51|
# |     8|    2|
# |     2|  101|
# |     4|   24|
# |    13|    1|
# |    14|    1|
# |    16|    1|
# +------+-----+

# %%
def shape(data):
    rows, cols = data.count(), len(data.columns)
    shape = (rows, cols)
    return shape

# %%
shape(df)
# Out:
# (756, 3)

# %%
from pyspark.sql import functions as F

# Calculate the mean of the ratings column
ratings_mean = df.groupBy().avg('rating').collect()[0][0]
print(f"Mean rating: {ratings_mean}")

# Modify all ratings less than the mean to 0 and greater than the mean to 1 and using a UDF to apply the transformation
modify_rating_udf = F.udf(lambda x: 0 if x < ratings_mean else 1, 'int')
relevant_df = df.withColumn('rating', modify_rating_udf('rating'))

# Rename rating to label
relevant_df = relevant_df.withColumnRenamed('rating', 'label')

# Displaying the dataframe
display(relevant_df)
# Out:
# Mean rating: 1.6203703703703705
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>user_id</th><th>item_id</th><th>label</th></tr></thead><tbody><tr><td>321d47b1-78de-438f-b6c3-2479e06d3bd2</td><td>7bb2c89a01a746e1b46272901a87605b</td><td>1</td></tr><tr><td>f30165e7-e7d7-4212-b961-47997b7e53af</td><td>9ca43b27a0ed48d699f0e126a9dcbe14</td><td>0</td></tr><tr><td>35d2b23b-4d4d-4b58-9686-0c57103af869</td><td>1c8362ee6cf44ff49990d29f3f783825</td><td>1</td></tr><tr><td>321d47b1-78de-438f-b6c3-2479e06d3bd2</td><td>b4eb1e9b-ce0c-4a6e-ac8c-b78745c6f696</td><td>0</td></tr><tr><td>cf056cdb-c14b-4fe7-abb4-ea899db0e992</td><td>2dfcb5da-8de6-43ad-a597-9caaef87884c</td><td>1</td></tr><tr><td>cf4d9d6d-9902-47dc-ab48-ec153f6f05e9</td><td>3a59d8daae5147c389cdaaffbcad7d64</td><td>0</td></tr><tr><td>c1e5e4b0-5515-4b95-bdda-2dd12b7f7f6a</td><td>dcfb1c00f6414037935ad05e2c69d10c</td><td>1</td></tr><tr><td>7864e425-bbea-4537-9425-f807f60bf131</td><td>fe6c2ca0f8744858836da9117b4cebcc</td><td>1</td></tr><tr><td>734cacb1-3f7a-4023-a75a-542996432829</td><td>b157943c-c33e-41eb-ab4a-e1337ddb70bb</td><td>0</td></
# 2025/03/27 20:16:32 INFO databricks.automl.client.manager: AutoML will optimize for F1 score metric, which is tracked as val_f1_score in the MLflow experiment.
# 2025/03/27 20:16:33 INFO databricks.automl.client.manager: MLflow Experiment ID: 3674116869511500
# 2025/03/27 20:16:33 INFO databricks.automl.client.manager: MLflow Experiment: https://adpdc-share1-dev.cloud.databricks.com/?o=233647784655798#mlflow/experiments/3674116869511500
# 2025/03/27 20:18:18 INFO databricks.automl.client.manager: Data exploration notebook: https://adpdc-share1-dev.cloud.databricks.com/?o=233647784655798#notebook/3674116869511534
# 2025/03/27 20:47:25 INFO databricks.automl.client.manager: AutoML experiment completed successfully.
#         <style>
#             .grid-container {
#               display: grid
#               grid-template-columns: auto;
#               padding: 10px;
#             }
#             <!-- Picked to be same as in webapp/web/js/templates/iframeSandbox.css -->
#             .grid-container div {
#               font-family: Helvetica, Arial, sans-serif;
#               font-size: 14px;
#             }
#         </style>
#         <div class="grid-container">
#
#             <div><p>For exploratory data analysis, open the <a href=https://adpdc-share1-dev.cloud.databricks.com/?o=233647784655798#notebook/3674116869511534>data exploration notebook</a></p></div>
#             <div><p>To view the best performing model, open the <a href=#notebook/3674116869511910>best trial notebook</a></p></div>
#             <div><p>To view details about all trials, navigate to the <a href=https://adpdc-share1-dev.cloud.databricks.com/?o=233647784655798#mlflow/experiments/3674116869511500>MLflow experiment</a></p></div>
#             <div><p><strong>Metrics for the best trial:</strong></p></div>
#             <div>
#                 <!-- class inlined from webapp/web/js/templates/iframeSandbox.css -->
#
#                     <table class="dataframe">
#                         <thead>
#                           <tr>
#                             <th></th>
#                             <th>Train</th>
#                             <th>Validation</th>
#                             <th>Test</th>
#                           </tr>
#                         </thead>
#                         <tbody>
#
#                 <tr>
#                     <th> f1_score </th>
#                     <td> 0.881 </td>
#                     <td> 0.509 </td>
#                     <td> 0.308 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> recall_score </th>
#                     <td> 0.855 </td>
#                     <td> 0.424 </td>
#                     <td> 0.275 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> roc_auc </th>
#                     <td> 0.987 </td>
#                     <td> 0.691 </td>
#                     <td> 0.628 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> false_negatives </th>
#                     <td> 17.000 </td>
#                     <td> 19.000 </td>
#                     <td> 37.000 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> false_positives </th>
#                     <td> 10.000 </td>
#                     <td> 8.000 </td>
#                     <td> 26.000 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> example_count </th>
#                     <td> 430.000 </td>
#                     <td> 118.000 </td>
#                     <td> 199.000 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> precision_score </th>
#                     <td> 0.909 </td>
#                     <td> 0.636 </td>
#                     <td> 0.350 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> true_positives </th>
#                     <td> 100.000 </td>
#                     <td> 14.000 </td>
#                     <td> 14.000 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> precision_recall_auc </th>
#                     <td> 0.968 </td>
#                     <td> 0.457 </td>
#                     <td> 0.346 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> true_negatives </th>
#                     <td> 303.000 </td>
#                     <td> 77.000 </td>
#                     <td> 122.000 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> log_loss </th>
#                     <td> 0.225 </td>
#                     <td> 0.590 </td>
#                     <td> 0.614 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> score </th>
#                     <td> 0.937 </td>
#                     <td> 0.771 </td>
#                     <td> 0.683 </td>
#                 </tr>
#
#
#                 <tr>
#                     <th> accuracy_score </th>
#                     <td> 0.937 </td>
#                     <td> 0.771 </td>
#                     <td> 0.683 </td>
#                 </tr>
#
#                         </tbody>
#                     </table>
#
#             </div>
#         </div>
